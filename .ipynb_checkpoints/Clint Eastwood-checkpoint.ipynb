# %%
import time
import config
import tmdbsimple as tmdb          # tmdbsimple 2.2.0
tmdb.API_KEY = config.tmdb_api_key # get TMDB API key from config.py file

import pprint as pp
import pandas as pd
import numpy as np
import scipy as sp
import scipy.stats as stats
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print("Enter actor's full name...")
actor = input("... MUST be a string: ")
search = tmdb.Search()
actor_response = search.person(query=actor) 
actor_id = search.results[0]['id']
actor_id
# Out:
# Enter actor's full name...
# ... MUST be a string: Clint Eastwood
# 190

# %%
actor_movie_credits = actor + " Movies"
actor_movie_credits
# Out:
# 'Clint Eastwood Movies'

# %%
#Now get actor's credits
search_actor_id = tmdb.People(actor_id)
response_actor_id = search_actor_id.movie_credits()
response_actor_id
#actor_movie_credits = actor + " Credits")
# Out:
# {'cast': [{'character': 'Bill Munny',
#    'credit_id': '52fe4211c3a36847f8001447',
#    'release_date': '1992-08-07',
#    'vote_count': 2028,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.9,
#    'title': 'Unforgiven',
#    'genre_ids': [37],
#    'original_language': 'en',
#    'original_title': 'Unforgiven',
#    'popularity': 16.755,
#    'id': 33,
#    'backdrop_path': '/nKYH8DaWjKE3RhEyaa0Ue01kPCp.jpg',
#    'overview': 'William Munny is a retired, once-ruthless killer turned gentle widower and hog farmer. To help support his two motherless children, he accepts one last bounty-hunter mission to find the men who brutalized a prostitute. Joined by his former partner and a cocky greenhorn, he takes on a corrupt sheriff.',
#    'poster_path': '/km6qw4qUkHQRN5y2U1juM1WkBFh.jpg'},
#   {'character': 'Luther Whitney',
#    'credit_id': '52fe4212c3a36847f8001ce1',
#    'release_date': '1997-02-14',
#    'vote_count': 424,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.6,
#    'title': 'Absolute Power',
#    'genre_ids': [80, 18, 9648, 53],
#    'original_language': 'en',
#    'original_title': 'Absolute Power',
#    'popularity': 10.509,
#    'id': 66,
#    'backdrop_path': '/zDSAJ8xpbq1jekZOT2DL9yasMEv.jpg',
#    'overview': 'A master thief coincidentally is robbing a house where a murder—in which the President of The United States is involved—occurs in front of his eyes. He is forced to run, while holding evidence that could convict the President.',
#    'poster_path': '/oJQdp09Oc51DkArsMDvgDLdWiDu.jpg'},
#   {'character': 'Frankie Dunn',
#    'credit_id': '52fe4213c3a36847f8002015',
#    'poster_path': '/h4VZKi2Jt4VoBYJmtC4c3bO8KqM.jpg',
#    'id': 70,
#    'video': False,
#    'vote_count': 5082,
#    'adult': False,
#    'backdrop_path': '/7nGW4MhYQ7sJfp482XkrgqPYQ2S.jpg',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'Million Dollar Baby',
#    'popularity': 14.475,
#    'title': 'Million Dollar Baby',
#    'vote_average': 7.9,
#    'overview': "Despondent over a painful estrangement from his daughter, trainer Frankie Dunn isn't prepared for boxer Maggie Fitzgerald to enter his life. But Maggie's determined to go pro and to convince Dunn and his cohort to help her.",
#    'release_date': '2004-12-15'},
#   {'character': 'Joe',
#    'credit_id': '52fe423dc3a36847f800ed7d',
#    'poster_path': '/sFLgxvtK9vxbNq502peVJ847Owp.jpg',
#    'id': 391,
#    'video': False,
#    'vote_count': 1942,
#    'adult': False,
#    'backdrop_path': '/mndYimxcima4Z5YxH8XngTEGi5L.jpg',
#    'genre_ids': [37],
#    'original_language': 'it',
#    'original_title': 'Per un pugno di dollari',
#    'popularity': 12.797,
#    'title': 'A Fistful of Dollars',
#    'vote_average': 7.9,
#    'overview': 'The Man With No Name enters the Mexican village of San Miguel in the midst of a power struggle among the three Rojo brothers and sheriff John Baxter. When a regiment of Mexican soldiers bearing gold intended to pay for new weapons is waylaid by the Rojo brothers, the stranger inserts himself into the middle of the long-simmering battle, selling false information to both sides for his own benefit.',
#    'release_date': '1967-01-18'},
#   {'character': 'Blondie',
#    'credit_id': '52fe4242c3a36847f80105db',
#    'release_date': '1967-12-29',
#    'vote_count': 4270,
#    'video': False,
#    'adult': False,
#    'vote_average': 8.4,
#    'title': 'The Good, the Bad and the Ugly',
#    'genre_ids': [37],
#    'original_language': 'it',
#    'original_title': 'Il buono, il brutto, il cattivo',
#    'popularity': 19.808,
#    'id': 429,
#    'backdrop_path': '/xGC2fY5KFmtuXnsuQwYQKFOLZFy.jpg',
#    'overview': 'While the Civil War rages between the Union and the Confederacy, three men – a quiet loner, a ruthless hit man and a Mexican bandit – comb the American Southwest in search of a strongbox containing $200,000 in stolen gold.',
#    'poster_path': '/wfPHdfofBD5PN96dV96a51B3Ja2.jpg'},
#   {'character': 'Robert Kincaid',
#    'credit_id': '52fe426ac3a36847f801cfc9',
#    'release_date': '1995-09-28',
#    'vote_count': 828,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.6,
#    'title': 'The Bridges of Madison County',
#    'genre_ids': [18, 10749],
#    'original_language': 'en',
#    'original_title': 'The Bridges of Madison County',
#    'popularity': 10.029,
#    'id': 688,
#    'backdrop_path': '/4TnGcUsyd6ixuLWHaaEG5BGkAIp.jpg',
#    'overview': 'Photographer Robert Kincaid wanders into the life of housewife Francesca Johnson for four days in the 1960s.',
#    'poster_path': '/8TfLAfIh5Qxp2J4ZjOafHYhWtDb.jpg'},
#   {'character': 'Monco',
#    'credit_id': '52fe4290c3a36847f802895b',
#    'release_date': '1967-05-10',
#    'vote_count': 1873,
#    'video': False,
#    'adult': False,
#    'vote_average': 8,
#    'title': 'For a Few Dollars More',
#    'genre_ids': [37],
#    'original_language': 'it',
#    'original_title': 'Per qualche dollaro in più',
#    'popularity': 13.634,
#    'id': 938,
#    'backdrop_path': '/hs6OPto38fF589ScpGhl7uSU4MI.jpg',
#    'overview': 'Two bounty hunters are in pursuit of "El Indio," one of the most wanted fugitives in the western territories, and his gang.',
#    'poster_path': '/3jblmNz3pCdNBpdCQvD08lx7d4v.jpg'},
#   {'character': 'Insp. Harry Callahan',
#    'credit_id': '52fe4296c3a36847f802a53b',
#    'poster_path': '/4j2tBAusIVev4ZaScncIHknP7eV.jpg',
#    'id': 984,
#    'video': False,
#    'vote_count': 1093,
#    'adult': False,
#    'backdrop_path': '/t3OZS8yMs0NL4YgWWc04eXHTn1X.jpg',
#    'genre_ids': [28, 80, 53],
#    'original_language': 'en',
#    'original_title': 'Dirty Harry',
#    'popularity': 13.525,
#    'title': 'Dirty Harry',
#    'vote_average': 7.5,
#    'overview': "When a madman dubbed 'Scorpio' terrorizes San Francisco, hard-nosed cop, Harry Callahan – famous for his take-no-prisoners approach to law enforcement – is tasked with hunting down the psychopath. Harry eventually collars Scorpio in the process of rescuing a kidnap victim, only to see him walk on technicalities. Now, the maverick detective is determined to nail the maniac himself.",
#    'release_date': '1971-12-22'},
#   {'character': "Gunnery Sgt. Tom 'Gunny' Highway",
#    'credit_id': '52fe43089251416c75000c75',
#    'release_date': '1986-12-05',
#    'vote_count': 444,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.7,
#    'title': 'Heartbreak Ridge',
#    'genre_ids': [28, 35, 18, 10752],
#    'original_language': 'en',
#    'original_title': 'Heartbreak Ridge',
#    'popularity': 9.107,
#    'id': 10015,
#    'backdrop_path': '/AjE2mqKN5qulD1TOugPiT9kvuZp.jpg',
#    'overview': 'A hard-nosed, hard-living Marine gunnery sergeant clashes with his superiors and his ex-wife as he takes command of a spoiled recon platoon with a bad attitude.',
#    'poster_path': '/hbKkfRpjtoCYabxEmhklM6MhF7g.jpg'},
#   {'character': 'Steve Everett',
#    'credit_id': '52fe435f9251416c7500dcb5',
#    'poster_path': '/hhRHHwwrxsGQnQIynNW78a1IlQI.jpg',
#    'id': 10354,
#    'video': False,
#    'vote_count': 283,
#    'adult': False,
#    'backdrop_path': '/45DYVh15aiMZA4WRTzSdHMeMgRD.jpg',
#    'genre_ids': [80, 18, 53, 9648],
#    'original_language': 'en',
#    'original_title': 'True Crime',
#    'popularity': 9.027,
#    'title': 'True Crime',
#    'vote_average': 6.5,
#    'overview': "Boozer, skirt chaser, careless father. You could create your own list of reporter Steve Everett's faults but there's no time. A San Quentin Death Row prisoner is slated to die at midnight – a man Everett has suddenly realized is innocent.",
#    'release_date': '1999-03-19'},
#   {'character': 'Harry Callahan',
#    'credit_id': '52fe439b9251416c75017009',
#    'release_date': '1973-12-24',
#    'vote_count': 449,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.2,
#    'title': 'Magnum Force',
#    'genre_ids': [28, 80, 18, 9648, 53],
#    'original_language': 'en',
#    'original_title': 'Magnum Force',
#    'popularity': 11.352,
#    'id': 10648,
#    'backdrop_path': '/bdQf4GBBb9NKHGGBibuW6oUifOi.jpg',
#    'overview': '"Dirty" Harry Callahan is a San Francisco Police Inspector on the trail of a group of rogue cops who have taken justice into their own hands. When shady characters are murdered one after another in grisly fashion, only Dirty Harry can stop them.',
#    'poster_path': '/3gqV4jpKNFqxUWug3BRD6yUzSL1.jpg'},
#   {'character': 'Insp. Harry Callahan',
#    'credit_id': '52fe439b9251416c7501708f',
#    'poster_path': '/mpiX5JtQc0zXnoMQpolaFwBP5Uf.jpg',
#    'id': 10649,
#    'video': False,
#    'vote_count': 387,
#    'adult': False,
#    'backdrop_path': '/yVJTG4nXUxdUJVK2y3md4miS6NN.jpg',
#    'genre_ids': [28, 80, 53],
#    'original_language': 'en',
#    'original_title': 'The Enforcer',
#    'popularity': 8.791,
#    'title': 'The Enforcer',
#    'vote_average': 6.8,
#    'overview': 'Dirty Harry Callahan returns again, this time saddled with a rookie female partner. Together, they must stop a terrorist group consisting of angry Vietnam veterans.',
#    'release_date': '1976-12-21'},
#   {'character': 'Insp. Harry Callahan',
#    'credit_id': '52fe439b9251416c7501711b',
#    'poster_path': '/pXRSzPXFOCKDisLO9jWJhm8Jr47.jpg',
#    'id': 10650,
#    'video': False,
#    'vote_count': 381,
#    'adult': False,
#    'backdrop_path': '/oopJgSxY9UooC4asQtWOADpxI6h.jpg',
#    'genre_ids': [80],
#    'original_language': 'en',
#    'original_title': 'Sudden Impact',
#    'popularity': 9.596,
#    'title': 'Sudden Impact',
#    'vote_average': 6.6,
#    'overview': "When a young rape victim takes justice into her own hands and becomes a serial killer, it's up to Dirty Harry Callahan, on suspension from the SFPD, to bring her to justice.",
#    'release_date': '1983-12-08'},
#   {'character': 'Insp. Harry Callahan',
#    'credit_id': '52fe439c9251416c750171a7',
#    'poster_path': '/9ZUSqox9lIxN4xaYBac2QXMFcZj.jpg',
#    'id': 10651,
#    'video': False,
#    'vote_count': 360,
#    'adult': False,
#    'backdrop_path': '/v761yOHKO3p6Yr7LDCjud6tUL5G.jpg',
#    'genre_ids': [28, 80, 53],
#    'original_language': 'en',
#    'original_title': 'The Dead Pool',
#    'popularity': 11.649,
#    'title': 'The Dead Pool',
#    'vote_average': 6.4,
#    'overview': 'Dirty Harry Callahan returns for his final film adventure. Together with his partner Al Quan, he must investigate the systematic murder of actors and musicians. By the time Harry learns that the murders are a part of a sick game to predict the deaths of celebrities before they happen, it may be too late...',
#    'release_date': '1988-07-12'},
#   {'character': 'Mitchell Gant',
#    'credit_id': '52fe43a99251416c7501934d',
#    'poster_path': '/1QK1xhmvnLLZhDC8DNaFt08psp9.jpg',
#    'id': 10724,
#    'video': False,
#    'vote_count': 237,
#    'adult': False,
#    'backdrop_path': '/yIvxB5Gbq27ZexGgmKLcuDVTq1c.jpg',
#    'genre_ids': [878, 28, 12, 53],
#    'original_language': 'en',
#    'original_title': 'Firefox',
#    'popularity': 8.167,
#    'title': 'Firefox',
#    'vote_average': 6.1,
#    'overview': "The Soviets have developed a revolutionary new jet fighter, called 'Firefox'. Worried that the jet will be used as a first-strike weapon—as there are rumours that it is undetectable by radar—the British send ex-Vietnam War pilot, Mitchell Gant on a covert mission into the Soviet Union to steal the Firefox.",
#    'release_date': '1982-06-13'},
#   {'character': 'Frank Morris',
#    'credit_id': '52fe43ac9251416c7501994f',
#    'release_date': '1979-06-22',
#    'vote_count': 1238,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.5,
#    'title': 'Escape from Alcatraz',
#    'genre_ids': [80, 18],
#    'original_language': 'en',
#    'original_title': 'Escape from Alcatraz',
#    'popularity': 15.775,
#    'id': 10734,
#    'backdrop_path': '/doJGjcWPpuGuDPJwCpCNnYUG9x4.jpg',
#    'overview': 'Escape from Alcatraz tells the story of the only three men ever to escape from the infamous maximum security prison at Alcatraz. In 29 years, the seemingly impenetrable federal penitentiary, which housed Al Capone and "Birdman" Robert Stroud, was only broken once - by three men never heard of again.',
#    'poster_path': '/lBAxIEywz3KfzXimn9qHBArLHU8.jpg'},
#   {'character': 'Josey Wales',
#    'credit_id': '52fe43ad9251416c75019df7',
#    'poster_path': '/8HRmovHTe1FTiZ5GUM534izCNL2.jpg',
#    'id': 10747,
#    'video': False,
#    'vote_count': 507,
#    'adult': False,
#    'backdrop_path': '/vkE1ROrP1gA5c1L31XZ8JR9QRMJ.jpg',
#    'genre_ids': [37],
#    'original_language': 'en',
#    'original_title': 'The Outlaw Josey Wales',
#    'popularity': 12.278,
#    'title': 'The Outlaw Josey Wales',
#    'vote_average': 7.5,
#    'overview': "After avenging his family's brutal murder, Wales is pursued by a pack of soldiers. He prefers to travel alone, but ragtag outcasts are drawn to him - and Wales can't bring himself to leave them unprotected.",
#    'release_date': '1976-06-30'},
#   {'character': 'Tommy Nowak',
#    'credit_id': '52fe43d2c3a368484e000187',
#    'release_date': '1989-05-26',
#    'vote_count': 83,
#    'video': False,
#    'adult': False,
#    'vote_average': 5.4,
#    'title': 'Pink Cadillac',
#    'genre_ids': [28, 12, 35, 18, 10749],
#    'original_language': 'en',
#    'original_title': 'Pink Cadillac',
#    'popularity': 8.656,
#    'id': 20006,
#    'backdrop_path': '/a31S4P5Hb4Bknkbo8EvwWML8O8O.jpg',
#    'overview': 'Clint Eastwood plays a bounty hunter who helps out the wife of a bail-jumper after her child is kidnapped by neo-Nazi types.',
#    'poster_path': '/7XYykCIVegcVprrBUG16D6iYQe9.jpg'},
#   {'character': 'Dr. Jonathan Hemlock',
#    'credit_id': '52fe43dcc3a368484e00252d',
#    'poster_path': '/q1GB9vhp2WgnCTxo4PqNAo5yG9u.jpg',
#    'id': 20187,
#    'video': False,
#    'vote_count': 156,
#    'adult': False,
#    'backdrop_path': '/AfkACKbBjBKViIh1XhGLbXb0GOX.jpg',
#    'genre_ids': [28, 12, 80, 18, 9648, 53],
#    'original_language': 'en',
#    'original_title': 'The Eiger Sanction',
#    'popularity': 8.638,
#    'title': 'The Eiger Sanction',
#    'vote_average': 6.2,
#    'overview': 'A classical art professor and collector, who doubles as a professional assassin, is coerced out of retirement to avenge the murder of an old friend.',
#    'release_date': '1975-05-21'},
#   {'character': 'Marshal Jed Cooper',
#    'credit_id': '52fe43e4c3a36847f807687d',
#    'release_date': '1968-07-31',
#    'vote_count': 347,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.8,
#    'title': "Hang 'em High",
#    'genre_ids': [37],
#    'original_language': 'en',
#    'original_title': "Hang 'em High",
#    'popularity': 10.355,
#    'id': 4929,
#    'backdrop_path': '/b9ysOV6lBXY4cZen5AM7Z2r75io.jpg',
#    'overview': "Marshall Jed Cooper survives a hanging, vowing revenge on the lynch mob that left him dangling. To carry out his oath for vengeance, he returns to his former job as a lawman. Before long, he's caught up with the nine men on his hit list and starts dispensing his own brand of Wild West justice.",
#    'poster_path': '/gFvRKgCAa1MKlcAKZfoDNdR2dgy.jpg'},
#   {'character': 'Pardner',
#    'credit_id': '52fe43e5c3a368484e004617',
#    'poster_path': '/1wDiGBBhXStKy2674zDSEwxlBcw.jpg',
#    'id': 20391,
#    'video': False,
#    'vote_count': 104,
#    'adult': False,
#    'backdrop_path': '/vl54nByNhUuntO1DbILfBkrBvnE.jpg',
#    'genre_ids': [18, 28, 35, 37, 10402],
#    'original_language': 'en',
#    'original_title': 'Paint Your Wagon',
#    'popularity': 6.157,
#    'title': 'Paint Your Wagon',
#    'vote_average': 6.4,
#    'overview': 'A Michigan farmer and a prospector form a partnership in the California gold country. Their adventures include buying and sharing a wife, hijacking a stage, kidnapping six prostitutes, and turning their mining camp into a boom town. Along the way there is plenty of drinking, gambling, and singing. They even find time to do some creative gold mining.',
#    'release_date': '1969-10-15'},
#   {'character': 'Lt. Morris Schaffer',
#    'credit_id': '52fe43ea9251416c75022f43',
#    'release_date': '1969-03-05',
#    'vote_count': 403,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.6,
#    'title': 'Where Eagles Dare',
#    'genre_ids': [28, 12, 18, 36, 10752],
#    'original_language': 'en',
#    'original_title': 'Where Eagles Dare',
#    'popularity': 12.938,
#    'id': 11046,
#    'backdrop_path': '/aAFq5jVHV6RZpLcRXATskNBuEbM.jpg',
#    'overview': "World War II is raging, and an American general has been captured and is being held hostage in the Schloss Adler, a Bavarian castle that's nearly impossible to breach. It's up to a group of skilled Allied soldiers to liberate the general before it's too late.",
#    'poster_path': '/991u0tSWGTVXCYkgC6ftaGE4bkQ.jpg'},
#   {'character': 'Frank Corvin',
#    'credit_id': '52fe440ec3a36847f807fc81',
#    'poster_path': '/aBhWg4uQMnpWnsn8pgNw6mQasOJ.jpg',
#    'id': 5551,
#    'video': False,
#    'vote_count': 689,
#    'adult': False,
#    'backdrop_path': '/yDq3Mi5iqPWqnN1ym5VZrEL07EN.jpg',
#    'genre_ids': [28, 12, 53],
#    'original_language': 'en',
#    'original_title': 'Space Cowboys',
#    'popularity': 8.672,
#    'title': 'Space Cowboys',
#    'vote_average': 6.3,
#    'overview': "Frank Corvin, ‘Hawk’ Hawkins, Jerry O'Neill and ‘Tank’ Sullivan were hotdog members of Project Daedalus, the Air Force's test program for space travel, but their hopes were dashed in 1958 with the formation of NASA and the use of trained chimps. They blackmail their way into orbit when Russia's mysterious ‘Ikon’ communications satellite's orbit begins to degrade and threatens to crash to Earth.",
#    'release_date': '2000-07-31'},
#   {'character': 'Bronco Billy',
#    'credit_id': '52fe442bc3a368484e013775',
#    'release_date': '1980-06-11',
#    'vote_count': 92,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.1,
#    'title': 'Bronco Billy',
#    'genre_ids': [28, 35, 18, 37, 10749],
#    'original_language': 'en',
#    'original_title': 'Bronco Billy',
#    'popularity': 8.013,
#    'id': 21866,
#    'backdrop_path': '/k215tEWyBst0aLgD976SlVxrrLQ.jpg',
#    'overview': 'An idealistic, modern-day cowboy struggles to keep his Wild West show afloat in the face of hard luck and waning interest.',
#    'poster_path': '/9eXrB9j0gwxQBPJWRp8ExgKaSy7.jpg'},
#   {'character': 'Sergeant First Class Kelly',
#    'credit_id': '52fe44619251416c75032b57',
#    'poster_path': '/lLFncrtTIz1hcteLbM9eKRflrMd.jpg',
#    'id': 11589,
#    'video': False,
#    'vote_count': 316,
#    'adult': False,
#    'backdrop_path': '/js7WdYkmPDx8zHX0pgzhNuOTk77.jpg',
#    'genre_ids': [12, 35, 10752],
#    'original_language': 'en',
#    'original_title': "Kelly's Heroes",
#    'popularity': 11.207,
#    'title': "Kelly's Heroes",
#    'vote_average': 7.4,
#    'overview': 'A misfit group of World War II American soldiers goes AWOL to rob a bank behind German lines.',
#    'release_date': '1970-06-23'},
#   {'character': 'Nick Pulovski',
#    'credit_id': '52fe4465c3a36847f80936f5',
#    'poster_path': '/eKNeRE7uxShUZavtuAJ5YY2ViYH.jpg',
#    'id': 6723,
#    'video': False,
#    'vote_count': 243,
#    'adult': False,
#    'backdrop_path': '/1dPfT8SAVv7ARTbPf4tiM6ThdP2.jpg',
#    'genre_ids': [28, 80, 18, 53],
#    'original_language': 'en',
#    'original_title': 'The Rookie',
#    'popularity': 9.386,
#    'title': 'The Rookie',
#    'vote_average': 5.8,
#    'overview': "Veteran cop Nick Pulovski is used to playing musical partners; many of the partners he's had in the past have died on the job, and often as a result of Nick's risky tactics. But the rookie who's been assigned to help Nick bust a carjacking ring is almost as hotheaded as he is … and when Nick gets kidnapped, his newbie partner is his only hope.",
#    'release_date': '1990-12-06'},
#   {'character': 'Capt. Wes Block',
#    'credit_id': '52fe447d9251416c75036a87',
#    'release_date': '1984-08-17',
#    'vote_count': 148,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.1,
#    'title': 'Tightrope',
#    'genre_ids': [80, 18, 9648, 53],
#    'original_language': 'en',
#    'original_title': 'Tightrope',
#    'popularity': 10.116,
#    'id': 11707,
#    'backdrop_path': '/sEo92hswtqKB55opy98ripMg5TV.jpg',
#    'overview': "Wes Block is a detective who's put on the case of a serial killer. His victims are young and pretty women, which he rapes and murders. The murders are getting personal when the killer chooses victims who are acquaintances of Block. Even his daughters are threatened.",
#    'poster_path': '/3MKGOGgd5xcgfLqRTpaGwneV17T.jpg'},
#   {'character': 'The Stranger',
#    'credit_id': '52fe449d9251416c7503b07b',
#    'release_date': '1973-04-19',
#    'vote_count': 495,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.5,
#    'title': 'High Plains Drifter',
#    'genre_ids': [37],
#    'original_language': 'en',
#    'original_title': 'High Plains Drifter',
#    'popularity': 10.727,
#    'id': 11901,
#    'backdrop_path': '/hST5A6ljJWlbyz5kbh6JV2WONzU.jpg',
#    'overview': 'A gunfighting stranger comes to the small settlement of Lago. After gunning down three gunmen who tried to kill him, the townsfolk decide to hire the Stranger to hold off three outlaws who are on their way.',
#    'poster_path': '/557vwDdOIQ07Q1QvTwHVmxHJpXU.jpg'},
#   {'character': 'Hogan',
#    'credit_id': '52fe44a19251416c7503b7e9',
#    'release_date': '1970-06-16',
#    'vote_count': 254,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.9,
#    'title': 'Two Mules for Sister Sara',
#    'genre_ids': [37],
#    'original_language': 'en',
#    'original_title': 'Two Mules for Sister Sara',
#    'popularity': 11.213,
#    'id': 11916,
#    'backdrop_path': '/gMGFCW5YCR0C958xxuKAoInUoiE.jpg',
#    'overview': 'Hogan, on his way to do some reconnaissance for a future mission to capture a French fort, encounters Sister Sara, a nun in trouble. Before he knows it, Hogan is accompanying Sister Sara in the dangerous frontier while she seeks to achieve a hidden goal.',
#    'poster_path': '/u98Fqg9CJsvy0ppn21ndND3WDnY.jpg'},
#   {'character': 'Thunderbolt',
#    'credit_id': '52fe44a1c3a36847f80a11a1',
#    'release_date': '1974-05-23',
#    'vote_count': 202,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.8,
#    'title': 'Thunderbolt and Lightfoot',
#    'genre_ids': [28, 35, 80],
#    'original_language': 'en',
#    'original_title': 'Thunderbolt and Lightfoot',
#    'popularity': 5.841,
#    'id': 8348,
#    'backdrop_path': '/qquZOH7PfVb1t2T6CiCWSYt7YIW.jpg',
#    'overview': 'With the help of an irreverent young sidekick, a bank robber gets his old gang back together to organise a daring new heist.',
#    'poster_path': '/ys9vfK1436huuHsUpM7MxBkX3qS.jpg'},
#   {'character': 'Cpl. John McBurney',
#    'credit_id': '52fe44a69251416c910181e7',
#    'release_date': '1971-03-31',
#    'vote_count': 178,
#    'video': False,
#    'adult': False,
#    'vote_average': 7,
#    'title': 'The Beguiled',
#    'genre_ids': [18, 53, 10752],
#    'original_language': 'en',
#    'original_title': 'The Beguiled',
#    'popularity': 7.066,
#    'id': 31906,
#    'backdrop_path': '/1Aucj1zrqpLZd5yLNAmF5MGldt.jpg',
#    'overview': "Offbeat Civil War drama in which a wounded Yankee soldier, after finding refuge in an isolated girls' school in the South towards the end of the war, becomes the object of the young women's sexual fantasies. The soldier manipulates the situation for his own gratification, but when he refuses to completely comply with the girls' wishes, they make it very difficult for him to leave.",
#    'poster_path': '/iUTzQnTGy7rzhFs5GnsXNAT48KE.jpg'},
#   {'character': 'Clint Eastwood (uncredited)',
#    'credit_id': '52fe44bfc3a36847f80a79c5',
#    'poster_path': '/1WeumvndgPE3hopKQqXbCKO26oH.jpg',
#    'id': 8839,
#    'video': False,
#    'vote_count': 2540,
#    'adult': False,
#    'backdrop_path': '/w4w8CTEe4isWO2TzDSQ3MV3br9l.jpg',
#    'genre_ids': [14, 35, 10751],
#    'original_language': 'en',
#    'original_title': 'Casper',
#    'popularity': 10.385,
#    'title': 'Casper',
#    'vote_average': 6.2,
#    'overview': 'Furious that her late father only willed her his gloomy-looking mansion rather than his millions, Carrigan Crittenden is ready to burn the place to the ground when she discovers a map to a treasure hidden in the house. But when she enters the rickety mansion to seek her claim, she is frightened away by a wicked wave of ghosts. Determined to get her hands on this hidden fortune, she hires afterlife therapist Dr. James Harvey to exorcise the ghosts from the mansion. Harvey and his daughter Kat move in, and soon Kat meets Casper, the ghost of a young boy who\'s "the friendliest ghost you know." But not so friendly are Casper\'s uncles--Stretch, Fatso and Stinkie--who are determined to drive all "fleshies" away.',
#    'release_date': '1995-05-26'},
#   {'character': 'Preacher',
#    'credit_id': '52fe44c3c3a36847f80a8a7d',
#    'release_date': '1985-06-28',
#    'vote_count': 455,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.1,
#    'title': 'Pale Rider',
#    'genre_ids': [37, 10749],
#    'original_language': 'en',
#    'original_title': 'Pale Rider',
#    'popularity': 11.991,
#    'id': 8879,
#    'backdrop_path': '/2Sjgpf8XLtphbfCTPS8ZU96b2J1.jpg',
#    'overview': 'A small gold mining camp is terrorised by a ruthless land owner wanting to take their land. Clint Eastwood arrives riding a pale horse just as a young girl is praying to God to help the miners. He is revealed to be a preacher with mysterious and possible otherworldly origins who teams up with the miners to defeat the land owner and the corrupt sheriff.',
#    'poster_path': '/7C18VUCvZH5O0ibZogZP4TQJTiu.jpg'},
#   {'character': 'Jet Pilot',
#    'credit_id': '52fe44d9c3a36847f80adacb',
#    'poster_path': '/gPjlVSys2CJP1aQKXnhj4kKDxrB.jpg',
#    'id': 9077,
#    'video': False,
#    'vote_count': 99,
#    'adult': False,
#    'backdrop_path': '/ccjSeVoh3ZPXoiFSkFmZZM1HmsC.jpg',
#    'genre_ids': [27, 878, 53],
#    'original_language': 'en',
#    'original_title': 'Tarantula',
#    'popularity': 9.042,
#    'title': 'Tarantula',
#    'vote_average': 6.2,
#    'overview': "A lone-wolf scientist sequestered in a mansion near a small desert town arouses the suspicion of the town's doctor when his lab assistant is found dead from a case of acromegaly which took only four days to develop.  As the doctor investigates, aided by the scientist's new, and very female, assistant, they discover that, far worse, something much larger and hungrier than it ever should be,  is devouring local cattle - and humans - in increasingly large quantities.",
#    'release_date': '1955-12-14'},
#   {'character': 'Secret Service Agent Frank Horrigan',
#    'credit_id': '52fe44f0c3a36847f80b3101',
#    'poster_path': '/bmeD5LdQiRaZmVHbySXw6WJgAVA.jpg',
#    'id': 9386,
#    'video': False,
#    'vote_count': 703,
#    'adult': False,
#    'backdrop_path': '/wrmr8lCW7EPHLbFe1GjnyZZecGL.jpg',
#    'genre_ids': [28, 18, 53, 80, 9648],
#    'original_language': 'en',
#    'original_title': 'In the Line of Fire',
#    'popularity': 11.372,
#    'title': 'In the Line of Fire',
#    'vote_average': 6.9,
#    'overview': 'Veteran Secret Service agent Frank Horrigan is a man haunted by his failure to save President Kennedy while serving protection detail in Dallas. Thirty years later, a man calling himself "Booth" threatens the life of the current President, forcing Horrigan to come back to protection detail to confront the ghosts from his past.',
#    'release_date': '1993-07-08'},
#   {'character': 'Coogan',
#    'credit_id': '52fe44f1c3a368484e03fa53',
#    'release_date': '1968-10-02',
#    'vote_count': 136,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.5,
#    'title': "Coogan's Bluff",
#    'genre_ids': [28, 80, 18, 53],
#    'original_language': 'en',
#    'original_title': "Coogan's Bluff",
#    'popularity': 9.311,
#    'id': 26170,
#    'backdrop_path': '/evKvNgzydY1e8LmnEpxhAO0272X.jpg',
#    'overview': 'Coogan (Clint Eastwood) an Arizona deputy sheriff goes to New York to pick up a prisoner. While escorting the prisoner to the airport he escapes and Coogan heads into the City to recapture him.',
#    'poster_path': '/3qesKb5OL4zzBRwc2GiQPOeGrib.jpg'},
#   {'character': 'Chief Red Garnett',
#    'credit_id': '52fe4509c3a36847f80b8add',
#    'poster_path': '/pJNioEVuIGNHAxwn0JtOzW111s7.jpg',
#    'id': 9559,
#    'video': False,
#    'vote_count': 735,
#    'adult': False,
#    'backdrop_path': '/nHZM78MjXsOXtN0zvNLRnRV7BJD.jpg',
#    'genre_ids': [80, 18, 53],
#    'original_language': 'en',
#    'original_title': 'A Perfect World',
#    'popularity': 10.083,
#    'title': 'A Perfect World',
#    'vote_average': 7.4,
#    'overview': 'A kidnapped boy strikes up a friendship with his captor: an escaped convict on the run from the law, headed by an honorable U.S. Marshal.',
#    'release_date': '1993-11-24'},
#   {'character': 'Terry McCaleb',
#    'credit_id': '52fe450cc3a36847f80b9301',
#    'poster_path': '/bRGewrLrBJKLTYkO4zoTS8MxOHX.jpg',
#    'id': 9573,
#    'video': False,
#    'vote_count': 371,
#    'adult': False,
#    'backdrop_path': '/q2DEwwyzf5SyzSzFZK0vVIK3DIq.jpg',
#    'genre_ids': [80, 53],
#    'original_language': 'en',
#    'original_title': 'Blood Work',
#    'popularity': 8.752,
#    'title': 'Blood Work',
#    'vote_average': 6.2,
#    'overview': 'Still recovering from a heart transplant, a retired FBI profiler returns to service when his own blood analysis offers clues to the identity of a serial killer.',
#    'release_date': '2002-08-06'},
#   {'character': 'Walt Kowalski',
#    'credit_id': '52fe454f9251416c750523ff',
#    'release_date': '2008-12-09',
#    'vote_count': 6088,
#    'video': False,
#    'adult': False,
#    'vote_average': 8,
#    'title': 'Gran Torino',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'Gran Torino',
#    'popularity': 13.573,
#    'id': 13223,
#    'backdrop_path': '/w7oBCXL7gAwmYD7g0W17q8q1Ozc.jpg',
#    'overview': "Widower Walt Kowalski is a grumpy, prejudiced, tough-minded, unhappy, old, Korean War veteran who can't get along with either his kids or his neighbours. His prize possession is a 1972 Gran Torino he keeps in mint condition. When his neighbour, Thao—a young Hmong teenager under pressure from his gang member cousin—tries to steal his Gran Torino, Walt sets out to reform the youth and takes steps to protect Thao and his family from the gangs that infest their neighborhood.",
#    'poster_path': '/yeBc5vpEiqIAZrbVQnl833GlBEi.jpg'},
#   {'character': '',
#    'credit_id': '52fe4586c3a36847f80cc203',
#    'poster_path': '/51TTPweO0AiAlFyPDHkPRO6nFRf.jpg',
#    'id': 40196,
#    'video': False,
#    'vote_count': 6,
#    'adult': False,
#    'backdrop_path': '/h6vDNT9OHzfrwtHNmvPNlz1VPbi.jpg',
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'America: A Tribute to Heroes',
#    'popularity': 1.49,
#    'title': 'America: A Tribute to Heroes',
#    'vote_average': 6,
#    'overview': 'America: A Tribute to Heroes was a benefit concert organized by actor George Clooney and broadcast by the four major United States television networks in the aftermath of the September 11, 2001 attacks on the World Trade Center and The Pentagon. Done in the style of a telethon, it featured a number of national and international entertainers performing to raise money for the victims and their families, particularly but not limited to the New York City firefighters and New York City police officers. It aired September 21, 2001, uninterrupted and commercial-free. It was released on December 4, 2001 on compact disc and DVD.',
#    'release_date': '2001-09-21'},
#   {'character': 'John Wilson',
#    'credit_id': '52fe45afc3a368484e06942b',
#    'poster_path': '/6nGnHhGyaAfhkSH39gBHlFj3O4q.jpg',
#    'id': 28761,
#    'video': False,
#    'vote_count': 99,
#    'adult': False,
#    'backdrop_path': '/lUtyGLrWzS6edEi0oDXr6yMdGJ4.jpg',
#    'genre_ids': [28, 12, 18],
#    'original_language': 'en',
#    'original_title': 'White Hunter, Black Heart',
#    'popularity': 7.722,
#    'title': 'White Hunter, Black Heart',
#    'vote_average': 6.5,
#    'overview': 'A thinly fictionalized account of a legendary movie director, whose desire to hunt down an animal turns into a grim situation with his movie crew in Africa',
#    'release_date': '1990-09-14'},
#   {'character': 'Husband',
#    'credit_id': '52fe45d79251416c91040339',
#    'release_date': '1969-03-12',
#    'vote_count': 21,
#    'video': False,
#    'adult': False,
#    'vote_average': 5.8,
#    'title': 'The Witches',
#    'genre_ids': [35, 18, 10749],
#    'original_language': 'it',
#    'original_title': 'Le streghe',
#    'popularity': 2.98,
#    'id': 36236,
#    'backdrop_path': '/5DfZhbdHSlU99hwtGfDLIB60mRP.jpg',
#    'overview': "Five short stories loosely dealing with the roles of women in society. A superstar actress travels to a mountain resort, only to evoke jealousy from women and lust from men. A woman offers to take an injured man to the hospital. A widowed father and his son seek for a new wife/mother. A man seeks revenge for a woman's honor. A bored housewife tries to explain to her husband that he's not as romantic as he used to be.",
#    'poster_path': '/c4MkRbvhYPywQVDhf8g61Qsyo27.jpg'},
#   {'character': 'Himself',
#    'credit_id': '52fe45d8c3a368484e0720f7',
#    'poster_path': '/peH43ELxI8ED50zBkfe7nPLZywV.jpg',
#    'id': 29332,
#    'video': False,
#    'vote_count': 10,
#    'adult': False,
#    'backdrop_path': '/1v748X0SN6KY9XpXjtAqIFVDzEH.jpg',
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': "Raw Iron: The Making of 'Pumping Iron'",
#    'popularity': 0.84,
#    'title': "Raw Iron: The Making of 'Pumping Iron'",
#    'vote_average': 7.3,
#    'overview': 'A documentary on the making of "Pumping Iron" to celebrate its 25th anniversary. Aired on Cinemax.',
#    'release_date': '2002-01-01'},
#   {'character': 'Joe Kidd',
#    'credit_id': '52fe46239251416c7506e755',
#    'poster_path': '/rLsoXLC2YpZ5B0OR1wTLv1i4jC3.jpg',
#    'id': 14881,
#    'video': False,
#    'vote_count': 140,
#    'adult': False,
#    'backdrop_path': '/nXKa3FR1kUfBxRsVg3K9ZQapyS8.jpg',
#    'genre_ids': [37],
#    'original_language': 'en',
#    'original_title': 'Joe Kidd',
#    'popularity': 7.603,
#    'title': 'Joe Kidd',
#    'vote_average': 6.4,
#    'overview': 'A band of Mexicans find their U. S. land claims denied and all the records destroyed in a courthouse fire. Their leader, Louis Chama, encourages them to use force to regain their land. A wealthy landowner wanting the same decides to hire a gang of killers with Joe Kidd to track Chama.',
#    'release_date': '1972-07-14'},
#   {'character': 'Dave',
#    'credit_id': '52fe46559251416c750750c7',
#    'poster_path': '/gMMYNpxsVwGjgtMR20dKXr3kWUg.jpg',
#    'id': 15393,
#    'video': False,
#    'vote_count': 170,
#    'adult': False,
#    'backdrop_path': '/owqxugHrY65LFsSgXkx2O1iIOjG.jpg',
#    'genre_ids': [80, 18, 10749, 53],
#    'original_language': 'en',
#    'original_title': 'Play Misty for Me',
#    'popularity': 9.197,
#    'title': 'Play Misty for Me',
#    'vote_average': 6.7,
#    'overview': 'A brief fling between a male disc jockey and an obsessed female fan takes a frightening, and perhaps even deadly turn when another woman enters the picture.',
#    'release_date': '1971-11-03'},
#   {'character': 'Philo Beddoe',
#    'credit_id': '52fe46579251416c75075479',
#    'poster_path': '/6djws9dSOk8WquoB14LdZy71c37.jpg',
#    'id': 15417,
#    'video': False,
#    'vote_count': 208,
#    'adult': False,
#    'backdrop_path': '/4YdEQTF7wZyl2kTKsRc567Lp3q3.jpg',
#    'genre_ids': [28, 35, 12, 10749, 18],
#    'original_language': 'en',
#    'original_title': 'Every Which Way But Loose',
#    'popularity': 11.228,
#    'title': 'Every Which Way But Loose',
#    'vote_average': 6.1,
#    'overview': "Philo Beddoe is your regular, easygoing, truck-driving guy. He's also the best bar-room brawler west of the Rockies. And he lives with a 165-pound orangutan named Clyde. Like other guys, Philo finally falls in love - with a flighty singer who leads him on a screwball chase across the American Southwest. Nothing's in the way except a motorcycle gang, and legendary brawler Tank Murdock.",
#    'release_date': '1978-12-19'},
#   {'character': 'Red Stovall',
#    'credit_id': '52fe467d9251416c91056241',
#    'release_date': '1982-12-15',
#    'vote_count': 68,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.1,
#    'title': 'Honkytonk Man',
#    'genre_ids': [35, 18, 10402, 37],
#    'original_language': 'en',
#    'original_title': 'Honkytonk Man',
#    'popularity': 6.32,
#    'id': 37917,
#    'backdrop_path': '/oXMXnP5nrfQSwQ2rweVjICxh3yU.jpg',
#    'overview': 'Young boy leaves the Oklahoma farm to travel with his country musician uncle who is trying out for the Grand Ole Opry. Set during the Great Depression.',
#    'poster_path': '/iWfzcM49wT02y7I03Br0lVUlKwY.jpg'},
#   {'character': 'Jonesey',
#    'credit_id': '52fe468bc3a368484e09692d',
#    'poster_path': '/iCfN0KzQOxxcA57a2TQuBlMyimM.jpg',
#    'id': 62742,
#    'video': False,
#    'vote_count': 10,
#    'adult': False,
#    'backdrop_path': '/k0ZzZvDQdlbmb4ETnBnCHtloL56.jpg',
#    'genre_ids': [35, 10751, 10749],
#    'original_language': 'en',
#    'original_title': 'Francis in the Navy',
#    'popularity': 1.919,
#    'title': 'Francis in the Navy',
#    'vote_average': 5.6,
#    'overview': 'In the U. S. Army intelligence office, bumbling lieutenant Peter Stirling receives a coded message from his friend, Francis, a talking mule. The note urges Pete to hurry to the Coronado, California naval base, where Francis is about to be sold as surplus. Pete rushes to the train station, but before he can board, nurse Betsy Donevan mistakes him for her shell-shocked brother, Navy boatswain Slicker Donevan. She tries to forcibly remove his uniform so he will not get into trouble for impersonating an Army officer. Finally she realizes that Pete is not Slicker but merely his mirror image.',
#    'release_date': '1955-08-24'},
#   {'character': 'Lieutenant Speer',
#    'credit_id': '52fe46fa9251416c75089d9f',
#    'poster_path': '/ffrOlm7QpfmjoMZ13qBli7cSpyi.jpg',
#    'id': 16969,
#    'video': False,
#    'vote_count': 83,
#    'adult': False,
#    'backdrop_path': '/fZskxM5vnL0UEm1zeXeYhpFUoUJ.jpg',
#    'genre_ids': [28, 35, 80, 9648],
#    'original_language': 'en',
#    'original_title': 'City Heat',
#    'popularity': 7.125,
#    'title': 'City Heat',
#    'vote_average': 5.4,
#    'overview': "Set in Kansas City in 1933, Eastwood plays a police lieutenant known simply by his last name, Speer. Reynolds plays a former cop turned private eye named Mike Murphy. Both Speer and Murphy served on the force together and were once good friends, but are now bitter enemies. When Murphy's partner is slain they team up again to fight the mob.",
#    'release_date': '1984-12-05'},
#   {'character': 'Philo Beddoe',
#    'credit_id': '52fe470c9251416c7508c23f',
#    'release_date': '1980-12-17',
#    'vote_count': 148,
#    'video': False,
#    'adult': False,
#    'vote_average': 6,
#    'title': 'Any Which Way You Can',
#    'genre_ids': [28, 12, 35],
#    'original_language': 'en',
#    'original_title': 'Any Which Way You Can',
#    'popularity': 6.943,
#    'id': 17169,
#    'backdrop_path': '/A0gP8vufy0qj4XoyDCznykKGVRu.jpg',
#    'overview': "Philo takes part in a bare knuckle fight - as he does - to make some more money than he can earn from his car repair business. He decides to retire from fighting, but when the Mafia come along and arrange another fight, he is pushed into it. A motorcycle gang and an orangutan called Clyde all add to the 'fun'.",
#    'poster_path': '/fGP1rB0MapjDyR0lCjYa6AhjQ1i.jpg'},
#   {'character': 'Ben Shockley',
#    'credit_id': '52fe47409251416c75092d79',
#    'poster_path': '/vojzvKay2QT2eGwvfGBkFfJQlcj.jpg',
#    'id': 17689,
#    'video': False,
#    'vote_count': 213,
#    'adult': False,
#    'backdrop_path': '/AqLSm9sl2Oe46XvqhoRBhKI3wXi.jpg',
#    'genre_ids': [18, 28, 80, 53],
#    'original_language': 'en',
#    'original_title': 'The Gauntlet',
#    'popularity': 7.514,
#    'title': 'The Gauntlet',
#    'vote_average': 6.6,
#    'overview': 'Phoenix cop Ben Shockley is well on his way to becoming a derelict when he is assigned to transport a witness named Gus Mally from Vegas. Mally turns out to be a belligerent prostitute with mob ties and incriminating information regarding a high-placed figure.',
#    'release_date': '1977-12-21'},
#   {'character': 'Marine (Medic)',
#    'credit_id': '52fe47dc9251416c910782f3',
#    'poster_path': '/4X4v06n9TQ8dsYe0iVDLRC4xGlQ.jpg',
#    'id': 80775,
#    'video': False,
#    'vote_count': 8,
#    'adult': False,
#    'backdrop_path': '/oFYdDj0C4kiWyeyk37ioTlp6K5X.jpg',
#    'genre_ids': [10752],
#    'original_language': 'en',
#    'original_title': 'Away All Boats',
#    'popularity': 2.359,
#    'title': 'Away All Boats',
#    'vote_average': 5.8,
#    'overview': "The story of USS 'Belinda', a U.S. naval ship, and its crew during the battle of the Pacific 1943-1945, as it prepares for action and landing troops on enemy beachheads.",
#    'release_date': '1956-08-16'},
#   {'character': 'Himself - Actor & Director',
#    'credit_id': '52fe4884c3a36847f816b735',
#    'poster_path': '/eqGCZfslyfzJgzBGG9BmJHEiLdN.jpg',
#    'id': 53943,
#    'video': False,
#    'vote_count': 1,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'Iron and Beyond',
#    'popularity': 0.662,
#    'title': 'Iron and Beyond',
#    'vote_average': 4,
#    'overview': "This short documentary explores just how the film Pumping Iron revolutionized the fitness industry and created an international icon in Arnold Schwarzenegger. It also touches on what Hollywood's idea of an action star was and is.",
#    'release_date': '2002-11-15'},
#   {'character': 'Himself',
#    'credit_id': '52fe4922c3a36847f818a84b',
#    'poster_path': '/7JFLTShP17J1bvgirSBJhQIQtFK.jpg',
#    'id': 57024,
#    'video': False,
#    'vote_count': 3,
#    'adult': False,
#    'backdrop_path': '/8hZU4FR9uQWm15wUvjKxzubOLd4.jpg',
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'Kurosawa',
#    'popularity': 1.181,
#    'title': 'Kurosawa',
#    'vote_average': 6.7,
#    'overview': 'Documentary on film maker Akira Kurosawa',
#    'release_date': '2000-12-24'},
#   {'character': 'Himself',
#    'credit_id': '52fe49699251416c750c7207',
#    'release_date': '1995-02-02',
#    'vote_count': 9,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.1,
#    'title': 'One Hundred and One Nights',
#    'genre_ids': [35, 36, 10749],
#    'original_language': 'fr',
#    'original_title': 'Les cent et une nuits de Simon Cinéma',
#    'popularity': 3.128,
#    'id': 94771,
#    'backdrop_path': '/pib01jLQZuIpDX6xdvfmX02HX0T.jpg',
#    'overview': "Monsieur Cinema, a hundred years old, lives alone in a large villa. His memories fade away, so he engages a young woman to tell him stories about all the movies ever made. Also a line of movie stars comes to visit him giving him back the pleasure of life - but amongst them there are also some young students only striving after his money for the realization of their film projects. The two stories - Monsieur Cinema's and the young people's life - are told in parallel until they come together in the end when the old man plays a role in the film made by the students.",
#    'poster_path': '/i2gWZwbXuKoS1dq8guuOgfJV5Ys.jpg'},
#   {'character': 'Gus',
#    'credit_id': '52fe49da9251416c910baefb',
#    'release_date': '2012-09-21',
#    'vote_count': 633,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.7,
#    'title': 'Trouble with the Curve',
#    'genre_ids': [18, 10749],
#    'original_language': 'en',
#    'original_title': 'Trouble with the Curve',
#    'popularity': 9.386,
#    'id': 87825,
#    'backdrop_path': '/9fN6z7JcO5o3jDmJ0fHSq4PXwUT.jpg',
#    'overview': 'Slowed by age and failing eyesight, crack baseball scout Gus Lobel takes his grown daughter along as he checks out the final prospect of his career. Along the way, the two renew their bond, and she catches the eye of a young player-turned-scout.',
#    'poster_path': '/vNWFhlTseaTupYmpnXxJLoShJe3.jpg'},
#   {'character': 'Host',
#    'credit_id': '52fe4a7fc3a36847f81d13eb',
#    'poster_path': '/ovi4614LePVS96N9GA5WiWaRczH.jpg',
#    'id': 107400,
#    'video': False,
#    'vote_count': 0,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'original_language': 'en',
#    'original_title': 'Gary Cooper: American Life, American Legend',
#    'popularity': 0.84,
#    'title': 'Gary Cooper: American Life, American Legend',
#    'vote_average': 0,
#    'overview': 'Hosted by Clint Eastwood, Hollywood Remembers: Gary Cooper -- American Life, American Legend is a biographical portrait of the life and times of movie star Gary Cooper. The 47-minute tribute chronicles the actor\'s life from his early days as an "extra" in silent pictures to his acceptance of the 1960 Academy Award for lifetime achievement in film. Cooper\'s real-life role as a cowboy and his talent as a cartoonist are discussed, as are many of the Westerns, adventures, comedies, and war films in which he starred.',
#    'release_date': '1989-11-05'},
#   {'character': 'Himself',
#    'credit_id': '52fe4affc3a368484e172119',
#    'poster_path': '/j9oVwtsAp6lNZCkEPLvnphOSorp.jpg',
#    'id': 127598,
#    'video': False,
#    'vote_count': 1,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'original_language': 'nl',
#    'original_title': 'Clint Eastwood: Director',
#    'popularity': 0.87,
#    'title': 'Clint Eastwood: Director',
#    'vote_average': 7,
#    'overview': '',
#    'release_date': '1982-01-01'},
#   {'character': 'Tom - Ranch Hand (uncredited)',
#    'credit_id': '52fe4b08c3a36847f81ee997',
#    'poster_path': '/eIKcNVflGbkcZFYwfEHo5MCudXG.jpg',
#    'id': 111942,
#    'video': False,
#    'vote_count': 9,
#    'adult': False,
#    'backdrop_path': '/3v3dgk3P5cbrvkwQFsjiho2NY2N.jpg',
#    'genre_ids': [37],
#    'original_language': 'en',
#    'original_title': 'Star in the Dust',
#    'popularity': 2.134,
#    'title': 'Star in the Dust',
#    'vote_average': 3.9,
#    'overview': "The sheriff of Gunlock is planning to hang Sam Hall, who shot three farmers found on cattle land, at sundown. At the casino, betting is 8 to 3 he won't make it. The cattlemen are set to rescue Sam; the farmers hope to lynch him before he can be rescued; and Hall schemes for escape with his girl Nellie. But Sheriff Jorden is most concerned with finding out who hired Hall: a leading suspect is the sheriff's future brother-in-law.",
#    'release_date': '1956-06-13'},
#   {'character': 'Himself',
#    'credit_id': '52fe4b0cc3a368484e174d99',
#    'poster_path': '/6e4BkMnt42OCzH5e3xOXgWVYh2v.jpg',
#    'id': 127878,
#    'video': False,
#    'vote_count': 20,
#    'adult': False,
#    'backdrop_path': '/6K7qzg1BsmqW87K6NmCXmxNE0nJ.jpg',
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'Casting By',
#    'popularity': 3.236,
#    'title': 'Casting By',
#    'vote_average': 7.5,
#    'overview': 'This essential new documentary pays tribute to the legacy of the late, legendary casting director Marion Dougherty and shines a light on one of the most overlooked and least understood crafts in filmmaking.',
#    'release_date': '2012-10-12'},
#   {'character': 'Keith Williams',
#    'credit_id': '52fe4b1dc3a36847f81f3285',
#    'poster_path': '/kqLS5Kg21UjG3TOYxLvghlrwpDX.jpg',
#    'id': 112672,
#    'video': False,
#    'vote_count': 5,
#    'adult': False,
#    'backdrop_path': '/tnMjBlSgsRzfHM9wfO4vfn0whn8.jpg',
#    'genre_ids': [28, 10752, 37],
#    'original_language': 'en',
#    'original_title': 'Ambush at Cimarron Pass',
#    'popularity': 1.294,
#    'title': 'Ambush at Cimarron Pass',
#    'vote_average': 4.8,
#    'overview': 'A small Army patrol unit and a couple of former Confederates reluctantly throw in their lot together after being attacked by a band of Native Americans.',
#    'release_date': '1958-03-01'},
#   {'character': 'George Moseley',
#    'credit_id': '52fe4b50c3a368484e182fdb',
#    'poster_path': '/AvKlvYWJPw431fMPzNPqApYD7lO.jpg',
#    'id': 130134,
#    'video': False,
#    'vote_count': 3,
#    'adult': False,
#    'backdrop_path': '/vNaNZ9t1AqRW683zUJgC0jTxs0a.jpg',
#    'genre_ids': [10752, 18, 10749],
#    'original_language': 'en',
#    'original_title': 'Lafayette Escadrille',
#    'popularity': 0.948,
#    'title': 'Lafayette Escadrille',
#    'vote_average': 4.7,
#    'overview': 'A hotshot young flyer falls for a French sex worker during World War I.',
#    'release_date': '1958-03-01'},
#   {'character': 'Himself',
#    'credit_id': '52fe4b739251416c910dad2b',
#    'poster_path': '/i4X3XDdx1vxEibj3nvZprDi9Qji.jpg',
#    'id': 155060,
#    'video': False,
#    'vote_count': 4,
#    'adult': False,
#    'backdrop_path': '/1Bj7cBk57LfhBGs5hE0eXO0mpIp.jpg',
#    'genre_ids': [99, 18],
#    'original_language': 'en',
#    'original_title': 'The Eastwood Factor',
#    'popularity': 1.147,
#    'title': 'The Eastwood Factor',
#    'vote_average': 5,
# ...
#    'vote_count': 7946,
#    'video': False,
#    'poster_path': '/svPHnYE7N5NAGO49dBmRhq0vDQ3.jpg',
#    'backdrop_path': '/oJNu8vS6Wf10Cv2996KO65jt4C0.jpg',
#    'title': 'American Sniper',
#    'popularity': 13.813,
#    'genre_ids': [28, 10752],
#    'vote_average': 7.4,
#    'adult': False,
#    'release_date': '2014-12-25',
#    'credit_id': '54b657ad9251416780001363'},
#   {'id': 363676,
#    'department': 'Directing',
#    'original_language': 'en',
#    'original_title': 'Sully',
#    'job': 'Director',
#    'overview': "On 15 January 2009, the world witnessed the 'Miracle on the Hudson' when Captain 'Sully' Sullenberger glided his disabled plane onto the frigid waters of the Hudson River, saving the lives of all 155 aboard. However, even as Sully was being heralded by the public and the media for his unprecedented feat of aviation skill, an investigation was unfolding that threatened to destroy his reputation and career.",
#    'vote_count': 4092,
#    'video': False,
#    'release_date': '2016-09-09',
#    'vote_average': 7.1,
#    'title': 'Sully',
#    'popularity': 13.448,
#    'genre_ids': [18, 36],
#    'backdrop_path': '/vC9H1ZVdXi1KjH4aPfGB54mvDNh.jpg',
#    'adult': False,
#    'poster_path': '/h6O5OE3ueRVdCc7V7cwTiQocI7D.jpg',
#    'credit_id': '561c20b9c3a368225300205a'},
#   {'id': 363676,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Sully',
#    'job': 'Producer',
#    'overview': "On 15 January 2009, the world witnessed the 'Miracle on the Hudson' when Captain 'Sully' Sullenberger glided his disabled plane onto the frigid waters of the Hudson River, saving the lives of all 155 aboard. However, even as Sully was being heralded by the public and the media for his unprecedented feat of aviation skill, an investigation was unfolding that threatened to destroy his reputation and career.",
#    'vote_count': 4092,
#    'video': False,
#    'release_date': '2016-09-09',
#    'vote_average': 7.1,
#    'title': 'Sully',
#    'popularity': 13.448,
#    'genre_ids': [18, 36],
#    'backdrop_path': '/vC9H1ZVdXi1KjH4aPfGB54mvDNh.jpg',
#    'adult': False,
#    'poster_path': '/h6O5OE3ueRVdCc7V7cwTiQocI7D.jpg',
#    'credit_id': '5775cf8bc3a36808fd001d6e'},
#   {'id': 3580,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Changeling',
#    'job': 'Producer',
#    'overview': "Christine Collins is overjoyed when her kidnapped son is brought back home. But when Christine suspects that the boy returned to her isn't her child, the police captain has her committed to an asylum.",
#    'vote_count': 2199,
#    'video': False,
#    'release_date': '2008-05-20',
#    'vote_average': 7.5,
#    'title': 'Changeling',
#    'popularity': 7.592,
#    'genre_ids': [80, 18, 9648],
#    'backdrop_path': '/t4DO37tO3mhMX4DCdnI1EPsRi26.jpg',
#    'adult': False,
#    'poster_path': '/qtte2n6ygA1zVG5kLrjUGui28TJ.jpg',
#    'credit_id': '56cc9d03c3a3683b07000252'},
#   {'id': 984,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Dirty Harry',
#    'job': 'Executive Producer',
#    'overview': "When a madman dubbed 'Scorpio' terrorizes San Francisco, hard-nosed cop, Harry Callahan – famous for his take-no-prisoners approach to law enforcement – is tasked with hunting down the psychopath. Harry eventually collars Scorpio in the process of rescuing a kidnap victim, only to see him walk on technicalities. Now, the maverick detective is determined to nail the maniac himself.",
#    'vote_count': 1093,
#    'video': False,
#    'release_date': '1971-12-22',
#    'vote_average': 7.5,
#    'title': 'Dirty Harry',
#    'popularity': 13.525,
#    'genre_ids': [28, 80, 53],
#    'backdrop_path': '/t3OZS8yMs0NL4YgWWc04eXHTn1X.jpg',
#    'adult': False,
#    'poster_path': '/4j2tBAusIVev4ZaScncIHknP7eV.jpg',
#    'credit_id': '57681ad19251417d13000750'},
#   {'id': 409776,
#    'department': 'Directing',
#    'original_language': 'en',
#    'original_title': 'The Blues',
#    'job': 'Director',
#    'overview': 'A documentary series about the origin and history of The Blues.',
#    'vote_count': 5,
#    'video': False,
#    'poster_path': '/etnCkaamuE4WmdPlkXZv0iSJEqH.jpg',
#    'backdrop_path': None,
#    'title': 'The Blues',
#    'popularity': 0.772,
#    'genre_ids': [],
#    'vote_average': 9.2,
#    'adult': False,
#    'release_date': '2003-01-01',
#    'credit_id': '57b88ae0c3a3686476000f01'},
#   {'id': 209451,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Jersey Boys',
#    'job': 'Producer',
#    'overview': 'From director Clint Eastwood comes the big-screen version of the Tony Award-winning musical Jersey Boys. The film tells the story of four young men from the wrong side of the tracks in New Jersey who came together to form the iconic 1960s rock group The Four Seasons. The story of their trials and triumphs are accompanied by the songs that influenced a generation, including “Sherry,” “Big Girls Don’t Cry,” “Walk Like a Man,” “Rag Doll,” and many more.',
#    'vote_count': 389,
#    'video': False,
#    'release_date': '2014-06-20',
#    'vote_average': 6.9,
#    'title': 'Jersey Boys',
#    'popularity': 6.868,
#    'genre_ids': [10402, 18],
#    'backdrop_path': '/zLYEkkGA5jY8eJ6Nrdf9c8hYvbs.jpg',
#    'adult': False,
#    'poster_path': '/eauqByydTE8zx74Hd4CSE5mCw3u.jpg',
#    'credit_id': '582890edc3a368623f00694a'},
#   {'id': 453201,
#    'department': 'Directing',
#    'original_language': 'en',
#    'original_title': 'The 15:17 to Paris',
#    'job': 'Director',
#    'overview': 'In August 2015, an ISIS terrorist boarded train #9364 from Brussels to Paris. Armed with an AK-47 and enough ammo to kill more than 500 people, the terrorist might have succeeded except for three American friends who refused to give in to fear. One was a college student, one was a martial arts enthusiast and airman first class in the U.S. Air Force, and the other was a member of the Oregon National Guard, and all three pals proved fearless as they charged and ultimately overpowered the gunman after he emerged from a bathroom armed and ready to kill.',
#    'vote_count': 857,
#    'video': False,
#    'poster_path': '/qxJQ0VBCuJkJhJmuWzxI408ngwd.jpg',
#    'backdrop_path': '/gkkBhctHPGg8hrmtWbO3ySZoj4z.jpg',
#    'title': 'The 15:17 to Paris',
#    'popularity': 9.691,
#    'genre_ids': [18, 36, 53],
#    'vote_average': 5.3,
#    'adult': False,
#    'release_date': '2018-02-09',
#    'credit_id': '58f90e7592514106e200016e'},
#   {'id': 453201,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'The 15:17 to Paris',
#    'job': 'Producer',
#    'overview': 'In August 2015, an ISIS terrorist boarded train #9364 from Brussels to Paris. Armed with an AK-47 and enough ammo to kill more than 500 people, the terrorist might have succeeded except for three American friends who refused to give in to fear. One was a college student, one was a martial arts enthusiast and airman first class in the U.S. Air Force, and the other was a member of the Oregon National Guard, and all three pals proved fearless as they charged and ultimately overpowered the gunman after he emerged from a bathroom armed and ready to kill.',
#    'vote_count': 857,
#    'video': False,
#    'poster_path': '/qxJQ0VBCuJkJhJmuWzxI408ngwd.jpg',
#    'backdrop_path': '/gkkBhctHPGg8hrmtWbO3ySZoj4z.jpg',
#    'title': 'The 15:17 to Paris',
#    'popularity': 9.691,
#    'genre_ids': [18, 36, 53],
#    'vote_average': 5.3,
#    'adult': False,
#    'release_date': '2018-02-09',
#    'credit_id': '58fa60dac3a36879f40007ef'},
#   {'id': 504172,
#    'department': 'Directing',
#    'original_language': 'en',
#    'original_title': 'The Mule',
#    'job': 'Director',
#    'overview': 'Earl Stone, a man in his 80s, is broke, alone, and facing foreclosure of his business when he is offered a job that simply requires him to drive. Easy enough, but, unbeknownst to Earl, he’s just signed on as a drug courier for a Mexican cartel. He does so well that his cargo increases exponentially, and Earl hit the radar of hard-charging DEA agent Colin Bates.',
#    'vote_count': 1968,
#    'video': False,
#    'poster_path': '/klazQbxk3yfuZ8JcfO9jdKOZQJ7.jpg',
#    'backdrop_path': '/yuLfnOmCkez8pnyzoFebQSaGwel.jpg',
#    'title': 'The Mule',
#    'popularity': 23.568,
#    'genre_ids': [80, 18, 53],
#    'vote_average': 6.6,
#    'adult': False,
#    'release_date': '2018-12-14',
#    'credit_id': '5a7e419192514140f8000f34'},
#   {'id': 504172,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'The Mule',
#    'job': 'Producer',
#    'overview': 'Earl Stone, a man in his 80s, is broke, alone, and facing foreclosure of his business when he is offered a job that simply requires him to drive. Easy enough, but, unbeknownst to Earl, he’s just signed on as a drug courier for a Mexican cartel. He does so well that his cargo increases exponentially, and Earl hit the radar of hard-charging DEA agent Colin Bates.',
#    'vote_count': 1968,
#    'video': False,
#    'poster_path': '/klazQbxk3yfuZ8JcfO9jdKOZQJ7.jpg',
#    'backdrop_path': '/yuLfnOmCkez8pnyzoFebQSaGwel.jpg',
#    'title': 'The Mule',
#    'popularity': 23.568,
#    'genre_ids': [80, 18, 53],
#    'vote_average': 6.6,
#    'adult': False,
#    'release_date': '2018-12-14',
#    'credit_id': '5a7e419d0e0a262aac001013'},
#   {'id': 471616,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Indian Horse',
#    'job': 'Executive Producer',
#    'overview': 'Saul is a great native hockey player who overcomes racism in the 1970s then ultimately becomes tempted by alcoholism.',
#    'vote_count': 17,
#    'video': False,
#    'release_date': '2018-04-13',
#    'vote_average': 7.6,
#    'title': 'Indian Horse',
#    'popularity': 2.06,
#    'genre_ids': [18],
#    'backdrop_path': '/qk6LK4bYLvZj4E6eKy5GRLgGN3a.jpg',
#    'adult': False,
#    'poster_path': '/6PRmK9svHolvZ2CLNoBkmViYlrB.jpg',
#    'credit_id': '5aa3a70c0e0a26075700974a'},
#   {'id': 139408,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'The Stars Fell on Henrietta',
#    'job': 'Producer',
#    'overview': "The setting is early America during the oil boom. An elderly, down on his luck 'oil man', Mr. Cox finds himself in the town of Henrietta. Using unconventional methods, he convinces himself and local Don Day that there is oil on Day's land. The financially strapped Day puts everything into finding oil...but at what cost?",
#    'vote_count': 9,
#    'video': False,
#    'release_date': '1995-09-15',
#    'vote_average': 6.5,
#    'title': 'The Stars Fell on Henrietta',
#    'popularity': 1.517,
#    'genre_ids': [18],
#    'backdrop_path': '/iu6NBeV8TABfvT4jUrvjnCLO9am.jpg',
#    'adult': False,
#    'poster_path': '/5mkH38tcztyLy6CeAWHD1FC8ozC.jpg',
#    'credit_id': '5ad51092c3a3680c16007b24'},
#   {'id': 28761,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'White Hunter, Black Heart',
#    'job': 'Producer',
#    'overview': 'A thinly fictionalized account of a legendary movie director, whose desire to hunt down an animal turns into a grim situation with his movie crew in Africa',
#    'vote_count': 99,
#    'video': False,
#    'release_date': '1990-09-14',
#    'vote_average': 6.5,
#    'title': 'White Hunter, Black Heart',
#    'popularity': 7.722,
#    'genre_ids': [28, 12, 18],
#    'backdrop_path': '/lUtyGLrWzS6edEi0oDXr6yMdGJ4.jpg',
#    'adult': False,
#    'poster_path': '/6nGnHhGyaAfhkSH39gBHlFj3O4q.jpg',
#    'credit_id': '5add04eb0e0a2608d8000396'},
#   {'id': 462540,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Dave Brubeck: In His Own Sweet Way',
#    'job': 'Executive Producer',
#    'overview': "A chronological look at the life and career of jazz musician, composer, and performer Dave Brubeck (1920-2012 ), presented through contemporary interviews, archival footage of interviews and performances, and commentary by family, fellow musicians, and aficionados. Emphases include his mother's influence, his wife's invention of college tours, his skill as an accompanist, the great quartet (with Desmond, Morello, and Wright), his ability to find musical ideas everywhere, his orchestral compositions, his religious conversion, and his unflagging sweet nature.",
#    'vote_count': 0,
#    'video': False,
#    'release_date': '2010-12-06',
#    'vote_average': 0,
#    'title': 'Dave Brubeck: In His Own Sweet Way',
#    'popularity': 0.6,
#    'genre_ids': [10402, 99],
#    'backdrop_path': None,
#    'adult': False,
#    'poster_path': '/brAcAQOzfb3apBStzpIUtklC1if.jpg',
#    'credit_id': '5ade0834c3a36876fa00042a'},
#   {'id': 524469,
#    'department': 'Directing',
#    'original_language': 'en',
#    'original_title': 'The Beguiled: The Storyteller',
#    'job': 'Director',
#    'overview': 'The Beguiled: The Storyteller is the first documentary short ever directed by Clint Eastwood. Shot in Baton Rouge, Louisiana, under the Malpaso Production Company, it has a running time of 12 minutes and provides a behind-the-scenes look at the making of the 1971 film, The Beguiled. Eastwood highlights each of the primary actors including himself as well as director Don Siegel.',
#    'vote_count': 1,
#    'video': False,
#    'release_date': '1971-05-19',
#    'vote_average': 7,
#    'title': 'The Beguiled: The Storyteller',
#    'popularity': 0.6,
#    'genre_ids': [99],
#    'backdrop_path': None,
#    'adult': False,
#    'poster_path': '/Aa3LcSib4WJdwMfFxSTi9zsEtLf.jpg',
#    'credit_id': '5afbc87b0e0a2634600036da'},
#   {'id': 41973,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Thelonious Monk: Straight, No Chaser',
#    'job': 'Executive Producer',
#    'overview': 'A documentary film about the life of pianist and jazz great Thelonious Monk. Features live performances by Monk and his band, and interviews with friends and family about the offbeat genius.',
#    'vote_count': 7,
#    'video': False,
#    'release_date': '1988-10-25',
#    'vote_average': 6.7,
#    'title': 'Thelonious Monk: Straight, No Chaser',
#    'popularity': 1.986,
#    'genre_ids': [99, 10402],
#    'backdrop_path': '/jnDQHDx0hS3fbm4HJdlgRdeuoLE.jpg',
#    'adult': False,
#    'poster_path': '/ox9zReWOB6sucmE4KtuhudEjjCq.jpg',
#    'credit_id': '5b93ae2a92514143240069e3'},
#   {'id': 44603,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Hereafter',
#    'job': 'Producer',
#    'overview': 'Three people — a blue-collar American, a French journalist and a London school boy — are touched by death in different ways.',
#    'vote_count': 886,
#    'video': False,
#    'release_date': '2010-10-22',
#    'vote_average': 6,
#    'title': 'Hereafter',
#    'popularity': 10.357,
#    'genre_ids': [18, 14],
#    'backdrop_path': '/hqoT9VmekkuQ9vQFPjJOzLPdPfb.jpg',
#    'adult': False,
#    'poster_path': '/iyC8fKWncwX2d06NwUz5qbf2P1.jpg',
#    'credit_id': '5bce355b0e0a265d39005747'},
#   {'id': 44603,
#    'department': 'Sound',
#    'original_language': 'en',
#    'original_title': 'Hereafter',
#    'job': 'Music',
#    'overview': 'Three people — a blue-collar American, a French journalist and a London school boy — are touched by death in different ways.',
#    'vote_count': 886,
#    'video': False,
#    'release_date': '2010-10-22',
#    'vote_average': 6,
#    'title': 'Hereafter',
#    'popularity': 10.357,
#    'genre_ids': [18, 14],
#    'backdrop_path': '/hqoT9VmekkuQ9vQFPjJOzLPdPfb.jpg',
#    'adult': False,
#    'poster_path': '/iyC8fKWncwX2d06NwUz5qbf2P1.jpg',
#    'credit_id': '5bce35b10e0a265d2d00584d'},
#   {'id': 292011,
#    'department': 'Directing',
#    'original_language': 'en',
#    'original_title': 'Richard Jewell',
#    'job': 'Director',
#    'overview': 'The true story of Richard Jewell, hero and then suspect of the 1996 Olympic Park bombing.',
#    'vote_count': 0,
#    'video': False,
#    'release_date': '2019-12-31',
#    'vote_average': 0,
#    'title': 'Richard Jewell',
#    'popularity': 0.776,
#    'genre_ids': [18],
#    'backdrop_path': None,
#    'adult': False,
#    'poster_path': None,
#    'credit_id': '5cb8f3620e0a261a55ebefd6'}],
#  'id': 190}

# %%
num_of_credits = len(response_actor_id['cast'][:])
num_of_credits   #how many movies
# Out:
# 112

# %%
#Put all records in actor's first part of Data Frame (ie. hoffman_df)
labels = ['title','popularity','vote_average','vote_count']
idx = [film['id'] for film in response_actor_id['cast'][:]]
records = []
for film in (response_actor_id['cast'][:]):
    record = [film['title'], film['popularity'], film['vote_average'], film['vote_count']]
    records.append(record)

actor_df = pd.DataFrame.from_records(records, columns=labels, index=idx)
actor_df
# Out:
#                                                     title  popularity  \
# 33                                             Unforgiven      16.755
# 66                                         Absolute Power      10.509
# 70                                    Million Dollar Baby      14.475
# 391                                  A Fistful of Dollars      12.797
# 429                        The Good, the Bad and the Ugly      19.808
# 688                         The Bridges of Madison County      10.029
# 938                                For a Few Dollars More      13.634
# 984                                           Dirty Harry      13.525
# 10015                                    Heartbreak Ridge       9.107
# 10354                                          True Crime       9.027
# 10648                                        Magnum Force      11.352
# 10649                                        The Enforcer       8.791
# 10650                                       Sudden Impact       9.596
# 10651                                       The Dead Pool      11.649
# 10724                                             Firefox       8.167
# 10734                                Escape from Alcatraz      15.775
# 10747                              The Outlaw Josey Wales      12.278
# 20006                                       Pink Cadillac       8.656
# 20187                                  The Eiger Sanction       8.638
# 4929                                        Hang 'em High      10.355
# 20391                                    Paint Your Wagon       6.157
# 11046                                   Where Eagles Dare      12.938
# 5551                                        Space Cowboys       8.672
# 21866                                        Bronco Billy       8.013
# 11589                                      Kelly's Heroes      11.207
# 6723                                           The Rookie       9.386
# 11707                                           Tightrope      10.116
# 11901                                 High Plains Drifter      10.727
# 11916                           Two Mules for Sister Sara      11.213
# 8348                            Thunderbolt and Lightfoot       5.841
# ...                                                   ...         ...
# 377801                    Clint Eastwood, le franc-tireur       0.873
# 187534                      The First Traveling Saleslady       1.693
# 324314                            Tab Hunter Confidential       1.626
# 396462                                Jean Seberg Forever       1.097
# 55676   A Personal Journey with Martin Scorsese Throug...       3.184
# 94623                               Directed by John Ford       1.772
# 38868                        A Decade Under the Influence       2.493
# 343835      Sammy Davis, Jr. 60th Anniversary Celebration       0.767
# 187533                                  Never Say Goodbye       1.371
# 447454                     James Stewart's Wonderful Life       0.631
# 274061                   Johnny Mercer: The Dream's on Me       0.918
# 383934    Denn sie kennen kein Erbarmen: Der Italowestern       1.100
# 167688                           The Unbeatable Bruce Lee       1.121
# 504172                                           The Mule      23.568
# 462486                               Anything Is Possible       0.600
# 247525                    Happy 100th Birthday, Hollywood       0.600
# 190859                                    American Sniper      13.813
# 47975                                  The Spaghetti West       0.949
# 524469                      The Beguiled: The Storyteller       0.600
# 525362                            The Blues - Piano Blues       0.600
# 471208                                 Cannes: All Access       0.600
# 508466                                 Sad Hill Unearthed       2.014
# 558595                              Clint Eastwood's West       0.861
# 569055             Sergio Leone - Une Amérique de légende       0.600
# 574837  An Old Fashioned Love Story: Making 'The Bridg...       0.600
# 585937                                       Leone's West       0.628
# 112857                                        Piano Blues       0.987
# 599031                                  Forever Hollywood       1.199
# 616839  Play It Again: A Look Back at 'Play Misty for Me'       0.600
# 253639                           And the Oscar Goes To...       2.953
#
#         vote_average  vote_count
# 33               7.9        2028
# 66               6.6         424
# 70               7.9        5082
# 391              7.9        1942
# 429              8.4        4270
# 688              7.6         828
# 938              8.0        1873
# 984              7.5        1093
# 10015            6.7         444
# 10354            6.5         283
# 10648            7.2         449
# 10649            6.8         387
# 10650            6.6         381
# 10651            6.4         360
# 10724            6.1         237
# 10734            7.5        1238
# 10747            7.5         507
# 20006            5.4          83
# 20187            6.2         156
# 4929             6.8         347
# 20391            6.4         104
# 11046            7.6         403
# 5551             6.3         689
# 21866            6.1          92
# 11589            7.4         316
# 6723             5.8         243
# 11707            6.1         148
# 11901            7.5         495
# 11916            6.9         254
# 8348             6.8         202
# ...              ...         ...
# 377801          10.0           1
# 187534           5.2           5
# 324314           7.7          27
# 396462           0.0           0
# 55676            8.2          48
# 94623            6.8           9
# 38868            7.8          17
# 343835           9.3           3
# 187533           6.7           6
# 447454           0.0           0
# 274061          10.0           1
# 383934           0.0           0
# 167688           9.5           1
# 504172           6.6        1968
# 462486           0.0           0
# 247525           0.0           0
# 190859           7.4        7946
# 47975            6.5           2
# 524469           7.0           1
# 525362           7.3           3
# 471208           2.0           1
# 508466           7.2          27
# 558595           0.0           0
# 569055           0.0           0
# 574837           0.0           0
# 585937           0.0           0
# 112857           6.9           4
# 599031          10.0           1
# 616839           0.0           0
# 253639           7.0          23
#
# [112 rows x 4 columns]

# %%
#Now get 2nd part of actor's df from the tmdb.Movies for merging
labels = ['revenue','budget','profit','genres']
film_indices = [film[0] for film in actor_df.iterrows()]
#print(film_indices)
records = []
request_rate_limit = 40     #TMDB has rate limit of 40 requests per 10 seconds

for film_idx in film_indices:
    request_rate_limit -= 1
    if request_rate_limit == 0:            
        print("Hold yer horses, cowboy!")
        print("...wait per request limit...")
        time.sleep(10)
        request_rate_limit = 39
    movie = tmdb.Movies(film_idx)  #Each movie has unique identifier stored as index of df
    response = movie.info()
        
    profit = response['revenue'] - response['budget']
    record = [response['revenue'], response['budget'], profit, response['genres']]    
    records.append(record)

actor_movies_df = pd.DataFrame.from_records(records, columns=labels, index=film_indices)
actor_movies_df
# Out:
# Hold yer horses, cowboy!
# ...wait per request limit...
# Hold yer horses, cowboy!
# ...wait per request limit...
#           revenue    budget     profit  \
# 33      159157447  14000000  145157447
# 66       50068310  50000000      68310
# 70      216763646  30000000  186763646
# 391      14500000    200000   14300000
# 429      25100000   1200000   23900000
# 688     182016617  24000000  158016617
# 938      15000000    600000   14400000
# 984      35976000  10000000   25976000
# 10015    42724017  15000000   27724017
# 10354           0         0          0
# 10648    39768000         0   39768000
# 10649    46236000   9000000   37236000
# 10650    67642693  22000000   45642693
# 10651           0  20000000  -20000000
# 10724    70687344  18000000   52687344
# 10734    43000000   8000000   35000000
# 10747    31800000   3700000   28100000
# 20006           0         0          0
# 20187    14200000         0   14200000
# 4929      6800000   1800000    5000000
# 20391    31678778  20000000   11678778
# 11046    21000000   7700000   13300000
# 5551    128884132  65000000   63884132
# 21866           0         0          0
# 11589     5200000   4000000    1200000
# 6723     21633874  10000000   11633874
# 11707    48143579         0   48143579
# 11901    15700000   5500000   10200000
# 11916     5050000         0    5050000
# 8348     21700000         0   21700000
# ...           ...       ...        ...
# 377801          0         0          0
# 187534          0         0          0
# 324314          0         0          0
# 396462          0         0          0
# 55676           0         0          0
# 94623           0         0          0
# 38868           0         0          0
# 343835          0         0          0
# 187533          0         0          0
# 447454          0         0          0
# 274061          0         0          0
# 383934          0         0          0
# 167688          0         0          0
# 504172  171304407  50000000  121304407
# 462486          0         0          0
# 247525          0         0          0
# 190859  542307423  58800000  483507423
# 47975           0         0          0
# 524469          0         0          0
# 525362          0         0          0
# 471208          0         0          0
# 508466      22834    170000    -147166
# 558595          0         0          0
# 569055          0         0          0
# 574837          0         0          0
# 585937          0         0          0
# 112857          0         0          0
# 599031          0         0          0
# 616839          0         0          0
# 253639          0         0          0
#
#                                                    genres
# 33                        [{'id': 37, 'name': 'Western'}]
# 66      [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 70                          [{'id': 18, 'name': 'Drama'}]
# 391                       [{'id': 37, 'name': 'Western'}]
# 429                       [{'id': 37, 'name': 'Western'}]
# 688     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 938                       [{'id': 37, 'name': 'Western'}]
# 984     [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 10015   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 10354   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 10648   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 10649   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 10650                       [{'id': 80, 'name': 'Crime'}]
# 10651   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 10724   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 10734   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 10747                     [{'id': 37, 'name': 'Western'}]
# 20006   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 20187   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4929                      [{'id': 37, 'name': 'Western'}]
# 20391   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 11046   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 5551    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 21866   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 11589   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 6723    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 11707   [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...
# 11901                     [{'id': 37, 'name': 'Western'}]
# 11916                     [{'id': 37, 'name': 'Western'}]
# 8348    [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# ...                                                   ...
# 377801                                                 []
# 187534  [{'id': 35, 'name': 'Comedy'}, {'id': 37, 'nam...
# 324314                [{'id': 99, 'name': 'Documentary'}]
# 396462                [{'id': 99, 'name': 'Documentary'}]
# 55676                 [{'id': 99, 'name': 'Documentary'}]
# 94623                 [{'id': 99, 'name': 'Documentary'}]
# 38868   [{'id': 35, 'name': 'Comedy'}, {'id': 99, 'nam...
# 343835  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 187533                                                 []
# 447454                [{'id': 99, 'name': 'Documentary'}]
# 274061                [{'id': 99, 'name': 'Documentary'}]
# 383934  [{'id': 37, 'name': 'Western'}, {'id': 99, 'na...
# 167688                [{'id': 99, 'name': 'Documentary'}]
# 504172  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 462486                [{'id': 99, 'name': 'Documentary'}]
# 247525                  [{'id': 10751, 'name': 'Family'}]
# 190859  [{'id': 10752, 'name': 'War'}, {'id': 28, 'nam...
# 47975                 [{'id': 99, 'name': 'Documentary'}]
# 524469                [{'id': 99, 'name': 'Documentary'}]
# 525362  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
# 471208                [{'id': 99, 'name': 'Documentary'}]
# 508466                [{'id': 99, 'name': 'Documentary'}]
# 558595                [{'id': 99, 'name': 'Documentary'}]
# 569055                [{'id': 99, 'name': 'Documentary'}]
# 574837                [{'id': 99, 'name': 'Documentary'}]
# 585937                                                 []
# 112857  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
# 599031                [{'id': 99, 'name': 'Documentary'}]
# 616839                [{'id': 99, 'name': 'Documentary'}]
# 253639  [{'id': 99, 'name': 'Documentary'}, {'id': 107...
#
# [112 rows x 4 columns]

# %%
print(actor_df.shape)
actor_df.head(5)
# Out:
# (112, 4)
#                               title  popularity  vote_average  vote_count
# 33                       Unforgiven      16.755           7.9        2028
# 66                   Absolute Power      10.509           6.6         424
# 70              Million Dollar Baby      14.475           7.9        5082
# 391            A Fistful of Dollars      12.797           7.9        1942
# 429  The Good, the Bad and the Ugly      19.808           8.4        4270

# %%
print(actor_movies_df.shape)
actor_movies_df.head(5)
# Out:
# (112, 4)
#        revenue    budget     profit  \
# 33   159157447  14000000  145157447
# 66    50068310  50000000      68310
# 70   216763646  30000000  186763646
# 391   14500000    200000   14300000
# 429   25100000   1200000   23900000
#
#                                                 genres
# 33                     [{'id': 37, 'name': 'Western'}]
# 66   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 70                       [{'id': 18, 'name': 'Drama'}]
# 391                    [{'id': 37, 'name': 'Western'}]
# 429                    [{'id': 37, 'name': 'Western'}]

# %%
# This builds the full df, still need to build final
actor_full_df = pd.merge(actor_df, actor_movies_df, left_index=True, right_index=True)
print(actor_full_df.shape)
actor_full_df
# Out:
# (112, 8)
#                                                     title  popularity  \
# 33                                             Unforgiven      16.755
# 66                                         Absolute Power      10.509
# 70                                    Million Dollar Baby      14.475
# 391                                  A Fistful of Dollars      12.797
# 429                        The Good, the Bad and the Ugly      19.808
# 688                         The Bridges of Madison County      10.029
# 938                                For a Few Dollars More      13.634
# 984                                           Dirty Harry      13.525
# 10015                                    Heartbreak Ridge       9.107
# 10354                                          True Crime       9.027
# 10648                                        Magnum Force      11.352
# 10649                                        The Enforcer       8.791
# 10650                                       Sudden Impact       9.596
# 10651                                       The Dead Pool      11.649
# 10724                                             Firefox       8.167
# 10734                                Escape from Alcatraz      15.775
# 10747                              The Outlaw Josey Wales      12.278
# 20006                                       Pink Cadillac       8.656
# 20187                                  The Eiger Sanction       8.638
# 4929                                        Hang 'em High      10.355
# 20391                                    Paint Your Wagon       6.157
# 11046                                   Where Eagles Dare      12.938
# 5551                                        Space Cowboys       8.672
# 21866                                        Bronco Billy       8.013
# 11589                                      Kelly's Heroes      11.207
# 6723                                           The Rookie       9.386
# 11707                                           Tightrope      10.116
# 11901                                 High Plains Drifter      10.727
# 11916                           Two Mules for Sister Sara      11.213
# 8348                            Thunderbolt and Lightfoot       5.841
# ...                                                   ...         ...
# 377801                    Clint Eastwood, le franc-tireur       0.873
# 187534                      The First Traveling Saleslady       1.693
# 324314                            Tab Hunter Confidential       1.626
# 396462                                Jean Seberg Forever       1.097
# 55676   A Personal Journey with Martin Scorsese Throug...       3.184
# 94623                               Directed by John Ford       1.772
# 38868                        A Decade Under the Influence       2.493
# 343835      Sammy Davis, Jr. 60th Anniversary Celebration       0.767
# 187533                                  Never Say Goodbye       1.371
# 447454                     James Stewart's Wonderful Life       0.631
# 274061                   Johnny Mercer: The Dream's on Me       0.918
# 383934    Denn sie kennen kein Erbarmen: Der Italowestern       1.100
# 167688                           The Unbeatable Bruce Lee       1.121
# 504172                                           The Mule      23.568
# 462486                               Anything Is Possible       0.600
# 247525                    Happy 100th Birthday, Hollywood       0.600
# 190859                                    American Sniper      13.813
# 47975                                  The Spaghetti West       0.949
# 524469                      The Beguiled: The Storyteller       0.600
# 525362                            The Blues - Piano Blues       0.600
# 471208                                 Cannes: All Access       0.600
# 508466                                 Sad Hill Unearthed       2.014
# 558595                              Clint Eastwood's West       0.861
# 569055             Sergio Leone - Une Amérique de légende       0.600
# 574837  An Old Fashioned Love Story: Making 'The Bridg...       0.600
# 585937                                       Leone's West       0.628
# 112857                                        Piano Blues       0.987
# 599031                                  Forever Hollywood       1.199
# 616839  Play It Again: A Look Back at 'Play Misty for Me'       0.600
# 253639                           And the Oscar Goes To...       2.953
#
#         vote_average  vote_count    revenue    budget     profit  \
# 33               7.9        2028  159157447  14000000  145157447
# 66               6.6         424   50068310  50000000      68310
# 70               7.9        5082  216763646  30000000  186763646
# 391              7.9        1942   14500000    200000   14300000
# 429              8.4        4270   25100000   1200000   23900000
# 688              7.6         828  182016617  24000000  158016617
# 938              8.0        1873   15000000    600000   14400000
# 984              7.5        1093   35976000  10000000   25976000
# 10015            6.7         444   42724017  15000000   27724017
# 10354            6.5         283          0         0          0
# 10648            7.2         449   39768000         0   39768000
# 10649            6.8         387   46236000   9000000   37236000
# 10650            6.6         381   67642693  22000000   45642693
# 10651            6.4         360          0  20000000  -20000000
# 10724            6.1         237   70687344  18000000   52687344
# 10734            7.5        1238   43000000   8000000   35000000
# 10747            7.5         507   31800000   3700000   28100000
# 20006            5.4          83          0         0          0
# 20187            6.2         156   14200000         0   14200000
# 4929             6.8         347    6800000   1800000    5000000
# 20391            6.4         104   31678778  20000000   11678778
# 11046            7.6         403   21000000   7700000   13300000
# 5551             6.3         689  128884132  65000000   63884132
# 21866            6.1          92          0         0          0
# 11589            7.4         316    5200000   4000000    1200000
# 6723             5.8         243   21633874  10000000   11633874
# 11707            6.1         148   48143579         0   48143579
# 11901            7.5         495   15700000   5500000   10200000
# 11916            6.9         254    5050000         0    5050000
# 8348             6.8         202   21700000         0   21700000
# ...              ...         ...        ...       ...        ...
# 377801          10.0           1          0         0          0
# 187534           5.2           5          0         0          0
# 324314           7.7          27          0         0          0
# 396462           0.0           0          0         0          0
# 55676            8.2          48          0         0          0
# 94623            6.8           9          0         0          0
# 38868            7.8          17          0         0          0
# 343835           9.3           3          0         0          0
# 187533           6.7           6          0         0          0
# 447454           0.0           0          0         0          0
# 274061          10.0           1          0         0          0
# 383934           0.0           0          0         0          0
# 167688           9.5           1          0         0          0
# 504172           6.6        1968  171304407  50000000  121304407
# 462486           0.0           0          0         0          0
# 247525           0.0           0          0         0          0
# 190859           7.4        7946  542307423  58800000  483507423
# 47975            6.5           2          0         0          0
# 524469           7.0           1          0         0          0
# 525362           7.3           3          0         0          0
# 471208           2.0           1          0         0          0
# 508466           7.2          27      22834    170000    -147166
# 558595           0.0           0          0         0          0
# 569055           0.0           0          0         0          0
# 574837           0.0           0          0         0          0
# 585937           0.0           0          0         0          0
# 112857           6.9           4          0         0          0
# 599031          10.0           1          0         0          0
# 616839           0.0           0          0         0          0
# 253639           7.0          23          0         0          0
#
#                                                    genres
# 33                        [{'id': 37, 'name': 'Western'}]
# 66      [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 70                          [{'id': 18, 'name': 'Drama'}]
# 391                       [{'id': 37, 'name': 'Western'}]
# 429                       [{'id': 37, 'name': 'Western'}]
# 688     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 938                       [{'id': 37, 'name': 'Western'}]
# 984     [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 10015   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 10354   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 10648   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 10649   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 10650                       [{'id': 80, 'name': 'Crime'}]
# 10651   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 10724   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 10734   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 10747                     [{'id': 37, 'name': 'Western'}]
# 20006   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 20187   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4929                      [{'id': 37, 'name': 'Western'}]
# 20391   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 11046   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 5551    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 21866   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 11589   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 6723    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 11707   [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...
# 11901                     [{'id': 37, 'name': 'Western'}]
# 11916                     [{'id': 37, 'name': 'Western'}]
# 8348    [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# ...                                                   ...
# 377801                                                 []
# 187534  [{'id': 35, 'name': 'Comedy'}, {'id': 37, 'nam...
# 324314                [{'id': 99, 'name': 'Documentary'}]
# 396462                [{'id': 99, 'name': 'Documentary'}]
# 55676                 [{'id': 99, 'name': 'Documentary'}]
# 94623                 [{'id': 99, 'name': 'Documentary'}]
# 38868   [{'id': 35, 'name': 'Comedy'}, {'id': 99, 'nam...
# 343835  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 187533                                                 []
# 447454                [{'id': 99, 'name': 'Documentary'}]
# 274061                [{'id': 99, 'name': 'Documentary'}]
# 383934  [{'id': 37, 'name': 'Western'}, {'id': 99, 'na...
# 167688                [{'id': 99, 'name': 'Documentary'}]
# 504172  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 462486                [{'id': 99, 'name': 'Documentary'}]
# 247525                  [{'id': 10751, 'name': 'Family'}]
# 190859  [{'id': 10752, 'name': 'War'}, {'id': 28, 'nam...
# 47975                 [{'id': 99, 'name': 'Documentary'}]
# 524469                [{'id': 99, 'name': 'Documentary'}]
# 525362  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
# 471208                [{'id': 99, 'name': 'Documentary'}]
# 508466                [{'id': 99, 'name': 'Documentary'}]
# 558595                [{'id': 99, 'name': 'Documentary'}]
# 569055                [{'id': 99, 'name': 'Documentary'}]
# 574837                [{'id': 99, 'name': 'Documentary'}]
# 585937                                                 []
# 112857  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
# 599031                [{'id': 99, 'name': 'Documentary'}]
# 616839                [{'id': 99, 'name': 'Documentary'}]
# 253639  [{'id': 99, 'name': 'Documentary'}, {'id': 107...
#
# [112 rows x 8 columns]

# %%
#Save to PostgrSQL

# %%
#Create new column containing a list of genres for each movie
def to_list(cell):
    #input is a single cell containing a list of dicts
    #rreturns a list of genres as unique strings
    l = []
    for d in cell:     #cell is list of dicts
        l.append(d['name'])
    return(l)

actor_full_df['genre_names'] = actor_full_df['genres'].map(to_list)
#Drop duplicate info
actor_full_df.drop(['genres'], axis=1, inplace=True)
actor_full_df
# Out:
#                                                     title  popularity  \
# 33                                             Unforgiven      16.755
# 66                                         Absolute Power      10.509
# 70                                    Million Dollar Baby      14.475
# 391                                  A Fistful of Dollars      12.797
# 429                        The Good, the Bad and the Ugly      19.808
# 688                         The Bridges of Madison County      10.029
# 938                                For a Few Dollars More      13.634
# 984                                           Dirty Harry      13.525
# 10015                                    Heartbreak Ridge       9.107
# 10354                                          True Crime       9.027
# 10648                                        Magnum Force      11.352
# 10649                                        The Enforcer       8.791
# 10650                                       Sudden Impact       9.596
# 10651                                       The Dead Pool      11.649
# 10724                                             Firefox       8.167
# 10734                                Escape from Alcatraz      15.775
# 10747                              The Outlaw Josey Wales      12.278
# 20006                                       Pink Cadillac       8.656
# 20187                                  The Eiger Sanction       8.638
# 4929                                        Hang 'em High      10.355
# 20391                                    Paint Your Wagon       6.157
# 11046                                   Where Eagles Dare      12.938
# 5551                                        Space Cowboys       8.672
# 21866                                        Bronco Billy       8.013
# 11589                                      Kelly's Heroes      11.207
# 6723                                           The Rookie       9.386
# 11707                                           Tightrope      10.116
# 11901                                 High Plains Drifter      10.727
# 11916                           Two Mules for Sister Sara      11.213
# 8348                            Thunderbolt and Lightfoot       5.841
# ...                                                   ...         ...
# 377801                    Clint Eastwood, le franc-tireur       0.873
# 187534                      The First Traveling Saleslady       1.693
# 324314                            Tab Hunter Confidential       1.626
# 396462                                Jean Seberg Forever       1.097
# 55676   A Personal Journey with Martin Scorsese Throug...       3.184
# 94623                               Directed by John Ford       1.772
# 38868                        A Decade Under the Influence       2.493
# 343835      Sammy Davis, Jr. 60th Anniversary Celebration       0.767
# 187533                                  Never Say Goodbye       1.371
# 447454                     James Stewart's Wonderful Life       0.631
# 274061                   Johnny Mercer: The Dream's on Me       0.918
# 383934    Denn sie kennen kein Erbarmen: Der Italowestern       1.100
# 167688                           The Unbeatable Bruce Lee       1.121
# 504172                                           The Mule      23.568
# 462486                               Anything Is Possible       0.600
# 247525                    Happy 100th Birthday, Hollywood       0.600
# 190859                                    American Sniper      13.813
# 47975                                  The Spaghetti West       0.949
# 524469                      The Beguiled: The Storyteller       0.600
# 525362                            The Blues - Piano Blues       0.600
# 471208                                 Cannes: All Access       0.600
# 508466                                 Sad Hill Unearthed       2.014
# 558595                              Clint Eastwood's West       0.861
# 569055             Sergio Leone - Une Amérique de légende       0.600
# 574837  An Old Fashioned Love Story: Making 'The Bridg...       0.600
# 585937                                       Leone's West       0.628
# 112857                                        Piano Blues       0.987
# 599031                                  Forever Hollywood       1.199
# 616839  Play It Again: A Look Back at 'Play Misty for Me'       0.600
# 253639                           And the Oscar Goes To...       2.953
#
#         vote_average  vote_count    revenue    budget     profit  \
# 33               7.9        2028  159157447  14000000  145157447
# 66               6.6         424   50068310  50000000      68310
# 70               7.9        5082  216763646  30000000  186763646
# 391              7.9        1942   14500000    200000   14300000
# 429              8.4        4270   25100000   1200000   23900000
# 688              7.6         828  182016617  24000000  158016617
# 938              8.0        1873   15000000    600000   14400000
# 984              7.5        1093   35976000  10000000   25976000
# 10015            6.7         444   42724017  15000000   27724017
# 10354            6.5         283          0         0          0
# 10648            7.2         449   39768000         0   39768000
# 10649            6.8         387   46236000   9000000   37236000
# 10650            6.6         381   67642693  22000000   45642693
# 10651            6.4         360          0  20000000  -20000000
# 10724            6.1         237   70687344  18000000   52687344
# 10734            7.5        1238   43000000   8000000   35000000
# 10747            7.5         507   31800000   3700000   28100000
# 20006            5.4          83          0         0          0
# 20187            6.2         156   14200000         0   14200000
# 4929             6.8         347    6800000   1800000    5000000
# 20391            6.4         104   31678778  20000000   11678778
# 11046            7.6         403   21000000   7700000   13300000
# 5551             6.3         689  128884132  65000000   63884132
# 21866            6.1          92          0         0          0
# 11589            7.4         316    5200000   4000000    1200000
# 6723             5.8         243   21633874  10000000   11633874
# 11707            6.1         148   48143579         0   48143579
# 11901            7.5         495   15700000   5500000   10200000
# 11916            6.9         254    5050000         0    5050000
# 8348             6.8         202   21700000         0   21700000
# ...              ...         ...        ...       ...        ...
# 377801          10.0           1          0         0          0
# 187534           5.2           5          0         0          0
# 324314           7.7          27          0         0          0
# 396462           0.0           0          0         0          0
# 55676            8.2          48          0         0          0
# 94623            6.8           9          0         0          0
# 38868            7.8          17          0         0          0
# 343835           9.3           3          0         0          0
# 187533           6.7           6          0         0          0
# 447454           0.0           0          0         0          0
# 274061          10.0           1          0         0          0
# 383934           0.0           0          0         0          0
# 167688           9.5           1          0         0          0
# 504172           6.6        1968  171304407  50000000  121304407
# 462486           0.0           0          0         0          0
# 247525           0.0           0          0         0          0
# 190859           7.4        7946  542307423  58800000  483507423
# 47975            6.5           2          0         0          0
# 524469           7.0           1          0         0          0
# 525362           7.3           3          0         0          0
# 471208           2.0           1          0         0          0
# 508466           7.2          27      22834    170000    -147166
# 558595           0.0           0          0         0          0
# 569055           0.0           0          0         0          0
# 574837           0.0           0          0         0          0
# 585937           0.0           0          0         0          0
# 112857           6.9           4          0         0          0
# 599031          10.0           1          0         0          0
# 616839           0.0           0          0         0          0
# 253639           7.0          23          0         0          0
#
#                                               genre_names
# 33                                              [Western]
# 66                      [Crime, Drama, Thriller, Mystery]
# 70                                                [Drama]
# 391                                             [Western]
# 429                                             [Western]
# 688                                      [Drama, Romance]
# 938                                             [Western]
# 984                             [Action, Crime, Thriller]
# 10015                        [Action, Comedy, Drama, War]
# 10354                   [Crime, Drama, Thriller, Mystery]
# 10648           [Action, Crime, Thriller, Drama, Mystery]
# 10649                           [Action, Crime, Thriller]
# 10650                                             [Crime]
# 10651                           [Action, Crime, Thriller]
# 10724      [Science Fiction, Action, Adventure, Thriller]
# 10734                                      [Crime, Drama]
# 10747                                           [Western]
# 20006         [Action, Adventure, Comedy, Drama, Romance]
# 20187   [Action, Adventure, Crime, Drama, Mystery, Thr...
# 4929                                            [Western]
# 20391             [Drama, Action, Comedy, Western, Music]
# 11046            [Adventure, Drama, Action, History, War]
# 5551                        [Action, Adventure, Thriller]
# 21866           [Action, Comedy, Drama, Romance, Western]
# 11589                            [Adventure, Comedy, War]
# 6723                     [Action, Crime, Drama, Thriller]
# 11707                   [Mystery, Thriller, Crime, Drama]
# 11901                                           [Western]
# 11916                                           [Western]
# 8348                              [Comedy, Crime, Action]
# ...                                                   ...
# 377801                                                 []
# 187534                                  [Comedy, Western]
# 324314                                      [Documentary]
# 396462                                      [Documentary]
# 55676                                       [Documentary]
# 94623                                       [Documentary]
# 38868                      [Comedy, Documentary, Romance]
# 343835                                    [Comedy, Music]
# 187533                                                 []
# 447454                                      [Documentary]
# 274061                                      [Documentary]
# 383934                             [Western, Documentary]
# 167688                                      [Documentary]
# 504172                           [Crime, Drama, Thriller]
# 462486                                      [Documentary]
# 247525                                           [Family]
# 190859                                      [War, Action]
# 47975                                       [Documentary]
# 524469                                      [Documentary]
# 525362                               [Music, Documentary]
# 471208                                      [Documentary]
# 508466                                      [Documentary]
# 558595                                      [Documentary]
# 569055                                      [Documentary]
# 574837                                      [Documentary]
# 585937                                                 []
# 112857                               [Music, Documentary]
# 599031                                      [Documentary]
# 616839                                      [Documentary]
# 253639                            [Documentary, TV Movie]
#
# [112 rows x 8 columns]

# %%
print(actor_full_df.shape)
actor_full_df.describe()
# Out:
# (112, 8)
#        popularity  vote_average   vote_count       revenue        budget  \
# count  112.000000    112.000000   112.000000  1.120000e+02  1.120000e+02
# mean     5.590964      5.805357   436.151786  2.832836e+07  6.107098e+06
# std      5.142051      2.625030  1173.491919  7.346843e+07  1.399020e+07
# min      0.600000      0.000000     0.000000  0.000000e+00  0.000000e+00
# 25%      1.099250      5.400000     2.750000  0.000000e+00  0.000000e+00
# 50%      3.054000      6.550000    26.000000  0.000000e+00  0.000000e+00
# 75%      9.386000      7.300000   323.750000  2.165041e+07  1.350000e+06
# max     23.568000     10.000000  7946.000000  5.423074e+08  6.500000e+07
#
#              profit
# count  1.120000e+02
# mean   2.222126e+07
# std    6.330551e+07
# min   -2.000000e+07
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    1.331225e+07
# max    4.835074e+08

# %% [markdown]
# Delete rows with non-movies (eg. Documentary(99), TV Movie(10770) ). Deciding what constitutes a genre.
# 1. Eliminate rows containing Documentery or TV Movie as a genre.
# 2. Eliminate rows where revenue or budget are zero.

# %%
actor_full_df.head(3)
# Out:
#                   title  popularity  vote_average  vote_count    revenue  \
# 33           Unforgiven      16.755           7.9        2028  159157447
# 66       Absolute Power      10.509           6.6         424   50068310
# 70  Million Dollar Baby      14.475           7.9        5082  216763646
#
#       budget     profit                        genre_names
# 33  14000000  145157447                          [Western]
# 66  50000000      68310  [Crime, Drama, Thriller, Mystery]
# 70  30000000  186763646                            [Drama]

# %%
# If Genres is in Documentary(99), TV Movie(10770), delete the row.
# If revenue, budget or profit is zero or NaN, eliminate the row.
# If vote_count	< 20, eliminate the row.
#hoffman_full_df.isnull().sum()

# %%
#Function removes Documentary(99) and TV Movie(10770) genres on each cell
def exclude_genres(cell):
    '''looks for excluded values in a cell
       returns boolean mask'''
    excluded_genre = ['TV Movie','Documentary']
#    print(cell)
    if len(cell) == 0:
        return False
    else:
        for g in excluded_genre:
            if g in cell:
                return False
    return True

#  .map to genres column
actor_full_df = actor_full_df[actor_full_df.genre_names.map(exclude_genres)]            
actor_full_df
# Out:
#                                                 title  popularity  \
# 33                                         Unforgiven      16.755
# 66                                     Absolute Power      10.509
# 70                                Million Dollar Baby      14.475
# 391                              A Fistful of Dollars      12.797
# 429                    The Good, the Bad and the Ugly      19.808
# 688                     The Bridges of Madison County      10.029
# 938                            For a Few Dollars More      13.634
# 984                                       Dirty Harry      13.525
# 10015                                Heartbreak Ridge       9.107
# 10354                                      True Crime       9.027
# 10648                                    Magnum Force      11.352
# 10649                                    The Enforcer       8.791
# 10650                                   Sudden Impact       9.596
# 10651                                   The Dead Pool      11.649
# 10724                                         Firefox       8.167
# 10734                            Escape from Alcatraz      15.775
# 10747                          The Outlaw Josey Wales      12.278
# 20006                                   Pink Cadillac       8.656
# 20187                              The Eiger Sanction       8.638
# 4929                                    Hang 'em High      10.355
# 20391                                Paint Your Wagon       6.157
# 11046                               Where Eagles Dare      12.938
# 5551                                    Space Cowboys       8.672
# 21866                                    Bronco Billy       8.013
# 11589                                  Kelly's Heroes      11.207
# 6723                                       The Rookie       9.386
# 11707                                       Tightrope      10.116
# 11901                             High Plains Drifter      10.727
# 11916                       Two Mules for Sister Sara      11.213
# 8348                        Thunderbolt and Lightfoot       5.841
# ...                                               ...         ...
# 9386                              In the Line of Fire      11.372
# 26170                                  Coogan's Bluff       9.311
# 9559                                  A Perfect World      10.083
# 9573                                       Blood Work       8.752
# 13223                                     Gran Torino      13.573
# 28761                       White Hunter, Black Heart       7.722
# 36236                                     The Witches       2.980
# 14881                                        Joe Kidd       7.603
# 15393                               Play Misty for Me       9.197
# 15417                       Every Which Way But Loose      11.228
# 37917                                   Honkytonk Man       6.320
# 62742                             Francis in the Navy       1.919
# 16969                                       City Heat       7.125
# 17169                           Any Which Way You Can       6.943
# 17689                                    The Gauntlet       7.514
# 80775                                  Away All Boats       2.359
# 94771                      One Hundred and One Nights       3.128
# 87825                          Trouble with the Curve       9.386
# 111942                               Star in the Dust       2.134
# 112672                        Ambush at Cimarron Pass       1.294
# 130134                           Lafayette Escadrille       0.948
# 40761                         Revenge of the Creature       4.972
# 40374                                          Breezy       7.591
# 113939                        Lady Godiva of Coventry       1.521
# 150157                              Escapade In Japan       1.357
# 187534                  The First Traveling Saleslady       1.693
# 343835  Sammy Davis, Jr. 60th Anniversary Celebration       0.767
# 504172                                       The Mule      23.568
# 247525                Happy 100th Birthday, Hollywood       0.600
# 190859                                American Sniper      13.813
#
#         vote_average  vote_count    revenue    budget     profit  \
# 33               7.9        2028  159157447  14000000  145157447
# 66               6.6         424   50068310  50000000      68310
# 70               7.9        5082  216763646  30000000  186763646
# 391              7.9        1942   14500000    200000   14300000
# 429              8.4        4270   25100000   1200000   23900000
# 688              7.6         828  182016617  24000000  158016617
# 938              8.0        1873   15000000    600000   14400000
# 984              7.5        1093   35976000  10000000   25976000
# 10015            6.7         444   42724017  15000000   27724017
# 10354            6.5         283          0         0          0
# 10648            7.2         449   39768000         0   39768000
# 10649            6.8         387   46236000   9000000   37236000
# 10650            6.6         381   67642693  22000000   45642693
# 10651            6.4         360          0  20000000  -20000000
# 10724            6.1         237   70687344  18000000   52687344
# 10734            7.5        1238   43000000   8000000   35000000
# 10747            7.5         507   31800000   3700000   28100000
# 20006            5.4          83          0         0          0
# 20187            6.2         156   14200000         0   14200000
# 4929             6.8         347    6800000   1800000    5000000
# 20391            6.4         104   31678778  20000000   11678778
# 11046            7.6         403   21000000   7700000   13300000
# 5551             6.3         689  128884132  65000000   63884132
# 21866            6.1          92          0         0          0
# 11589            7.4         316    5200000   4000000    1200000
# 6723             5.8         243   21633874  10000000   11633874
# 11707            6.1         148   48143579         0   48143579
# 11901            7.5         495   15700000   5500000   10200000
# 11916            6.9         254    5050000         0    5050000
# 8348             6.8         202   21700000         0   21700000
# ...              ...         ...        ...       ...        ...
# 9386             6.9         703  176997168  40000000  136997168
# 26170            6.5         136    3110000         0    3110000
# 9559             7.4         735  135130999  30000000  105130999
# 9573             6.2         371   31794718  50000000  -18205282
# 13223            8.0        6088  269958228  33000000  236958228
# 28761            6.5          99          0         0          0
# 36236            5.8          21          0         0          0
# 14881            6.4         140    6330000         0    6330000
# 15393            6.7         170   10600000    725000    9875000
# 15417            6.1         208         85         5         80
# 37917            6.1          68          0         0          0
# 62742            5.6          10          0         0          0
# 16969            5.4          83   38348988  25000000   13348988
# 17169            6.0         148   70687344         0   70687344
# 17689            6.6         213   26414658   5500000   20914658
# 80775            5.8           8          0         0          0
# 94771            6.1           9          0         0          0
# 87825            6.7         633          0         0          0
# 111942           3.9           9          0         0          0
# 112672           4.8           5          0         0          0
# 130134           4.7           3          0         0          0
# 40761            5.7          49          0   1100000   -1100000
# 40374            7.3          52          0         0          0
# 113939           5.0           5          0         0          0
# 150157           5.7           6          0         0          0
# 187534           5.2           5          0         0          0
# 343835           9.3           3          0         0          0
# 504172           6.6        1968  171304407  50000000  121304407
# 247525           0.0           0          0         0          0
# 190859           7.4        7946  542307423  58800000  483507423
#
#                                               genre_names
# 33                                              [Western]
# 66                      [Crime, Drama, Thriller, Mystery]
# 70                                                [Drama]
# 391                                             [Western]
# 429                                             [Western]
# 688                                      [Drama, Romance]
# 938                                             [Western]
# 984                             [Action, Crime, Thriller]
# 10015                        [Action, Comedy, Drama, War]
# 10354                   [Crime, Drama, Thriller, Mystery]
# 10648           [Action, Crime, Thriller, Drama, Mystery]
# 10649                           [Action, Crime, Thriller]
# 10650                                             [Crime]
# 10651                           [Action, Crime, Thriller]
# 10724      [Science Fiction, Action, Adventure, Thriller]
# 10734                                      [Crime, Drama]
# 10747                                           [Western]
# 20006         [Action, Adventure, Comedy, Drama, Romance]
# 20187   [Action, Adventure, Crime, Drama, Mystery, Thr...
# 4929                                            [Western]
# 20391             [Drama, Action, Comedy, Western, Music]
# 11046            [Adventure, Drama, Action, History, War]
# 5551                        [Action, Adventure, Thriller]
# 21866           [Action, Comedy, Drama, Romance, Western]
# 11589                            [Adventure, Comedy, War]
# 6723                     [Action, Crime, Drama, Thriller]
# 11707                   [Mystery, Thriller, Crime, Drama]
# 11901                                           [Western]
# 11916                                           [Western]
# 8348                              [Comedy, Crime, Action]
# ...                                                   ...
# 9386            [Action, Drama, Thriller, Crime, Mystery]
# 26170                    [Action, Crime, Drama, Thriller]
# 9559                             [Crime, Drama, Thriller]
# 9573                                    [Crime, Thriller]
# 13223                                             [Drama]
# 28761                          [Action, Adventure, Drama]
# 36236                            [Comedy, Drama, Romance]
# 14881                                           [Western]
# 15393                   [Crime, Drama, Romance, Thriller]
# 15417         [Action, Comedy, Adventure, Romance, Drama]
# 37917                     [Western, Comedy, Drama, Music]
# 62742                           [Comedy, Family, Romance]
# 16969                    [Action, Comedy, Crime, Mystery]
# 17169                         [Action, Adventure, Comedy]
# 17689                    [Drama, Action, Crime, Thriller]
# 80775                                               [War]
# 94771                          [Comedy, History, Romance]
# 87825                                    [Drama, Romance]
# 111942                                          [Western]
# 112672                             [Action, War, Western]
# 130134                              [War, Drama, Romance]
# 40761                           [Horror, Science Fiction]
# 40374                                    [Drama, Romance]
# 113939                                   [Drama, History]
# 150157                                [Family, Adventure]
# 187534                                  [Comedy, Western]
# 343835                                    [Comedy, Music]
# 504172                           [Crime, Drama, Thriller]
# 247525                                           [Family]
# 190859                                      [War, Action]
#
# [64 rows x 8 columns]

# %%
#Eliminate the rows without budget or revenue data
good_money_df = actor_full_df[(actor_full_df.budget > 0.0) & (actor_full_df.revenue > 0.0)]
pd.options.display.float_format = '{:,.2f}'.format
#good_money_df['revenue'] = good_money_df['revenue'].apply(lambda x: '{:d}'.format(x))

#good_money_df['budget'] = good_money_df['budget'].apply(lambda x: '{:,.2f}'.format(x))

#good_money_df['profit'] = good_money_df['profit'].apply(lambda x: '{:,.2f}'.format(x))
#print(good_money_df.info())
print(good_money_df.shape)
print(good_money_df.describe())
good_money_df
# Out:
# (32, 8)
#        popularity  vote_average  vote_count        revenue        budget  \
# count       32.00         32.00       32.00          32.00         32.00
# mean        11.60          7.01    1,386.12  91,323,553.94 20,710,156.41
# std          3.67          0.75    1,895.35 115,112,281.95 19,490,599.15
# min          6.16          5.40       83.00          85.00          5.00
# 25%          9.17          6.55      339.25  21,475,405.50  5,125,000.00
# 50%         10.62          6.85      501.00  40,536,502.50 14,500,000.00
# 75%         13.54          7.53    1,890.25 141,137,611.00 30,750,000.00
# max         23.57          8.40    7,946.00 542,307,423.00 65,000,000.00
#
#               profit
# count          32.00
# mean   70,613,397.53
# std   102,991,721.99
# min   -18,205,282.00
# 25%    11,667,552.00
# 50%    26,850,008.50
# 75%   109,174,351.00
# max   483,507,423.00
#                                  title  popularity  vote_average  vote_count  \
# 33                          Unforgiven       16.75          7.90        2028
# 66                      Absolute Power       10.51          6.60         424
# 70                 Million Dollar Baby       14.47          7.90        5082
# 391               A Fistful of Dollars       12.80          7.90        1942
# 429     The Good, the Bad and the Ugly       19.81          8.40        4270
# 688      The Bridges of Madison County       10.03          7.60         828
# 938             For a Few Dollars More       13.63          8.00        1873
# 984                        Dirty Harry       13.53          7.50        1093
# 10015                 Heartbreak Ridge        9.11          6.70         444
# 10649                     The Enforcer        8.79          6.80         387
# 10650                    Sudden Impact        9.60          6.60         381
# 10724                          Firefox        8.17          6.10         237
# 10734             Escape from Alcatraz       15.78          7.50        1238
# 10747           The Outlaw Josey Wales       12.28          7.50         507
# 4929                     Hang 'em High       10.36          6.80         347
# 20391                 Paint Your Wagon        6.16          6.40         104
# 11046                Where Eagles Dare       12.94          7.60         403
# 5551                     Space Cowboys        8.67          6.30         689
# 11589                   Kelly's Heroes       11.21          7.40         316
# 6723                        The Rookie        9.39          5.80         243
# 11901              High Plains Drifter       10.73          7.50         495
# 8839                            Casper       10.38          6.20        2540
# 9386               In the Line of Fire       11.37          6.90         703
# 9559                   A Perfect World       10.08          7.40         735
# 9573                        Blood Work        8.75          6.20         371
# 13223                      Gran Torino       13.57          8.00        6088
# 15393                Play Misty for Me        9.20          6.70         170
# 15417        Every Which Way But Loose       11.23          6.10         208
# 16969                        City Heat        7.12          5.40          83
# 17689                     The Gauntlet        7.51          6.60         213
# 504172                        The Mule       23.57          6.60        1968
# 190859                 American Sniper       13.81          7.40        7946
#
#           revenue    budget     profit  \
# 33      159157447  14000000  145157447
# 66       50068310  50000000      68310
# 70      216763646  30000000  186763646
# 391      14500000    200000   14300000
# 429      25100000   1200000   23900000
# 688     182016617  24000000  158016617
# 938      15000000    600000   14400000
# 984      35976000  10000000   25976000
# 10015    42724017  15000000   27724017
# 10649    46236000   9000000   37236000
# 10650    67642693  22000000   45642693
# 10724    70687344  18000000   52687344
# 10734    43000000   8000000   35000000
# 10747    31800000   3700000   28100000
# 4929      6800000   1800000    5000000
# 20391    31678778  20000000   11678778
# 11046    21000000   7700000   13300000
# 5551    128884132  65000000   63884132
# 11589     5200000   4000000    1200000
# 6723     21633874  10000000   11633874
# 11901    15700000   5500000   10200000
# 8839    287928194  50000000  237928194
# 9386    176997168  40000000  136997168
# 9559    135130999  30000000  105130999
# 9573     31794718  50000000  -18205282
# 13223   269958228  33000000  236958228
# 15393    10600000    725000    9875000
# 15417          85         5         80
# 16969    38348988  25000000   13348988
# 17689    26414658   5500000   20914658
# 504172  171304407  50000000  121304407
# 190859  542307423  58800000  483507423
#
#                                            genre_names
# 33                                           [Western]
# 66                   [Crime, Drama, Thriller, Mystery]
# 70                                             [Drama]
# 391                                          [Western]
# 429                                          [Western]
# 688                                   [Drama, Romance]
# 938                                          [Western]
# 984                          [Action, Crime, Thriller]
# 10015                     [Action, Comedy, Drama, War]
# 10649                        [Action, Crime, Thriller]
# 10650                                          [Crime]
# 10724   [Science Fiction, Action, Adventure, Thriller]
# 10734                                   [Crime, Drama]
# 10747                                        [Western]
# 4929                                         [Western]
# 20391          [Drama, Action, Comedy, Western, Music]
# 11046         [Adventure, Drama, Action, History, War]
# 5551                     [Action, Adventure, Thriller]
# 11589                         [Adventure, Comedy, War]
# 6723                  [Action, Crime, Drama, Thriller]
# 11901                                        [Western]
# 8839                         [Fantasy, Comedy, Family]
# 9386         [Action, Drama, Thriller, Crime, Mystery]
# 9559                          [Crime, Drama, Thriller]
# 9573                                 [Crime, Thriller]
# 13223                                          [Drama]
# 15393                [Crime, Drama, Romance, Thriller]
# 15417      [Action, Comedy, Adventure, Romance, Drama]
# 16969                 [Action, Comedy, Crime, Mystery]
# 17689                 [Drama, Action, Crime, Thriller]
# 504172                        [Crime, Drama, Thriller]
# 190859                                   [War, Action]

# %%
print("Enter valid genre: ")
test_for_genre = input("... MUST be a capitalized: ")

def is_genre(cell):
    #returns True if in, else false (for masking)
    if test_for_genre in cell:
        return True 
    return False

tested_for_genre_df = good_money_df[good_money_df.genre_names.map(is_genre)]
not_tested_for_genre_df = good_money_df[False == good_money_df.genre_names.map(is_genre)]

print(tested_for_genre_df.shape)
print(tested_for_genre_df.describe())
tested_for_genre_df
# Out:
# Enter valid genre:
# ... MUST be a capitalized: Drama
# (15, 8)
#        popularity  vote_average  vote_count        revenue        budget  \
# count       15.00         15.00       15.00          15.00         15.00
# mean        11.66          6.96    1,256.73  93,286,052.47 21,595,000.33
# std          4.17          0.67    1,833.27  88,760,143.62 16,794,780.30
# min          6.16          5.80      104.00          85.00          5.00
# 25%          9.29          6.60      228.00  24,024,266.00  7,850,000.00
# 50%         10.51          6.70      444.00  43,000,000.00 20,000,000.00
# 75%         13.26          7.55    1,033.00 174,150,787.50 31,500,000.00
# max         23.57          8.00    6,088.00 269,958,228.00 50,000,000.00
#
#               profit
# count          15.00
# mean   71,691,052.13
# std    78,566,493.02
# min            80.00
# 25%    11,656,326.00
# 50%    27,724,017.00
# 75%   129,150,787.50
# max   236,958,228.00
#                                 title  popularity  vote_average  vote_count  \
# 66                     Absolute Power       10.51          6.60         424
# 70                Million Dollar Baby       14.47          7.90        5082
# 688     The Bridges of Madison County       10.03          7.60         828
# 10015                Heartbreak Ridge        9.11          6.70         444
# 10734            Escape from Alcatraz       15.78          7.50        1238
# 20391                Paint Your Wagon        6.16          6.40         104
# 11046               Where Eagles Dare       12.94          7.60         403
# 6723                       The Rookie        9.39          5.80         243
# 9386              In the Line of Fire       11.37          6.90         703
# 9559                  A Perfect World       10.08          7.40         735
# 13223                     Gran Torino       13.57          8.00        6088
# 15393               Play Misty for Me        9.20          6.70         170
# 15417       Every Which Way But Loose       11.23          6.10         208
# 17689                    The Gauntlet        7.51          6.60         213
# 504172                       The Mule       23.57          6.60        1968
#
#           revenue    budget     profit  \
# 66       50068310  50000000      68310
# 70      216763646  30000000  186763646
# 688     182016617  24000000  158016617
# 10015    42724017  15000000   27724017
# 10734    43000000   8000000   35000000
# 20391    31678778  20000000   11678778
# 11046    21000000   7700000   13300000
# 6723     21633874  10000000   11633874
# 9386    176997168  40000000  136997168
# 9559    135130999  30000000  105130999
# 13223   269958228  33000000  236958228
# 15393    10600000    725000    9875000
# 15417          85         5         80
# 17689    26414658   5500000   20914658
# 504172  171304407  50000000  121304407
#
#                                         genre_names
# 66                [Crime, Drama, Thriller, Mystery]
# 70                                          [Drama]
# 688                                [Drama, Romance]
# 10015                  [Action, Comedy, Drama, War]
# 10734                                [Crime, Drama]
# 20391       [Drama, Action, Comedy, Western, Music]
# 11046      [Adventure, Drama, Action, History, War]
# 6723               [Action, Crime, Drama, Thriller]
# 9386      [Action, Drama, Thriller, Crime, Mystery]
# 9559                       [Crime, Drama, Thriller]
# 13223                                       [Drama]
# 15393             [Crime, Drama, Romance, Thriller]
# 15417   [Action, Comedy, Adventure, Romance, Drama]
# 17689              [Drama, Action, Crime, Thriller]
# 504172                     [Crime, Drama, Thriller]

# %%
#Not in genre info
print(not_tested_for_genre_df.shape)
print(not_tested_for_genre_df.describe())
not_tested_for_genre_df.head(3)
# Out:
# (17, 8)
#        popularity  vote_average  vote_count        revenue        budget  \
# count       17.00         17.00       17.00          17.00         17.00
# mean        11.55          7.05    1,500.29  89,591,937.59 19,929,411.76
# std          3.29          0.83    1,997.47 137,015,084.10 22,087,008.76
# min          7.12          5.40       83.00   5,200,000.00    200,000.00
# 25%          8.79          6.30      371.00  15,700,000.00  3,700,000.00
# 50%         10.73          7.40      507.00  35,976,000.00 10,000,000.00
# 75%         13.53          7.50    1,942.00  70,687,344.00 25,000,000.00
# max         19.81          8.40    7,946.00 542,307,423.00 65,000,000.00
#
#               profit
# count          17.00
# mean   69,662,525.82
# std   123,079,149.95
# min   -18,205,282.00
# 25%    13,348,988.00
# 50%    25,976,000.00
# 75%    52,687,344.00
# max   483,507,423.00
#                               title  popularity  vote_average  vote_count  \
# 33                       Unforgiven       16.75          7.90        2028
# 391            A Fistful of Dollars       12.80          7.90        1942
# 429  The Good, the Bad and the Ugly       19.81          8.40        4270
#
#        revenue    budget     profit genre_names
# 33   159157447  14000000  145157447   [Western]
# 391   14500000    200000   14300000   [Western]
# 429   25100000   1200000   23900000   [Western]

# %%
len(tested_for_genre_df['popularity'])
# Out:
# 15

# %%
#Plot the distribution for popularity

fig, ax = plt.subplots(1, figsize=(16, 3))
ax.scatter(tested_for_genre_df['popularity'], np.repeat(0, len(tested_for_genre_df['popularity'])) + np.random.normal(0, 0.1, len(tested_for_genre_df['popularity'])), marker="*", c='blue', s=120)
ax.scatter(not_tested_for_genre_df['popularity'], np.repeat(1, len(not_tested_for_genre_df['popularity'])) + np.random.normal(0, 0.1, len(not_tested_for_genre_df['popularity'])),marker="*", c='red', s=120)
plt.title(actor + ' Movies TMDB Popularity', size = 20)
ax.set_yticks([0, 1])

ax.set_yticklabels([test_for_genre, "Not " + test_for_genre])  #generalize the label for and genre
#plt.tight_layout()
# Out:
# [Text(0, 0, 'Drama'), Text(0, 0, 'Not Drama')]

# %% [markdown]
# Null Hypothesis: H0 - There is no difference in the popularity of Eastwood's dramas vs. his non-dramatic categories.
# This hypothesis will be tested with the Rank Sum Statistic aka the U-Test

# %%
def count_winning_pairs(sample_1, sample_2):
    sample_1, sample_2 = np.array(sample_1), np.array(sample_2)
    n_total_wins = 0
    for x in sample_1:
        n_wins = np.sum(x > sample_2) + 0.5*np.sum(x == sample_2)
        n_total_wins += n_wins
    return n_total_wins

not_genre_wins = count_winning_pairs(not_tested_for_genre_df['popularity'], tested_for_genre_df['popularity'])
genre_wins = count_winning_pairs(tested_for_genre_df['popularity'], not_tested_for_genre_df['popularity'])
print("Total Number of Comparisons: {}\n".format(len(not_tested_for_genre_df['profit'])*len(tested_for_genre_df['profit'])))
print("Number of 'Not-in-Genre' Movie Wins: {}\n".format(not_genre_wins))
print("Number of In Genre: " + test_for_genre + " Movie Wins: {}".format(genre_wins))
# Out:
# Total Number of Comparisons: 255
#
# Number of 'Not-in-Genre' Movie Wins: 127.0
#
# Number of In Genre: Drama Movie Wins: 128.0

# %% [markdown]
# The total number of wins is the total number of comparisons between a popularity of an "in genre" movie and the popularity of a not-in-genre movie.

# %%
# Now, using the U-Test (aka the Mann-Whitney U Statistic) calculate 
#    the Rank Sum Statistic
res = stats.mannwhitneyu(not_tested_for_genre_df['popularity'], tested_for_genre_df['popularity'], alternative="greater")
print("p-value for 'Not-in-Genre' Movie Popularity > " + test_for_genre + " Movie Popularity: {:2.3f}".format(res.pvalue))
# Out:
# p-value for 'Not-in-Genre' Movie Popularity > Drama Movie Popularity: 0.515

# %% [markdown]
# *********************************
#
# Here, we cannot reject the null hypothesis that Clint Eastwood's movies are more or less popular than his non-dramatic movies, at least in the measure of popularity in the TMDB.
#
# *****Note that this conclusion will change for each actor and each genre tested!!!!

# %%
#Plot the distribution for profit
fig, ax = plt.subplots(1, figsize=(16, 3))
ax.scatter(tested_for_genre_df['revenue'], np.repeat(0, len(tested_for_genre_df['revenue'])) + np.random.normal(0, 0.1, len(tested_for_genre_df['revenue'])), marker='$''\$''$', c='yellow', edgecolors='green', s=330)
ax.scatter(not_tested_for_genre_df['revenue'], np.repeat(1, len(not_tested_for_genre_df['revenue'])) + np.random.normal(0, 0.1, len(not_tested_for_genre_df['revenue'])),marker='$''\$''$',c='blue', edgecolors='green', s=330)
plt.title(actor + ' Movies - Revenue', size=20)


def format_func(value, tick_number):
    # find number of multiples of pi/2
    N = int(np.round(value / 1000000))
    if N == 0:
        return "0"
    elif N == 100:
        return ("$100")
    elif N == 200:
        return ("$200")
    elif N == 300:
        return ("$300")
    elif N == 400:
        return ("$400")
    elif N == 500:
        return ("$500")
    elif N == 600:
        return ("$600")
    elif N == 700:
        return ("$700")
    else:
        return ("$800")

ax.xaxis.set_major_formatter(plt.FuncFormatter(format_func))
ax.set_xlabel('Millions of U.S. Dollars', backgroundcolor='white', color=(.3, .9, .01), animated=True, fontstyle='italic', size=13)
ax.set_yticks([0, 1])
_nothing = ax.set_yticklabels([test_for_genre + "  ", "Not " + test_for_genre], fontstyle='oblique', color=(.18, .31, .31), size='15')
#plt.tight_layout()

# %% [markdown]
# ******
# Null Hypothesis: H0 - There is no difference in the revenue of Clint Eastwood's Drama movies and the revenue of those movies not considerd dramatic.
# This hypothesis will be tested with the Rank Sum Statistic aka the U-Test
# *******Note that this will change for each actor and genre tested.

# %%
def count_winning_pairs(sample_1, sample_2):
    sample_1, sample_2 = np.array(sample_1), np.array(sample_2)
    n_total_wins = 0
    for x in sample_1:
        n_wins = np.sum(x > sample_2) + 0.5*np.sum(x == sample_2)
        n_total_wins += n_wins
    return n_total_wins

not_genre_wins = count_winning_pairs(not_tested_for_genre_df['revenue'], tested_for_genre_df['revenue'])
genre_wins = count_winning_pairs(tested_for_genre_df['revenue'], not_tested_for_genre_df['revenue'])
print("Total Number of Comparisons: {}\n".format(len(not_tested_for_genre_df['revenue'])*len(tested_for_genre_df['revenue'])))
print("Number of 'Not-in-Genre' Movie Wins: {}\n".format(not_genre_wins))
print("Number of In Genre: " + test_for_genre + " Movie Wins: {}".format(genre_wins))
# Out:
# Total Number of Comparisons: 255
#
# Number of 'Not-in-Genre' Movie Wins: 111.0
#
# Number of In Genre: Drama Movie Wins: 144.0

# %% [markdown]
# Remember, the total number of "wins" is the total number of comparisons between the revenue of a in-genre movie and the revenue of a not-in-genre movie.

# %%
# Now, using the U-Test (aka the Mann-Whitney U Statistic) calculate 
#    the Rank Sum Statistic
res = stats.mannwhitneyu(not_tested_for_genre_df['revenue'], tested_for_genre_df['revenue'], alternative="greater")

print("p-value for 'Not-in-Genre' Movie Popularity > " + test_for_genre + " Movie Popularity: {:2.3f}".format(res.pvalue))
# Out:
# p-value for 'Not-in-Genre' Movie Popularity > Drama Movie Popularity: 0.740

# %% [markdown]
# ******
# Once again, we cannot reject the null hypothesis that there is no defference in revenue between Clint Eastwood's and non-dramatic movies.
# *****Note that this conclusion will change for each actor & genre tested.
