# %%
import time
import config
import tmdbsimple as tmdb          # tmdbsimple 2.2.0
tmdb.API_KEY = config.tmdb_api_key # get TMDB API key from config.py file

import pprint as pp
import pandas as pd
import numpy as np
import scipy as sp
import scipy.stats as stats
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print("Enter actor's full name...")
actor = input("... MUST be a string: ")
search = tmdb.Search()
actor_response = search.person(query=actor) 
actor_id = search.results[0]['id']
actor_id
# Out:
# Enter actor's full name...
# ... MUST be a string: Dustin Hoffman
# 4483

# %%
actor_movie_credits = actor + " Movies"
actor_movie_credits
# Out:
# 'Dustin Hoffman Movies'

# %%
#Now get actor's credits
search_actor_id = tmdb.People(actor_id)
response_actor_id = search_actor_id.movie_credits()
response_actor_id
#actor_movie_credits = actor + " Credits")
# Out:
# {'cast': [{'character': 'Raymond Babbitt',
#    'credit_id': '52fe423cc3a36847f800e8b7',
#    'poster_path': '/vllKYkA7eYi2UMM9yWQ1JegefBh.jpg',
#    'id': 380,
#    'video': False,
#    'vote_count': 3318,
#    'adult': False,
#    'backdrop_path': '/eZ4Aj1O6E95Mk5O9oKKdvfnSWzf.jpg',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'Rain Man',
#    'popularity': 12.331,
#    'title': 'Rain Man',
#    'vote_average': 7.7,
#    'overview': "Selfish yuppie Charlie Babbitt's father left a fortune to his savant brother Raymond and a pittance to Charlie; they travel cross-country.",
#    'release_date': '1988-12-11'},
#   {'character': 'Stanley Motss',
#    'credit_id': '52fe4258c3a36847f8016f15',
#    'poster_path': '/cGatilylRyJiCoOu5T5sAB17HKR.jpg',
#    'id': 586,
#    'video': False,
#    'vote_count': 459,
#    'adult': False,
#    'backdrop_path': '/bWoNwo04ZfZoEvEF8gliyB1EAyS.jpg',
#    'genre_ids': [35, 18],
#    'original_language': 'en',
#    'original_title': 'Wag the Dog',
#    'popularity': 11.072,
#    'title': 'Wag the Dog',
#    'vote_average': 6.9,
#    'overview': "During the final weeks of a presidential race, the President is accused of sexual misconduct. To distract the public until the election, the President's adviser hires a Hollywood producer to help him stage a fake war.",
#    'release_date': '1997-12-25'},
#   {'character': 'Bernie Focker',
#    'credit_id': '52fe426bc3a36847f801d325',
#    'release_date': '2004-12-22',
#    'vote_count': 2796,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.2,
#    'title': 'Meet the Fockers',
#    'genre_ids': [35, 10749],
#    'original_language': 'en',
#    'original_title': 'Meet the Fockers',
#    'popularity': 12.842,
#    'id': 693,
#    'backdrop_path': '/f0eF1rB9KnZPonliSt8CazKvihD.jpg',
#    'overview': "Hard-to-crack ex-CIA man, Jack Byrnes and his wife, Dina head for the warmer climes of Florida to meet son-in-law-to-be, Greg Focker's parents. Unlike their happily matched offspring, the future in-laws find themselves in a situation of opposites that definitely do not attract.",
#    'poster_path': '/xHAqB06iL5D6HyOS6QpgyKkRQHD.jpg'},
#   {'character': 'Danny Snyder',
#    'credit_id': '52fe427bc3a36847f8022297',
#    'poster_path': '/cDqEv4Fw4JZh2zCfecqw3z09L8z.jpg',
#    'id': 819,
#    'video': False,
#    'vote_count': 1485,
#    'adult': False,
#    'backdrop_path': '/vvdo7wDPJZHfstNMKprqRIM8l3B.jpg',
#    'genre_ids': [80, 18, 53],
#    'original_language': 'en',
#    'original_title': 'Sleepers',
#    'popularity': 12.434,
#    'title': 'Sleepers',
#    'vote_average': 7.5,
#    'overview': 'Two gangsters seek revenge on the state jail worker who during their stay at a youth prison sexually abused them. A sensational court hearing takes place to charge him for the crimes.',
#    'release_date': '1996-10-18'},
#   {'character': 'Charles Frohman',
#    'credit_id': '52fe4284c3a36847f8025327',
#    'release_date': '2004-11-11',
#    'vote_count': 2353,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.3,
#    'title': 'Finding Neverland',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'Finding Neverland',
#    'popularity': 9.334,
#    'id': 866,
#    'backdrop_path': '/sBsnLIrB0UdB7gBdmw5iJ9L1ltK.jpg',
#    'overview': "During a writing slump, playwright J.M. Barrie meets a widow and her three children—who soon become an important part of Barrie’s life and the inspiration that lead him to create his masterpiece. Peter Pan'.",
#    'poster_path': '/7VNtGDhKLefRhJWYokfP3hBh0uV.jpg'},
#   {'character': 'Captain James S. Hook',
#    'credit_id': '52fe4286c3a36847f8025be3',
#    'poster_path': '/6plGuz8L3fvkuENB0G2ZpBz6kej.jpg',
#    'id': 879,
#    'video': False,
#    'vote_count': 3087,
#    'adult': False,
#    'backdrop_path': '/rAb7vx2UauhHUmrYhZVoQxXuz37.jpg',
#    'genre_ids': [12, 14, 35, 10751],
#    'original_language': 'en',
#    'original_title': 'Hook',
#    'popularity': 12.376,
#    'title': 'Hook',
#    'vote_average': 6.9,
#    'overview': "The boy who wasn't supposed grow up—Peter Pan—does just that, becoming a soulless corporate lawyer whose workaholism could cost him his wife and kids. During his trip to see Granny Wendy in London, the vengeful Capt. Hook kidnaps Peter's kids and forces Peter to return to Neverland.",
#    'release_date': '1991-12-11'},
#   {'character': 'Carl Bernstein',
#    'credit_id': '52fe4288c3a36847f80265bd',
#    'release_date': '1976-04-04',
#    'vote_count': 809,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.7,
#    'title': "All the President's Men",
#    'genre_ids': [18, 36, 9648, 53],
#    'original_language': 'en',
#    'original_title': "All the President's Men",
#    'popularity': 18.213,
#    'id': 891,
#    'backdrop_path': '/rqM0Uq57NNOpEx7BBk7FqBfGqzc.jpg',
#    'overview': 'In the run-up to the 1972 elections, Washington Post reporter Bob Woodward covers what seems to be a minor break-in at the Democratic Party National Headquarters. He is surprised to find top lawyers already on the defense case, and the discovery of names and addresses of Republican fund organizers on the accused further arouses his suspicions. After the editor of the Post runs with the story and assigns Woodward and Carl Bernstein to it, they find the trail leading higher and higher in the Republican Party—and eventually into the White House itself.',
#    'poster_path': '/jvXiGgWyBYDfQb44spH9JPTOmAZ.jpg'},
#   {'character': 'David Sumner',
#    'credit_id': '52fe4297c3a36847f802ac27',
#    'poster_path': '/kn85ADdkCrL3I2uWfKKhxpjolU5.jpg',
#    'id': 994,
#    'video': False,
#    'vote_count': 407,
#    'adult': False,
#    'backdrop_path': '/yL7uVOyvwZeP2U0zKIE3WQqoilA.jpg',
#    'genre_ids': [80, 18, 53],
#    'original_language': 'en',
#    'original_title': 'Straw Dogs',
#    'popularity': 10.811,
#    'title': 'Straw Dogs',
#    'vote_average': 7.2,
#    'overview': "David Sumner, a mild-mannered academic from the United States, marries Amy, an Englishwoman. In order to escape a hectic stateside lifestyle, David and his wife relocate to the small town in rural Cornwall where Amy was raised. There, David is ostracized by the brutish men of the village, including Amy's old flame, Charlie. Eventually the taunts escalate, and two of the locals rape Amy. This sexual assault awakes a shockingly violent side of David.",
#    'release_date': '1971-12-29'},
#   {'character': 'Professor Jules Hilbert',
#    'credit_id': '52fe42ebc3a36847f802ccfb',
#    'poster_path': '/AtjCCvfMq9kmjwjbVwTJ0mWG7zp.jpg',
#    'id': 1262,
#    'video': False,
#    'vote_count': 1243,
#    'adult': False,
#    'backdrop_path': '/sqq5nDBcgTDrIJ3Hcqq8q4a1iut.jpg',
#    'genre_ids': [35, 18, 14, 10749],
#    'original_language': 'en',
#    'original_title': 'Stranger Than Fiction',
#    'popularity': 8.176,
#    'title': 'Stranger Than Fiction',
#    'vote_average': 7.2,
#    'overview': 'Harold Crick is a lonely IRS agent whose mundane existence is transformed when he hears a mysterious voice narrating his life.',
#    'release_date': '2006-11-10'},
#   {'character': 'Giuseppe Baldini',
#    'credit_id': '52fe42f6c3a36847f803011f',
#    'release_date': '2007-01-05',
#    'vote_count': 2356,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.2,
#    'title': 'Perfume: The Story of a Murderer',
#    'genre_ids': [80, 18, 14],
#    'original_language': 'en',
#    'original_title': 'Perfume: The Story of a Murderer',
#    'popularity': 10.036,
#    'id': 1427,
#    'backdrop_path': '/3i8bJa5yvLZW2k4sg2Cd1Yy0a1x.jpg',
#    'overview': "Jean-Baptiste Grenouille, born in the stench of 18th century Paris, develops a superior olfactory sense, which he uses to create the world's finest perfumes. However, his work takes a dark turn as he tries to preserve scents in the search for the ultimate perfume.",
#    'poster_path': '/zC9JHS6NlkJKPYFxOOqBl7fQCjT.jpg'},
#   {'character': 'Bernard Jaffe',
#    'credit_id': '52fe4303c3a36847f8033e0b',
#    'poster_path': '/xMVGVA3MAWtBcLIsfkYLa31n241.jpg',
#    'id': 1599,
#    'video': False,
#    'vote_count': 362,
#    'adult': False,
#    'backdrop_path': '/4oXV4AW6LYabqxmMZZ7gjJRP4Ej.jpg',
#    'genre_ids': [35, 10749],
#    'original_language': 'en',
#    'original_title': 'I Heart Huckabees',
#    'popularity': 8.18,
#    'title': 'I Heart Huckabees',
#    'vote_average': 6.3,
#    'overview': 'A husband-and-wife team play detective, but not in the traditional sense. Instead, the happy duo helps others solve their existential issues, the kind that keep you up at night, wondering what it all means.',
#    'release_date': '2004-09-10'},
#   {'character': 'The Conscience',
#    'credit_id': '52fe43129251416c75002647',
#    'poster_path': '/3XCzDTqh4X5YHxwys0IOpDyi7ly.jpg',
#    'id': 10047,
#    'video': False,
#    'vote_count': 747,
#    'adult': False,
#    'backdrop_path': '/xh0UGiLqfM1OfRBvmQ5AVF4h0dj.jpg',
#    'genre_ids': [12, 18, 28, 36, 10752],
#    'original_language': 'en',
#    'original_title': 'Joan of Arc',
#    'popularity': 11.561,
#    'title': 'The Messenger: The Story of Joan of Arc',
#    'vote_average': 6.3,
#    'overview': "In 1429 a teenage girl from a remote French village stood before her King with a message she claimed came from God; that she would defeat the world's greatest army and liberate her country from its political and religious turmoil. Following her mission to reclaim god's diminished kingdom - through her amazing victories until her violent and untimely death.",
#    'release_date': '1999-11-12'},
#   {'character': 'Dr. Norman Goodman',
#    'credit_id': '52fe43369251416c75007ce3',
#    'release_date': '1998-02-13',
#    'vote_count': 816,
#    'video': False,
#    'adult': False,
#    'vote_average': 6,
#    'title': 'Sphere',
#    'genre_ids': [18, 27, 9648, 878],
#    'original_language': 'en',
#    'original_title': 'Sphere',
#    'popularity': 11.722,
#    'id': 10153,
#    'backdrop_path': '/41c9Posihpr1acKmY1zfVle8yET.jpg',
#    'overview': 'The OSSA discovers a spacecraft thought to be at least 300 years old at the bottom of the ocean. Immediately following the discovery, they decide to send a team down to the depths of the ocean to study the space craft. They are the best of best, smart and logical, and the perfect choice to learn more about the spacecraft.',
#    'poster_path': '/jrjzPjKnpJq99GPePKf64k7Fzqh.jpg'},
#   {'character': 'Roscuro (voice)',
#    'credit_id': '52fe43409251416c750093d3',
#    'release_date': '2008-12-19',
#    'vote_count': 498,
#    'video': False,
#    'adult': False,
#    'vote_average': 5.8,
#    'title': 'The Tale of Despereaux',
#    'genre_ids': [12, 16, 10751],
#    'original_language': 'en',
#    'original_title': 'The Tale of Despereaux',
#    'popularity': 9.896,
#    'id': 10199,
#    'backdrop_path': '/3ZmsKrY96jFXtpOIpYOsJD8pEXF.jpg',
#    'overview': 'Once upon a time... in the far away kingdom of Dor... lived a brave and virtuous mouse with comically oversized ears who dreamt of becoming a knight. Banished from his home for having such lofty ambitions, Despereaux sets off on an amazing adventure with his good-hearted rat friend Roscuro, who leads him, at long last, on a very noble quest to rescue an endangered princess and save an entire kingdom from darkness.',
#    'poster_path': '/8Nge4rXAQzU5w9U8OvnXuuJltL9.jpg'},
#   {'character': 'Mr. Edward Magorium',
#    'credit_id': '52fe4349c3a36847f8048c23',
#    'release_date': '2007-11-14',
#    'vote_count': 697,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.2,
#    'title': "Mr. Magorium's Wonder Emporium",
#    'genre_ids': [35, 14, 10751],
#    'original_language': 'en',
#    'original_title': "Mr. Magorium's Wonder Emporium",
#    'popularity': 8.198,
#    'id': 2284,
#    'backdrop_path': '/icq8EO55IEvDo7OGCQfFXZ8l3Sv.jpg',
#    'overview': "Molly Mahoney is the awkward and insecure manager of Mr. Magorium's Wonder Emporium—the strangest, most fantastic and most wonderful toy store in the world. After Mr. Magorium bequeaths the store to her, a dark and ominous change begins to take over the once-remarkable Emporium.",
#    'poster_path': '/75m4IBZE6gUrltcDgTSBTFg68QT.jpg'},
#   {'character': 'Thomas Babington ‚Babe‘ Levy',
#    'credit_id': '52fe437f9251416c75012a15',
#    'poster_path': '/uPNgubSiri2yvBQRPtP77ViYjN.jpg',
#    'id': 10518,
#    'video': False,
#    'vote_count': 441,
#    'adult': False,
#    'backdrop_path': '/d90eG6WVgIIncfykkHPktX2Bi2M.jpg',
#    'genre_ids': [53, 18],
#    'original_language': 'en',
#    'original_title': 'Marathon Man',
#    'popularity': 8.836,
#    'title': 'Marathon Man',
#    'vote_average': 7.4,
#    'overview': 'A graduate student and obsessive runner in New York is drawn into a mysterious plot involving his brother, a member of the secretive Division.',
#    'release_date': '1976-10-06'},
#   {'character': 'Vito McMullen',
#    'credit_id': '52fe43869251416c75013c93',
#    'poster_path': '/9HhRk8eUjxUf0CDHTS9YcUk8TTB.jpg',
#    'id': 10551,
#    'video': False,
#    'vote_count': 98,
#    'adult': False,
#    'backdrop_path': '/xVTt5RHaTAuCStfAVrOCPMWA1ye.jpg',
#    'genre_ids': [28, 35, 80, 18, 53, 9648],
#    'original_language': 'en',
#    'original_title': 'Family Business',
#    'popularity': 8.375,
#    'title': 'Family Business',
#    'vote_average': 5.6,
#    'overview': "Jessie is an aging career criminal who has been in more jails, fights, schemes, and lineups than just about anyone else. His son Vito, while currently on the straight and narrow, has had a fairly shady past and is indeed no stranger to illegal activity. They both have great hope for Adam, Vito's son and Jessie's grandson, who is bright, good-looking, and without a criminal past.",
#    'release_date': '1989-12-15'},
#   {'character': 'Enrico Salvatore "Ratso" Rizzo',
#    'credit_id': '52fe4388c3a36847f805b511',
#    'poster_path': '/jEeyGsyoiRPwwxDkR1WWNT8eoyN.jpg',
#    'id': 3116,
#    'video': False,
#    'vote_count': 569,
#    'adult': False,
#    'backdrop_path': '/9Ln5wxy1yuvgIEw2hDqMld44BGH.jpg',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'Midnight Cowboy',
#    'popularity': 12.605,
#    'title': 'Midnight Cowboy',
#    'vote_average': 7.5,
#    'overview': 'Joe Buck is a wide-eyed hustler from Texas hoping to score big with wealthy New York City women; he finds a companion in Enrico "Ratso" Rizzo, an ailing swindler with a bum leg and a quixotic fantasy of escaping to Florida.',
#    'release_date': '1969-07-30'},
#   {'character': 'Jason Fister',
#    'credit_id': '52fe438ac3a36847f805c153',
#    'poster_path': '/ePgzLH1dDcFN9IFaaNNlylbGPHM.jpg',
#    'id': 3148,
#    'video': False,
#    'vote_count': 2,
#    'adult': False,
#    'backdrop_path': '/cpoupjbDLsj2f4sdkhYW8SA11Ba.jpg',
#    'genre_ids': [28, 35, 80],
#    'original_language': 'en',
#    'original_title': 'Un Dollaro per 7 vigliacchi',
#    'popularity': 0.911,
#    'title': "Madigan's Millions",
#    'vote_average': 3.5,
#    'overview': "When a deported gangster dies in Italy, the U.S. Treasury Department is very interested in the one million dollars Madigan owed the government, but managed to take to Italy with him. They send Agent Jason Phister over to Italy to nose out the million. His criteria for the job is that no one would ever guess he's an agent of the United States government.",
#    'release_date': '1968-05-30'},
#   {'character': "Bernard 'Bernie' Laplante",
#    'credit_id': '52fe43a59251416c7501878d',
#    'poster_path': '/gT4qFlAcRcMvOanRPjke3MOSZGo.jpg',
#    'id': 10699,
#    'video': False,
#    'vote_count': 204,
#    'adult': False,
#    'backdrop_path': '/caT7bZzSJbDkydsCIUH9zKDTDbt.jpg',
#    'genre_ids': [18, 35, 53, 9648],
#    'original_language': 'en',
#    'original_title': 'Hero',
#    'popularity': 8.109,
#    'title': 'Hero',
#    'vote_average': 6.3,
#    'overview': "Bernie Laplante is having a rough time. He's divorced, his ex-wife hates him and has custody of their son, the cops are setting a trap for him, then to top it all, he loses a shoe whilst rescuing passengers of a crashed jet. Being a thief who is down on his luck, Bernie takes advantage of the crash, but then someone else claims credit for the rescue.",
#    'release_date': '1992-10-02'},
#   {'character': 'Winston King',
#    'credit_id': '52fe43ad9251416c75019c89',
#    'release_date': '2003-04-25',
#    'vote_count': 210,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.3,
#    'title': 'Confidence',
#    'genre_ids': [28, 35, 80, 9648, 53],
#    'original_language': 'en',
#    'original_title': 'Confidence',
#    'popularity': 6.862,
#    'id': 10743,
#    'backdrop_path': '/yOJa3Q2CBlV1el7KoFmQJwbv39Q.jpg',
#    'overview': "What Jake Vig doesn't know just might get him killed. A sharp and polished grifter, Jake has just swindled thousands of dollars from the unsuspecting Lionel Dolby with the help of his crew. It becomes clear that Lionel wasn't just any mark, he was an accountant for eccentric crime boss Winston King. Jake and his crew will have to stay one step ahead of both the criminals and the cops to finally settle their debt.",
#    'poster_path': '/tYLBs9gB7MjShvj7CJK62fkHpE.jpg'},
#   {'character': 'Jack Crabb',
#    'credit_id': '52fe43e99251416c75022c6b',
#    'poster_path': '/gXqYGKMrAqMkmlpPh1rzwYZi7eH.jpg',
#    'id': 11040,
#    'video': False,
#    'vote_count': 250,
#    'adult': False,
#    'backdrop_path': '/tWP2LoaMRjX3Y4dDOSwE2prN423.jpg',
#    'genre_ids': [12, 37, 35, 18],
#    'original_language': 'en',
#    'original_title': 'Little Big Man',
#    'popularity': 7.857,
#    'title': 'Little Big Man',
#    'vote_average': 7.7,
#    'overview': 'Jack Crabb, looking back from extreme old age, tells of his life being raised by Indians and fighting with General Custer.',
#    'release_date': '1970-12-14'},
#   {'character': 'Wendell Rohr',
#    'credit_id': '52fe44279251416c7502ab37',
#    'poster_path': '/8tBOi178wfUptdoGqJ9iacl1RLc.jpg',
#    'id': 11329,
#    'video': False,
#    'vote_count': 616,
#    'adult': False,
#    'backdrop_path': '/mSFzYuqATKYAXIVgk6nPqyk59J7.jpg',
#    'genre_ids': [18, 53],
#    'original_language': 'en',
#    'original_title': 'Runaway Jury',
#    'popularity': 8.929,
#    'title': 'Runaway Jury',
#    'vote_average': 6.9,
#    'overview': 'A juror on the inside and a woman on the outside manipulate a court trial involving a major gun manufacturer.',
#    'release_date': '2003-10-09'},
#   {'character': 'Louis Dega',
#    'credit_id': '52fe442ec3a36847f80870d3',
#    'release_date': '1973-12-16',
#    'vote_count': 877,
#    'video': False,
#    'adult': False,
#    'vote_average': 8,
#    'title': 'Papillon',
#    'genre_ids': [80, 18],
#    'original_language': 'en',
#    'original_title': 'Papillon',
#    'popularity': 12.396,
#    'id': 5924,
#    'backdrop_path': '/w6XYdZIXZlMNL2efDXdXI6q4lhm.jpg',
#    'overview': 'A man befriends a fellow criminal as the two of them begin serving their sentence on a dreadful prison island, which inspires the man to plot his escape.',
#    'poster_path': '/q1tmTQvEWbJgf8eccX1XWXxWKkK.jpg'},
#   {'character': 'Himself',
#    'credit_id': '582cd63dc3a3683e490030bb',
#    'release_date': '2018-01-22',
#    'vote_count': 1,
#    'video': False,
#    'adult': False,
#    'vote_average': 0,
#    'title': 'Hal',
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'Hal',
#    'popularity': 2.05,
#    'id': 322520,
#    'backdrop_path': '/qBVVCW6CZFF14se1cTZ3F2TsyET.jpg',
#    'overview': "Hal Ashby's obsessive genius led to an unprecedented string of Oscar®-winning classics, including Harold and Maude, Shampoo and Being There. But as contemporaries Coppola, Scorsese and Spielberg rose to blockbuster stardom in the 1980s, Ashby's uncompromising nature played out as a cautionary tale of art versus commerce.",
#    'poster_path': '/zwtegwJ5iLEpnd6UVzyYlJHsH33.jpg'},
#   {'character': 'Ben Floss',
#    'credit_id': '52fe44549251416c9100cd77',
#    'poster_path': '/paSG3UmjxU0ZpzKWYk3AMqjZWyk.jpg',
#    'id': 31005,
#    'video': False,
#    'vote_count': 110,
#    'adult': False,
#    'backdrop_path': '/53f29bdN46K7UT17OCYQ0sBZBdm.jpg',
#    'genre_ids': [10749, 18],
#    'original_language': 'en',
#    'original_title': 'Moonlight Mile',
#    'popularity': 8.662,
#    'title': 'Moonlight Mile',
#    'vote_average': 6.3,
#    'overview': 'As he copes with the death of his fiancee along with her parents, a young man must figure out what he wants out of life.',
#    'release_date': '2002-09-27'},
#   {'character': 'Wally Stanton',
#    'credit_id': '52fe44689251416c9100f9a9',
#    'poster_path': '/hluywh88zMF9uYroBTNIrmozgQ5.jpg',
#    'id': 31200,
#    'video': False,
#    'vote_count': 17,
#    'adult': False,
#    'backdrop_path': '/wINvqci7jSC8IhsrrBulEd1sUhN.jpg',
#    'genre_ids': [18, 9648, 53],
#    'original_language': 'en',
#    'original_title': 'Agatha',
#    'popularity': 2.727,
#    'title': 'Agatha',
#    'vote_average': 6.4,
#    'overview': 'England, 1926. An American journalist looks for mystery writer Agatha Christie when she suddenly disappears without explanation, leaving no trace.',
#    'release_date': '1979-02-09'},
#   {'character': 'Max Dembo',
#    'credit_id': '52fe4468c3a368484e02153b',
#    'poster_path': '/qht8SAqj7dEeEzv9yXalFB35ycb.jpg',
#    'id': 23397,
#    'video': False,
#    'vote_count': 57,
#    'adult': False,
#    'backdrop_path': '/seDvAlXiab7DQ45hiTYKRSZJSbT.jpg',
#    'genre_ids': [80, 18],
#    'original_language': 'en',
#    'original_title': 'Straight Time',
#    'popularity': 4.953,
#    'title': 'Straight Time',
#    'vote_average': 7.2,
#    'overview': 'After being released on parole, a burglar attempts to go straight, get a regular job, and just go by the rules. He soon finds himself back in jail at the hands of a power-hungry parole officer.',
#    'release_date': '1978-03-18'},
#   {'character': 'Sam Daniels',
#    'credit_id': '52fe4469c3a36847f80949b5',
#    'poster_path': '/4KymNvlWR0XF0sqX2BWRd9Z3yXR.jpg',
#    'id': 6950,
#    'video': False,
#    'vote_count': 927,
#    'adult': False,
#    'backdrop_path': '/wrlZRyyOnD24KQzo3OVi4lWyqdF.jpg',
#    'genre_ids': [28, 18, 878, 53],
#    'original_language': 'en',
#    'original_title': 'Outbreak',
#    'popularity': 10.65,
#    'title': 'Outbreak',
#    'vote_average': 6.4,
#    'overview': "A deadly airborne virus finds its way into the USA and starts killing off people at an epidemic rate. Col Sam Daniels' job is to stop the virus spreading from a small town, which must be quarantined, and to prevent an over reaction by the White House.",
#    'release_date': '1995-03-10'},
#   {'character': "Walt 'Teach' Teacher",
#    'credit_id': '52fe44859251416c91013a7d',
#    'release_date': '1996-09-13',
#    'vote_count': 22,
#    'video': False,
#    'adult': False,
#    'vote_average': 5.5,
#    'title': 'American Buffalo',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'American Buffalo',
#    'popularity': 2.586,
#    'id': 31546,
#    'backdrop_path': '/sztvmnlzAhW6iphXAYrCnwBAYid.jpg',
#    'overview': 'Three inner-city losers plan a robbery of a valuable coin in a seedy second-hand junk shop.',
#    'poster_path': '/sWrsVr9x8V9Kc0sIfrtoMxznJvQ.jpg'},
#   {'character': 'Ted Kramer',
#    'credit_id': '52fe44b49251416c7503e2f5',
#    'poster_path': '/oyYtH37h8rLUxlERoD49losVvlg.jpg',
#    'id': 12102,
#    'video': False,
#    'vote_count': 1028,
#    'adult': False,
#    'backdrop_path': '/aE33zDunu8FTj76IXqJmHVbcRWg.jpg',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'Kramer vs. Kramer',
#    'popularity': 7.291,
#    'title': 'Kramer vs. Kramer',
#    'vote_average': 7.5,
#    'overview': 'Ted Kramer is a career man for whom his work comes before his family. His wife Joanna cannot take this anymore, so she decides to leave him. Ted is now faced with the tasks of housekeeping and taking care of himself and their young son Billy.',
#    'release_date': '1979-12-19'},
#   {'character': 'Shifu (voice)',
#    'credit_id': '52fe4500c3a36847f80b6cab',
#    'poster_path': '/2Paj1nufT0jeSY0G4u3RC31HIGT.jpg',
#    'id': 9502,
#    'video': False,
#    'vote_count': 6409,
#    'adult': False,
#    'backdrop_path': '/pmLEmMLYCreFAxfdCt5uO1wDgSi.jpg',
#    'genre_ids': [12, 16, 10751, 35],
#    'original_language': 'en',
#    'original_title': 'Kung Fu Panda',
#    'popularity': 19.193,
#    'title': 'Kung Fu Panda',
#    'vote_average': 7.1,
#    'overview': 'When the Valley of Peace is threatened, lazy Po the panda discovers his destiny as the "chosen one" and trains to become a kung fu hero, but transforming the unsleek slacker into a brave warrior won\'t be easy. It\'s up to Master Shifu and the Furious Five -- Tigress, Crane, Mantis, Viper and Monkey -- to give it a try.',
#    'release_date': '2008-06-05'},
#   {'character': 'Willy Loman',
#    'credit_id': '52fe45079251416c7504946d',
#    'release_date': '1985-08-16',
#    'vote_count': 68,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.7,
#    'title': 'Death of a Salesman',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'Death of a Salesman',
#    'popularity': 4.214,
#    'id': 12615,
#    'backdrop_path': '/t1hWOaiaPn9jAH6DyvgpyhH0tA7.jpg',
#    'overview': "Salesman Willy Loman is in a crisis. He's about to lose his job, he can't pay his bills, and his sons Biff and Happy don't respect him and can't seem to live up to their potential. He wonders what went wrong and how he can make things up to his family.",
#    'poster_path': '/tIRmjfaLmVHjGFaIcNGD3hggvbO.jpg'},
#   {'character': 'Dutch Schultz',
#    'credit_id': '52fe450e9251416c7504a301',
#    'poster_path': '/wMIXsvxco8ob3b6RE9otuui3jQO.jpg',
#    'id': 12647,
#    'video': False,
#    'vote_count': 98,
#    'adult': False,
#    'backdrop_path': '/AqsO0lmxGaF9LbSlz2u5EeVpPHJ.jpg',
#    'genre_ids': [18, 28, 53, 80],
#    'original_language': 'en',
#    'original_title': 'Billy Bathgate',
#    'popularity': 9.499,
#    'title': 'Billy Bathgate',
#    'vote_average': 5.7,
#    'overview': 'In the year 1935, a teen named Billy Bathgate finds first love while becoming the protégé of fledgling gangster Dutch Schultz.',
#    'release_date': '1991-11-01'},
#   {'character': 'Chuck Clarke',
#    'credit_id': '52fe45179251416c7504b651',
#    'poster_path': '/fttHfkyvPtTP1LU8RodBIvyUN8A.jpg',
#    'id': 12704,
#    'video': False,
#    'vote_count': 56,
#    'adult': False,
#    'backdrop_path': '/jfdi1qRZOpVgpPgye6jTB8kdJuh.jpg',
#    'genre_ids': [28, 12, 35],
#    'original_language': 'en',
#    'original_title': 'Ishtar',
#    'popularity': 5.188,
#    'title': 'Ishtar',
#    'vote_average': 4.4,
#    'overview': 'Two terrible lounge singers get booked to play a gig in a Moroccan hotel but somehow become pawns in an international power play between the CIA, the Emir of Ishtar, and the rebels trying to overthrow his regime',
#    'release_date': '1987-05-15'},
#   {'character': 'Meyer Lansky',
#    'credit_id': '52fe451ec3a36847f80bd76f',
#    'poster_path': '/v19DsrJb0TJxTCdgaUzzuvOjfeD.jpg',
#    'id': 9700,
#    'video': False,
#    'vote_count': 45,
#    'adult': False,
#    'backdrop_path': '/jw13PODz15BjaFEE4lL67kiXACE.jpg',
#    'genre_ids': [18, 10749],
#    'original_language': 'en',
#    'original_title': 'The Lost City',
#    'popularity': 3.703,
#    'title': 'The Lost City',
#    'vote_average': 6.2,
#    'overview': "In Havana, Cuba in the late 1950's, a wealthy family, one of whose sons is a prominent nightclub owner, is caught in the violent transition from the oppressive regime of Batista to the Marxist government of Fidel Castro. Castro's regime ultimately leads the nightclub owner to flee to New York.",
#    'release_date': '2005-09-03'},
#   {'character': 'Max Brackett',
#    'credit_id': '52fe4529c3a36847f80bfda1',
#    'release_date': '1997-11-07',
#    'vote_count': 136,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.1,
#    'title': 'Mad City',
#    'genre_ids': [28, 18, 53],
#    'original_language': 'en',
#    'original_title': 'Mad City',
#    'popularity': 6.496,
#    'id': 9770,
#    'backdrop_path': '/5rEDVAEmOsU7jOSVAlYhCpSPmgW.jpg',
#    'overview': 'A misguided museum guard who loses his job and then tries to get it back at gunpoint is thrown into the fierce world of ratings-driven TV gone mad.',
#    'poster_path': '/3aBKgBnqzg3ZUpGCHXzlVs2xINU.jpg'},
#   {'character': 'Lenny Bruce',
#    'credit_id': '52fe452cc3a368484e04c795',
#    'release_date': '1974-11-10',
#    'vote_count': 93,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.4,
#    'title': 'Lenny',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'Lenny',
#    'popularity': 7.4,
#    'id': 27094,
#    'backdrop_path': '/9845oZ76y6PZ9jIldL4UrLaOjMc.jpg',
#    'overview': 'The story of acerbic 1960s comic Lenny Bruce, whose groundbreaking, no-holds-barred style and social commentary was often deemed by the Establisment as too obscene for the public.',
#    'poster_path': '/vwC9cBoVg82D9q2J3BGaZ0VlgkR.jpg'},
#   {'character': 'Critic (uncredited)',
#    'credit_id': '571f7afdc3a36856a70016e5',
#    'release_date': '2004-12-17',
#    'vote_count': 3139,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.8,
#    'title': "Lemony Snicket's A Series of Unfortunate Events",
#    'genre_ids': [12, 35, 10751],
#    'original_language': 'en',
#    'original_title': "Lemony Snicket's A Series of Unfortunate Events",
#    'popularity': 25.146,
#    'id': 11774,
#    'backdrop_path': '/iH65TTlQtDKCFZ9FZI04jz6xKPF.jpg',
#    'overview': 'Three wealthy children\'s parents are killed in a fire. When they are sent to a distant relative, they find out that he is plotting to kill them and seize their fortune.  This movie is extremely alarming, an expression which here means "a thrilling misadventure involving three ingenious orphans and a villainous actor named Count Olaf (Jim Carrey) who wants their enormous fortune."  It includes a suspicious fire, delicious pasta, Jim Carrey, poorly behaved looches, Billy Connolly, an incredibly deadly viper, Meryl Streep, and the voice of an imposter named Jude Law.',
#    'poster_path': '/dHQMAj9E2G2ewjN1aCOPubsZaj1.jpg'},
#   {'character': 'Ben Braddock',
#    'credit_id': '52fe46369251416c9104d0a7',
#    'poster_path': '/AuFvrbtWSPiBPIv9ewH2DV4nhCD.jpg',
#    'id': 37247,
#    'video': False,
#    'vote_count': 1620,
#    'adult': False,
#    'backdrop_path': '/sEWKMIlgUCCb2n5mT0Mf71DRKLR.jpg',
#    'genre_ids': [35, 18],
#    'original_language': 'en',
#    'original_title': 'The Graduate',
#    'popularity': 11.111,
#    'title': 'The Graduate',
#    'vote_average': 7.7,
#    'overview': 'Benjamin, a recent college graduate is very worried about his future, he then finds himself in a love triangle with an older woman and her daughter.',
#    'release_date': '1967-12-21'},
#   {'character': 'John',
#    'credit_id': '52fe4661c3a368484e08d6cd',
#    'poster_path': '/uKyRiUUMQlevhArQM4VTViPtOUa.jpg',
#    'id': 61742,
#    'video': False,
#    'vote_count': 10,
#    'adult': False,
#    'backdrop_path': '/w6nWWj0PezxRwhtOtC0jAbjdIOf.jpg',
#    'genre_ids': [18, 10749],
#    'original_language': 'en',
#    'original_title': 'John and Mary',
#    'popularity': 1.4,
#    'title': 'John and Mary',
#    'vote_average': 6.8,
#    'overview': 'John and Mary meet in a singles bar, sleep together, and spend the next day getting to know each other.',
#    'release_date': '1969-12-14'},
#   {'character': 'Shifu (voice)',
#    'credit_id': '52fe46859251416c7507aee5',
#    'poster_path': '/AlSqOP7VnEhc2x170V2eZMTgzsA.jpg',
#    'id': 15854,
#    'video': False,
#    'vote_count': 201,
#    'adult': False,
#    'backdrop_path': '/Ag4zcxKZwBfsmKgY8jAWzWpyGXH.jpg',
#    'genre_ids': [16, 35, 10751],
#    'original_language': 'en',
#    'original_title': 'Kung Fu Panda: Secrets of the Furious Five',
#    'popularity': 11.254,
#    'title': 'Kung Fu Panda: Secrets of the Furious Five',
#    'vote_average': 6.6,
#    'overview': "Ordered to teach a martial arts class of rambunctious bunny kittens, Po tells stories of each of the Furious Five's pasts.",
#    'release_date': '2008-11-08'},
#   {'character': 'Peter (Archive Footage)',
#    'credit_id': '52fe46a69251416c7507f11f',
#    'poster_path': '/8eG421e0yf25xttvIMcysmTgT7J.jpg',
#    'id': 16130,
#    'video': False,
#    'vote_count': 97,
#    'adult': False,
#    'backdrop_path': '/wD7pJC0ZpGAzBSczXnf3dHuexLq.jpg',
#    'genre_ids': [35],
#    'original_language': 'fr',
#    'original_title': 'La classe américaine',
#    'popularity': 5.961,
#    'title': 'La classe américaine',
#    'vote_average': 7.9,
#    'overview': 'George Abitbol, "the Most Classy Man on Earth", dies sputtering his famous last words: "Crappy world!" What the heck did he mean? Reporters Steven, Peter and Dave investigate. La Classe Américaine is a montage of scenes taken from the Warner Bros. catalog and dubbed to fit the narration of what is arguably the greatest story ever told.',
#    'release_date': '1993-12-30'},
#   {'character': 'Harvey Shine',
#    'credit_id': '52fe46d19251416c75084865',
#    'poster_path': '/5hvK3SZ35Vr5jj93bYhE57dPwI.jpg',
#    'id': 16409,
#    'video': False,
#    'vote_count': 131,
#    'adult': False,
#    'backdrop_path': '/5MbPeCjdeFDCYAXM0WiPKPfNuXm.jpg',
#    'genre_ids': [18, 35, 10749],
#    'original_language': 'en',
#    'original_title': 'Last Chance Harvey',
#    'popularity': 5.658,
#    'title': 'Last Chance Harvey',
#    'vote_average': 6.2,
#    'overview': "In London for his daughter's wedding, a struggling jingle-writer, Harvey Shine, misses his plane to New York, and thus loses his job. While drowning his sorrows in the airport pub, Harvey meets Kate, a British government worker stuck in an endless cycle of work, phone calls from her mother, and blind dates. A connection forms between the unhappy pair, who soon find themselves falling in love.",
#    'release_date': '2008-12-25'},
#   {'character': 'Izzy Panofsky',
#    'credit_id': '52fe470ec3a36847f81211b9',
#    'poster_path': '/kJMNRVHqJkumHNT1sW9geSj1m52.jpg',
#    'id': 46829,
#    'video': False,
#    'vote_count': 219,
#    'adult': False,
#    'backdrop_path': '/sbB2v0OgPxbNjsoiKFzg304izWF.jpg',
#    'genre_ids': [35, 18],
#    'original_language': 'en',
#    'original_title': "Barney's Version",
#    'popularity': 5.393,
#    'title': "Barney's Version",
#    'vote_average': 7.2,
#    'overview': 'The picaresque and touching story of the politically incorrect, fully lived life of the impulsive, irascible and fearlessly blunt Barney Panofsky.',
#    'release_date': '2011-01-14'},
#   {'character': 'Bernie Focker',
#    'credit_id': '52fe471a9251416c9106a131',
#    'release_date': '2010-12-21',
#    'vote_count': 1985,
#    'video': False,
#    'adult': False,
#    'vote_average': 5.6,
#    'title': 'Little Fockers',
#    'genre_ids': [35, 10749],
#    'original_language': 'en',
#    'original_title': 'Little Fockers',
#    'popularity': 6.964,
#    'id': 39451,
#    'backdrop_path': '/gpodYxsJZ6OVlpPo0fYkubTBWx9.jpg',
#    'overview': "It has taken 10 years, two little Fockers with wife Pam and countless hurdles for Greg to finally get in with his tightly wound father-in-law, Jack. After the cash-strapped dad takes a job moonlighting for a drug company, Jack's suspicions about his favorite male nurse come roaring back. When Greg and Pam's entire clan descends for the twins' birthday party, Greg must prove to the skeptical Jack that he's fully capable as the man of the house.",
#    'poster_path': '/qixmjH8fLD9IkboPO7FKxAqzwRJ.jpg'},
#   {'character': 'Himself/Narrator',
#    'credit_id': '52fe47319251416c9106d085',
#    'poster_path': '/zvkRHyLiS2iX9j49p7iVQ8eAUkS.jpg',
#    'id': 39786,
#    'video': False,
#    'vote_count': 8,
#    'adult': False,
#    'backdrop_path': '/y4OGLKWptwGVhSbILfkuofvuDN0.jpg',
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'Visual Acoustics',
#    'popularity': 1.743,
#    'title': 'Visual Acoustics',
#    'vote_average': 7.8,
#    'overview': "Visual Acoustics celebrates the life and career of Julius Shulman, the world's greatest architectural photographer, whose images brought modern architecture to the American mainstream. Shulman, who passed away this year, captured the work of nearly every modern and progressive architect since the 1930s including Frank Lloyd Wright, Richard Neutra, John Lautner and Frank Gehry. His images epitomized the singular beauty of Southern California's modernist movement and brought its iconic structures to the attention of the general public. This unique film is both a testament to the evolution of modern architecture and a joyful portrait of the magnetic, whip-smart gentleman who chronicled it with his unforgettable images.",
#    'release_date': '2009-10-09'},
#   {'character': 'Shifu (voice)',
#    'credit_id': '52fe4795c3a36847f813d91b',
#    'poster_path': '/Fzyy2dauoKxjUzUPYYo3kJkJAW.jpg',
#    'id': 49444,
#    'video': False,
#    'vote_count': 3798,
#    'adult': False,
#    'backdrop_path': '/eyiE1vuizMKVu8MoZkg2xsramFl.jpg',
#    'genre_ids': [16, 10751],
#    'original_language': 'en',
#    'original_title': 'Kung Fu Panda 2',
#    'popularity': 14.72,
#    'title': 'Kung Fu Panda 2',
#    'vote_average': 6.8,
#    'overview': 'Po is now living his dream as The Dragon Warrior, protecting the Valley of Peace alongside his friends and fellow kung fu masters, The Furious Five - Tigress, Crane, Mantis, Viper and Monkey. But Po’s new life of awesomeness is threatened by the emergence of a formidable villain, who plans to use a secret, unstoppable weapon to conquer China and destroy kung fu. It is up to Po and The Furious Five to journey across China to face this threat and vanquish it. But how can Po stop a weapon that can stop kung fu? He must look to his past and uncover the secrets of his mysterious origins; only then will he be able to unlock the strength he needs to succeed.',
#    'release_date': '2011-05-25'},
#   {'character': 'Himself',
#    'credit_id': '52fe47c49251416c91074f8f',
#    'poster_path': '/9fbhUV6XgBhMQN5RPmv3xSHRdNr.jpg',
#    'id': 80489,
#    'video': False,
#    'vote_count': 4,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'es',
#    'original_title': 'El Rebelde Magnífico',
#    'popularity': 1.4,
#    'title': 'The Magnificent Rebel',
#    'vote_average': 5.8,
#    'overview': "A 1973 mini-documentary about the movie 'Papillon', a behind-the-scenes feature.",
#    'release_date': '1973-01-01'},
#   {'character': 'Shifu (voice)',
#    'credit_id': '52fe47c6c3a36847f8147901',
#    'poster_path': '/gp18R42TbSUlw9VnXFqyecm52lq.jpg',
#    'id': 50393,
#    'video': False,
#    'vote_count': 118,
#    'adult': False,
#    'backdrop_path': '/a14RyRGC3kz7YeQtvphuYMtou9v.jpg',
#    'genre_ids': [16, 10751, 10770],
#    'original_language': 'en',
#    'original_title': 'Kung Fu Panda Holiday',
#    'popularity': 11.576,
#    'title': 'Kung Fu Panda Holiday',
#    'vote_average': 6.5,
#    'overview': "The Winter Feast is Po's favorite holiday. Every year he and his father hang decorations, cook together, and serve noodle soup to the villagers. But this year Shifu informs Po that as Dragon Warrior, it is his duty to host the formal Winter Feast at the Jade Palace. Po is caught between his obligations as the Dragon Warrior and his family traditions: between Shifu and Mr. Ping.",
#    'release_date': '2010-11-26'},
#   {'character': 'Shifu (voice)',
#    'credit_id': '52fe47ef9251416c9107a96b',
#    'poster_path': '/kU8szr8xUWdMkVXifAw9r5tsuOT.jpg',
#    'id': 81003,
#    'video': False,
#    'vote_count': 127,
#    'adult': False,
#    'backdrop_path': '/bafBiUHLbjlIwedr3tH14aK1B9F.jpg',
#    'genre_ids': [16, 28],
#    'original_language': 'en',
#    'original_title': 'Kung Fu Panda: Secrets of the Masters',
#    'popularity': 8.26,
#    'title': 'Kung Fu Panda: Secrets of the Masters',
#    'vote_average': 6.4,
#    'overview': "Po and the Furious Five uncover the legend of three of kung fu's greatest heroes: Master Thundering Rhino, Master Storming Ox, and Master Croc.",
#    'release_date': '2011-12-12'},
#   {'character': 'Milquetoast the Cross-Dressing Cockroach',
#    'credit_id': '52fe483ec3a36847f815dcf1',
#    'poster_path': '/w9l43IAwYtRiwZQp2Nez1ht2393.jpg',
#    'id': 52691,
#    'video': False,
#    'vote_count': 17,
#    'adult': False,
#    'backdrop_path': '/tjWhCYzZpy5GqFulG8eQoK5juoP.jpg',
#    'genre_ids': [16, 35],
#    'original_language': 'en',
#    'original_title': 'A Wish for Wings That Work',
#    'popularity': 1.913,
#    'title': 'A Wish for Wings That Work',
#    'vote_average': 6,
#    'overview': 'Opus the Penguin struggles to achieve his seemingly impossible dream to be able to fly.',
#    'release_date': '1991-12-18'},
#   {'character': 'Hap',
#    'credit_id': '58c7ffbe92514179f700e938',
#    'poster_path': '/bDMkt7pLEizWbkxSYJsdCtBdAEY.jpg',
#    'id': 247924,
#    'video': False,
#    'vote_count': 2,
#    'adult': False,
#    'backdrop_path': '/P5mSf71hpyGrX6pGadhXvTpu3W.jpg',
#    'genre_ids': [35],
#    'original_language': 'en',
#    'original_title': 'The Tiger Makes Out',
#    'popularity': 0.6,
#    'title': 'The Tiger Makes Out',
#    'vote_average': 6.3,
#    'overview': "During a typically disaster-filled day, Ben Harris, an angry and frustrated bachelor mailman living in a cluttered Greenwich Village basement, learns he has been paying rent to a woman who hasn't owned his building in 6 years. No longer able to endure the injustices of society, he decides to activate the ferocious tiger within himself by abducting a helpless female and dragging her back to his lair.",
#    'release_date': '1967-08-18'},
#   {'character': 'Georgie Soloway',
#    'credit_id': '52fe48dd9251416c750b5c05',
#    'poster_path': '/aB5VRyCd18aOHKC8YAP8VKWZ7S8.jpg',
#    'id': 91607,
#    'video': False,
#    'vote_count': 5,
#    'adult': False,
#    'backdrop_path': '/hgTXyowOnfplAYMsQCqDRPR658w.jpg',
#    'genre_ids': [18, 35],
#    'original_language': 'en',
#    'original_title': 'Who Is Harry Kellerman and Why Is He Saying Those Terrible Things About Me?',
#    'popularity': 0.757,
#    'title': 'Who Is Harry Kellerman and Why Is He Saying Those Terrible Things About Me?',
#    'vote_average': 4.5,
#    'overview': 'Georgie Soloway, a pop hit love song writer who cannot love, himself, or others. He spends his days with various women flying his plane, and dropping in to the world around him.',
#    'release_date': '1971-06-15'},
#   {'character': 'Narrator',
#    'credit_id': '52fe4964c3a368484e129181',
#    'poster_path': '/eRmsl1MTN8W83dIOTg1Xv4phTY.jpg',
#    'id': 77259,
#    'video': False,
#    'vote_count': 2,
#    'adult': False,
#    'backdrop_path': '/sKqkYKw8Kre6qEySZBk9kRbOgEi.jpg',
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'Jews and Baseball: An American Love Story',
#    'popularity': 0.6,
#    'title': 'Jews and Baseball: An American Love Story',
#    'vote_average': 6,
#    'overview': 'Actor Dustin Hoffman narrates this decade-spanning documentary that highlights the contributions of Jewish Americans to the most American sport of them all: baseball. Highlights include a rare interview with legendary pitcher Sandy Koufax.',
#    'release_date': '2010-01-01'},
#   {'character': 'Alfredo',
#    'credit_id': '52fe499cc3a36847f81a393d',
#    'poster_path': '/mZniVpIFwLibRUMt1DeDorBk8d0.jpg',
#    'id': 59855,
#    'video': False,
#    'vote_count': 11,
#    'adult': False,
#    'backdrop_path': '/bSZu10Hau7V9Zjv0iUGbT11WSRf.jpg',
#    'genre_ids': [35, 10749],
#    'original_language': 'it',
#    'original_title': 'Alfredo, Alfredo',
#    'popularity': 2.306,
#    'title': 'Alfredo, Alfredo',
#    'vote_average': 6.3,
#    'overview': 'Alfredo, a timid young Italian, lusts after and woos the beautiful Maria Rosa. But when he manages to marry her, he discovers life is not nearly so blissful as he expected.',
#    'release_date': '1973-12-17'},
#   {'character': 'Shifu (voice)',
#    'credit_id': '52fe4a8b9251416c750e5a39',
#    'release_date': '2016-01-29',
#    'vote_count': 3101,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.7,
#    'title': 'Kung Fu Panda 3',
#    'genre_ids': [28, 12, 16, 35, 10751],
#    'original_language': 'en',
#    'original_title': 'Kung Fu Panda 3',
#    'popularity': 15.407,
#    'id': 140300,
#    'backdrop_path': '/eHWmEUP4fa7h1Fe7TXfTL7ncDl8.jpg',
#    'overview': 'Continuing his "legendary adventures of awesomeness", Po must face two hugely epic, but different threats: one supernatural and the other a little closer to his home.',
#    'poster_path': '/MZFPacfKzgisnPoJIPEFZUXBBT.jpg'},
#   {'character': 'Narrator',
#    'credit_id': '52fe4b96c3a368484e19042b',
#    'poster_path': '/l1T2LL8t9IXSambMnKr7IvhyHEL.jpg',
#    'id': 132507,
#    'video': False,
#    'vote_count': 1,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'Against the Tide',
#    'popularity': 0.623,
#    'title': 'Against the Tide',
#    'vote_average': 7,
#    'overview': "'Against The Tide' examines the conflict that erupted in the American Jewish community over the best means to rescue the European Jews trying to escape the Holocaust. It tells the little known story of Peter Bergson, who tirelessly stood up against American Jewish leaders in the late 30's and early 40's in an effort to save the Jews of Europe.",
#    'release_date': '2009-09-09'},
#   {'character': 'Himself',
#    'credit_id': '52fe4d539251416c75137651',
#    'poster_path': '/vCJtVW6lZJDn2XiBhWSyVmnUvYj.jpg',
#    'id': 189203,
#    'video': False,
#    'vote_count': 3,
#    'adult': False,
#    'backdrop_path': '/1w5StkmetGWAp2yqowow06W0tMZ.jpg',
#    'genre_ids': [99, 10770, 36],
#    'original_language': 'en',
#    'original_title': "All the President's Men Revisited",
#    'popularity': 0.706,
#    'title': "All the President's Men Revisited",
#    'vote_average': 7.5,
#    'overview': "The Watergate case was the original game changer of America politics. How has Watergate changed the Presidency? What effect has the scandal had on our political leaders? And has hope and optimism forever been replaced in our national dialogue by doubt and cynicism? In 1973, Watergate's most pivotal year, reporters Bob Woodward and Carl Bernstein doggedly investigated the scandal exposing the long, twisted trail of cover-ups and lies.",
#    'release_date': '2013-04-21'},
#   {'character': '',
#    'credit_id': '52fe4eb5c3a36847f82a2f4b',
#    'poster_path': '/wHuMSwUuOK1b7OnB2o8htukGZbu.jpg',
#    'id': 241291,
#    'video': False,
#    'vote_count': 1,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'original_language': 'en',
#    'original_title': 'The Shakespeare Sessions',
#    'popularity': 0.824,
#    'title': 'The Shakespeare Sessions',
#    'vote_average': 7,
#    'overview': 'Major film and television stars re-enact famous scenes from the plays of William Shakespeare .',
#    'release_date': '2003-01-01'},
#   {'character': '',
#    'credit_id': '52fe4f3ec3a36847f82c7e21',
#    'poster_path': '/pYocJ7JYPLcY5vCMQt6jAPKYG1y.jpg',
#    'id': 249141,
#    'video': False,
#    'vote_count': 1,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99, 10770],
#    'original_language': 'en',
#    'original_title': 'The First 100 Years: A Celebration of American Movies',
#    'popularity': 1.4,
#    'title': 'The First 100 Years: A Celebration of American Movies',
#    'vote_average': 10,
#    'overview': 'HBO documentary about movies',
#    'release_date': '1995-06-05'},
#   {'character': 'Riva',
#    'credit_id': '52fe4db6c3a368484e1f8993',
#    'release_date': '2014-05-09',
#    'vote_count': 1865,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.1,
#    'title': 'Chef',
#    'genre_ids': [35],
#    'original_language': 'en',
#    'original_title': 'Chef',
#    'popularity': 9.756,
#    'id': 212778,
#    'backdrop_path': '/sbH9aJV7fqhRaazCSWuOwNDIf1m.jpg',
#    'overview': "When Chef Carl Casper suddenly quits his job at a prominent Los Angeles restaurant after refusing to compromise his creative integrity for its controlling owner, he is left to figure out what's next. Finding himself in Miami, he teams up with his ex-wife, his friend and his son to launch a food truck. Taking to the road, Chef Carl goes back to his roots to reignite his passion for the kitchen -- and zest for life and love.",
#    'poster_path': '/dwweMX2MqYOYGg2Z2lZ8f6uopcg.jpg'},
#   {'character': 'Mr. Hoppy',
#    'credit_id': '549dce12c3a3680b27005608',
#    'poster_path': '/uaz3IDv0AWJvzUuGucTQAFNbqxx.jpg',
#    'id': 313867,
#    'video': False,
#    'vote_count': 59,
#    'adult': False,
#    'backdrop_path': '/iucckhzSCUCyQjg4hp1hiY0G9ma.jpg',
#    'genre_ids': [10749, 35],
#    'original_language': 'en',
#    'original_title': "Roald Dahl's Esio Trot",
#    'popularity': 3.97,
#    'title': "Roald Dahl's Esio Trot",
#    'vote_average': 7.1,
# ...
#    'vote_count': 0,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [10751, 16, 14],
#    'original_language': 'en',
#    'original_title': 'Tuesday',
#    'popularity': 0.6,
#    'title': 'Tuesday',
#    'vote_average': 0,
#    'overview': 'On a magical Tuesday night, a group of frogs take off on a journey through the nearby neighborhood.',
#    'release_date': '2001-09-04'},
#   {'character': 'Interviewee',
#    'credit_id': '5ab9bed1c3a36871d600e150',
#    'poster_path': None,
#    'id': 514416,
#    'video': False,
#    'vote_count': 0,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'The Graduate at 25',
#    'popularity': 0.6,
#    'title': 'The Graduate at 25',
#    'vote_average': 0,
#    'overview': 'A featurette on the making of the 1967 film "The Graduate."',
#    'release_date': '1992-01-01'},
#   {'character': 'Mumbles',
#    'credit_id': '5abbdc56c3a368435f015cc0',
#    'poster_path': '/4UfKEGnj9jPWV11LNKBXTgge3We.jpg',
#    'id': 8592,
#    'video': False,
#    'vote_count': 437,
#    'adult': False,
#    'backdrop_path': '/m6ciWmewDXT9vvb0ogLiuKhE7H.jpg',
#    'genre_ids': [12, 28, 35, 53, 80],
#    'original_language': 'en',
#    'original_title': 'Dick Tracy',
#    'popularity': 9.938,
#    'title': 'Dick Tracy',
#    'vote_average': 6.1,
#    'overview': "The comic strip detective finds his life vastly complicated when Breathless Mahoney makes advances towards him while he is trying to battle Big Boy Caprice's united mob.",
#    'release_date': '1990-06-15'},
#   {'character': '',
#    'credit_id': '5b106a2b0e0a26306a00ca8a',
#    'poster_path': '/bMOtCPIZOJb9y3P3JxYvs1AEd47.jpg',
#    'id': 513814,
#    'video': False,
#    'vote_count': 0,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'The Crowd Around the Cowboy',
#    'popularity': 1.4,
#    'title': 'The Crowd Around the Cowboy',
#    'vote_average': 0,
#    'overview': 'A short documentary made on location during the filming of John Schlesinger\'s 1969 film "Midnight Cowboy."',
#    'release_date': '1969-01-01'},
#   {'character': 'Interviewee',
#    'credit_id': '5b106db99251415ebb00a616',
#    'poster_path': None,
#    'id': 527619,
#    'video': False,
#    'vote_count': 0,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'After Midnight: Reflecting on a Classic 35 Years Later',
#    'popularity': 0.6,
#    'title': 'After Midnight: Reflecting on a Classic 35 Years Later',
#    'vote_average': 0,
#    'overview': 'Documentary about the making of the 1969 film "Midnight Cowboy".',
#    'release_date': '2006-02-21'},
#   {'character': 'Interviewee',
#    'credit_id': '5b1070240e0a26308e00bae8',
#    'poster_path': None,
#    'id': 527620,
#    'video': False,
#    'vote_count': 0,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'Controversy and Acclaim: The Timelessness of a Groundbreaking Film',
#    'popularity': 0.842,
#    'title': 'Controversy and Acclaim: The Timelessness of a Groundbreaking Film',
#    'vote_average': 0,
#    'overview': 'Documentary featuring the contentious news surrounding the movie "Midnight Cowboy" (1969), including its Oscar win for feature film.',
#    'release_date': '2006-02-21'},
#   {'character': 'Interviewee',
#    'credit_id': '5b107f909251415ee900e401',
#    'poster_path': '/lFRjRi44uznei5oSCql43rMS2mN.jpg',
#    'id': 149395,
#    'video': False,
#    'vote_count': 1,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': "Waldo Salt: A Screenwriter's Journey",
#    'popularity': 0.62,
#    'title': "Waldo Salt: A Screenwriter's Journey",
#    'vote_average': 7,
#    'overview': "Documentary is about the life and work of American screenwriter Waldo Salt who won two Academy Awards and was put on the Hollywood blacklist in the 1950s. The story is told through interviews with collaborators and friends such as Dustin Hoffman, Robert Redford, Jon Voight, John Schlesinger and with clips from Salt's films, chiefly Midnight Cowboy.",
#    'release_date': '1990-01-19'},
#   {'character': 'Interviewee',
#    'credit_id': '5b69f95b92514140680f7e5b',
#    'poster_path': '/nFm0zzRsfqLHp8ONvooj4Ezgav5.jpg',
#    'id': 514638,
#    'video': False,
#    'vote_count': 0,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'The Making of Tootsie',
#    'popularity': 0.6,
#    'title': 'The Making of Tootsie',
#    'vote_average': 0,
#    'overview': 'Behind-the-scenes documentary on the set of Sydney Pollack\'s 1982 film "Tootsie."',
#    'release_date': '1982-01-01'},
#   {'character': 'Interviewee',
#    'credit_id': '5c3b907cc3a36869493bc7d9',
#    'poster_path': None,
#    'id': 574945,
#    'video': False,
#    'vote_count': 0,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'On Location: Dustin Hoffman',
#    'popularity': 0.6,
#    'title': 'On Location: Dustin Hoffman',
#    'vote_average': 0,
#    'overview': "Profile of actor Dustin Hoffman on the set of Sam Peckinpah's 1971 film STRAW DOGS.",
#    'release_date': '1971-12-31'},
#   {'character': 'Himself - Actor',
#    'credit_id': '5c8cac61c3a368611f4837ae',
#    'poster_path': '/iQg08fAo1rK4mZ5L7QDyLg8aFK.jpg',
#    'id': 588296,
#    'video': False,
#    'vote_count': 1,
#    'adult': False,
#    'backdrop_path': '/rx267nts9qMNC6GpzAHSY85ku6v.jpg',
#    'genre_ids': [99, 10770],
#    'original_language': 'en',
#    'original_title': 'Arthur Miller: A Man of His Century',
#    'popularity': 0.6,
#    'title': 'Arthur Miller: A Man of His Century',
#    'vote_average': 7,
#    'overview': "An unparalleled portrait of Arthur Miller (1915-2005), a major writer who left an indelible mark on the world. Miller's life is intimately connected with the great themes that marked the 20th century. Glamour, fame, social criticism and Marilyn Monroe.",
#    'release_date': '2015-10-17'},
#   {'character': 'Dottor Green',
#    'credit_id': '5cdc5b61c3a3680fd4c55297',
#    'release_date': '2019-10-30',
#    'vote_count': 0,
#    'video': False,
#    'adult': False,
#    'vote_average': 0,
#    'title': 'The Man of the Labyrinth',
#    'genre_ids': [53],
#    'original_language': 'it',
#    'original_title': "L'uomo del labirinto",
#    'popularity': 1.515,
#    'id': 602545,
#    'backdrop_path': '/6KPYsO9NdNeXY6laoklXoHvLiX6.jpg',
#    'overview': 'The anomalous heat wave overwhelms everything, forcing everyone to reverse the pace of life: only during the hours of darkness it is possible to work, move, survive. And it is precisely in the middle of the night that Samantha emerges from the darkness that had swallowed her. A thirteen year old kidnapped and long held prisoner, Sam is now suddenly free and, traumatized and wounded, is hospitalized in a hospital room. Next to her, Dr. Green (Dustin Hoffman), an extraordinary profiler. Green in fact does not hunt monsters in the outside world, but in the minds of the victims. Because it is inside the memories of Sam that the clues able to lead to the capture of his jailer are hidden: the Man of the Labyrinth. But Dr. Green is not the only one chasing the monster. There is also Bruno Genko (Toni Servillo), a private investigator with an unexpected talent.',
#    'poster_path': '/yGCeY69ytOhFk6ofPT7WgeURLZq.jpg'},
#   {'character': 'Himself',
#    'credit_id': '5d3288586a300b2f7ea34c4c',
#    'poster_path': '/3UDpexhhsOOx4K4lrTOkVYplLZ3.jpg',
#    'id': 458074,
#    'video': False,
#    'vote_count': 1,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'de',
#    'original_title': 'Jonas in the Desert',
#    'popularity': 0.6,
#    'title': 'Jonas in the Desert',
#    'vote_average': 5,
#    'overview': 'Not a documentary in the strictest sense of the word. Rather, it is a journey through the world of the artist Jonas Mekas - one of the exponents of independent U.S. movies; founder and director of the New York Anthology Film Archive.',
#    'release_date': '1994-01-01'},
#   {'character': '',
#    'credit_id': '5d3497e86a300b1333a22cab',
#    'poster_path': '/yLp7rIfDtoILB9QWEVDPhKQgseQ.jpg',
#    'id': 617295,
#    'video': False,
#    'vote_count': 0,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': "Going the Distance: Remembering 'Marathon Man'",
#    'popularity': 0.6,
#    'title': "Going the Distance: Remembering 'Marathon Man'",
#    'vote_average': 0,
#    'overview': "This retrospective documentary offers a first-rate account of the making of 'Marathon Man'. Hoffman, Scheider, Keller and Goldman all share their memories, many of which are remarkably detailed. Even the change in the ending is addressed, and twenty-five years later, Goldman seems to have resigned himself to the rewrite.",
#    'release_date': '2001-08-28'},
#   {'character': '',
#    'credit_id': '5d3499c66a300b05ada4656b',
#    'poster_path': '/aTuQebwgzlb82WA5yYAs2jRA2Bf.jpg',
#    'id': 617297,
#    'video': False,
#    'vote_count': 0,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'The Magic of Hollywood... Is the Magic of People',
#    'popularity': 0.654,
#    'title': 'The Magic of Hollywood... Is the Magic of People',
#    'vote_average': 0,
#    'overview': "Producer Robert Evans dominates with his trademark promotional style, but Schlesinger gets a short time on camera (one of his few available interviews about the film), and Hoffman has even more. A highlight is the celebration of Olivier's final shooting day, complete with speeches and a toast.",
#    'release_date': '1976-10-06'},
#   {'character': 'Himself (archive footage)',
#    'credit_id': '5d5b6e275690b5397aff770a',
#    'poster_path': '/nNZ9kb3C3rmEHKTwDfN577cuXNo.jpg',
#    'id': 29047,
#    'video': False,
#    'vote_count': 35,
#    'adult': False,
#    'backdrop_path': '/qD8Dcdgb1V3xy7izDcpcnxmd052.jpg',
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': 'The Kid Stays in the Picture',
#    'popularity': 2.929,
#    'title': 'The Kid Stays in the Picture',
#    'vote_average': 7,
#    'overview': 'Documentary about legendary Paramount producer Robert Evans, based on his famous 1994 autobiography.',
#    'release_date': '2002-08-16'},
#   {'character': '',
#    'credit_id': '5d65a36dba48020015265962',
#    'poster_path': '/kgH49kPNNtel04HPVGQLS63coRF.jpg',
#    'id': 253639,
#    'video': False,
#    'vote_count': 23,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99, 10770],
#    'original_language': 'en',
#    'original_title': 'And the Oscar Goes To...',
#    'popularity': 2.953,
#    'title': 'And the Oscar Goes To...',
#    'vote_average': 7,
#    'overview': 'The story of the gold-plated statuette that became the film industry\'s most coveted prize, AND THE OSCAR GOES TO... traces the history of the Academy itself, which began in 1927 when Louis B. Mayer, then head of MGM, led other prominent members of the industry in forming this professional honorary organization. Two years later the Academy began bestowing awards, which were nicknamed "Oscar," and quickly came to represent the pinnacle of cinematic achievement.',
#    'release_date': '2014-02-02'},
#   {'character': '',
#    'credit_id': '5d72672a84448e1e292b23bd',
#    'release_date': '2015-12-06',
#    'vote_count': 2,
#    'video': False,
#    'adult': False,
#    'vote_average': 3.5,
#    'title': 'Warren Beatty - Mister Hollywood',
#    'genre_ids': [99],
#    'original_language': 'fr',
#    'original_title': 'Warren Beatty, une obsession hollywoodienne',
#    'popularity': 0.6,
#    'id': 371556,
#    'backdrop_path': '/bfRSoMKSAtPwpcXqzfrVRpaucSO.jpg',
#    'overview': '',
#    'poster_path': '/kYpPpubxrfKhxgGymDENe0RqQyf.jpg'}],
#  'crew': [{'id': 121826,
#    'department': 'Directing',
#    'original_language': 'en',
#    'original_title': 'Quartet',
#    'job': 'Director',
#    'overview': "The directorial debut of Dustin Hoffman, Quartet is a high-drama comedy about temperamental divas and old grudges, passion and pride, romance and Rigoletto. At a home for retired musicians, the annual concert to celebrate Verdi's birthday is disrupted by the arrival of Jean, an eternal diva and former wife of one of the residents. Expect poignancy and plenty of laughs.",
#    'vote_count': 215,
#    'video': False,
#    'release_date': '2013-01-10',
#    'vote_average': 6.6,
#    'title': 'Quartet',
#    'popularity': 7.536,
#    'genre_ids': [18, 35, 10749],
#    'backdrop_path': '/cTOZopbtjnaSSptIlGgVFtnYATV.jpg',
#    'adult': False,
#    'poster_path': '/9XJCnqQA1Yl3hiIHeH1jpibyT1i.jpg',
#    'credit_id': '52fe4a6ec3a368484e152d59'},
#   {'id': 28029,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'A Walk on the Moon',
#    'job': 'Producer',
#    'overview': 'The world of a young housewife is turned upside down when she has an affair with a free-spirited blouse salesman.',
#    'vote_count': 42,
#    'video': False,
#    'release_date': '1999-01-29',
#    'vote_average': 6.1,
#    'title': 'A Walk on the Moon',
#    'popularity': 3.024,
#    'genre_ids': [18, 10749],
#    'backdrop_path': '/x7vXdeO3S3pTfwlkhyAOKNQLij5.jpg',
#    'adult': False,
#    'poster_path': '/prNgf4ZHzkAp8Rl8KsaKMHOfDOs.jpg',
#    'credit_id': '55ef3f4bc3a3686f17009da5'},
#   {'id': 121826,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Quartet',
#    'job': 'Executive Producer',
#    'overview': "The directorial debut of Dustin Hoffman, Quartet is a high-drama comedy about temperamental divas and old grudges, passion and pride, romance and Rigoletto. At a home for retired musicians, the annual concert to celebrate Verdi's birthday is disrupted by the arrival of Jean, an eternal diva and former wife of one of the residents. Expect poignancy and plenty of laughs.",
#    'vote_count': 215,
#    'video': False,
#    'release_date': '2013-01-10',
#    'vote_average': 6.6,
#    'title': 'Quartet',
#    'popularity': 7.536,
#    'genre_ids': [18, 35, 10749],
#    'backdrop_path': '/cTOZopbtjnaSSptIlGgVFtnYATV.jpg',
#    'adult': False,
#    'poster_path': '/9XJCnqQA1Yl3hiIHeH1jpibyT1i.jpg',
#    'credit_id': '563b2b489251414cc9003d09'},
#   {'id': 31200,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Agatha',
#    'job': 'Producer',
#    'overview': 'England, 1926. An American journalist looks for mystery writer Agatha Christie when she suddenly disappears without explanation, leaving no trace.',
#    'vote_count': 17,
#    'video': False,
#    'release_date': '1979-02-09',
#    'vote_average': 6.4,
#    'title': 'Agatha',
#    'popularity': 2.727,
#    'genre_ids': [18, 9648, 53],
#    'backdrop_path': '/wINvqci7jSC8IhsrrBulEd1sUhN.jpg',
#    'adult': False,
#    'poster_path': '/hluywh88zMF9uYroBTNIrmozgQ5.jpg',
#    'credit_id': '5745413292514153e5001258'},
#   {'id': 167073,
#    'department': 'Crew',
#    'original_language': 'en',
#    'original_title': 'Brooklyn',
#    'job': 'Thanks',
#    'overview': 'In 1950s Ireland and New York, young Eilis Lacey has to choose between two men and two countries.',
#    'vote_count': 1978,
#    'video': False,
#    'release_date': '2015-11-04',
#    'vote_average': 7.3,
#    'title': 'Brooklyn',
#    'popularity': 11.966,
#    'genre_ids': [18, 10749],
#    'backdrop_path': '/7fXKVIM8UQBvQ9aQOzFqThlq7eN.jpg',
#    'adult': False,
#    'poster_path': '/dRpkyrSDrEMFRZDeFJG4EupqUfR.jpg',
#    'credit_id': '5787c350c3a368391900106c'},
#   {'id': 38618,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Tarzan and the Lost City',
#    'job': 'Producer',
#    'overview': 'Tarzan returns to his homeland of Africa to save his home from destruction.',
#    'vote_count': 15,
#    'video': False,
#    'release_date': '1998-04-24',
#    'vote_average': 4,
#    'title': 'Tarzan and the Lost City',
#    'popularity': 2,
#    'genre_ids': [28, 12],
#    'backdrop_path': '/dY0PPUlFHvh6RctsrbPVugyfbdu.jpg',
#    'adult': False,
#    'poster_path': '/mdKJwKYuetImwY2aTG4wSz60mB6.jpg',
#    'credit_id': '593e5e8cc3a3680f1402c05c'}],
#  'id': 4483}

# %%
num_of_credits = len(response_actor_id['cast'][:])
num_of_credits   #how many movies
# Out:
# 108

# %%
#Put all records in actor's first part of Data Frame (ie. hoffman_df)
labels = ['title','popularity','vote_average','vote_count']
idx = [film['id'] for film in response_actor_id['cast'][:]]
records = []
for film in (response_actor_id['cast'][:]):
    record = [film['title'], film['popularity'], film['vote_average'], film['vote_count']]
    records.append(record)

actor_df = pd.DataFrame.from_records(records, columns=labels, index=idx)
actor_df
# Out:
#                                                     title  popularity  \
# 380                                              Rain Man      12.331
# 586                                           Wag the Dog      11.072
# 693                                      Meet the Fockers      12.842
# 819                                              Sleepers      12.434
# 866                                     Finding Neverland       9.334
# 879                                                  Hook      12.376
# 891                               All the President's Men      18.213
# 994                                            Straw Dogs      10.811
# 1262                                Stranger Than Fiction       8.176
# 1427                     Perfume: The Story of a Murderer      10.036
# 1599                                    I Heart Huckabees       8.180
# 10047             The Messenger: The Story of Joan of Arc      11.561
# 10153                                              Sphere      11.722
# 10199                              The Tale of Despereaux       9.896
# 2284                       Mr. Magorium's Wonder Emporium       8.198
# 10518                                        Marathon Man       8.836
# 10551                                     Family Business       8.375
# 3116                                      Midnight Cowboy      12.605
# 3148                                   Madigan's Millions       0.911
# 10699                                                Hero       8.109
# 10743                                          Confidence       6.862
# 11040                                      Little Big Man       7.857
# 11329                                        Runaway Jury       8.929
# 5924                                             Papillon      12.396
# 322520                                                Hal       2.050
# 31005                                      Moonlight Mile       8.662
# 31200                                              Agatha       2.727
# 23397                                       Straight Time       4.953
# 6950                                             Outbreak      10.650
# 31546                                    American Buffalo       2.586
# ...                                                   ...         ...
# 23544                                          The Point!       1.581
# 1581                                          The Holiday      10.987
# 435860                          Arthur Penn: The Director       0.600
# 114524             Common Threads: Stories from the Quilt       0.840
# 456698     Michael Ballhaus - Eine Reise durch mein Leben       0.600
# 22509                              The Devil's Arithmetic       3.094
# 2800                                      Rumor Has It...       8.707
# 461569                                     The Star Wagon       0.621
# 274213                     The Journey of the Fifth Horse       0.600
# 410205  All Governments Lie: Truth, Deception, and the...       0.827
# 469940                  Mantrap: Straw Dogs—The Final Cut       1.400
# 479530                A Better Man: The Making of Tootsie       1.093
# 467062                                          Spielberg       7.056
# 504420                                            Tuesday       0.600
# 514416                                 The Graduate at 25       0.600
# 8592                                           Dick Tracy       9.938
# 513814                        The Crowd Around the Cowboy       1.400
# 527619  After Midnight: Reflecting on a Classic 35 Yea...       0.600
# 527620  Controversy and Acclaim: The Timelessness of a...       0.842
# 149395               Waldo Salt: A Screenwriter's Journey       0.620
# 514638                              The Making of Tootsie       0.600
# 574945                        On Location: Dustin Hoffman       0.600
# 588296                Arthur Miller: A Man of His Century       0.600
# 602545                           The Man of the Labyrinth       1.515
# 458074                                Jonas in the Desert       0.600
# 617295     Going the Distance: Remembering 'Marathon Man'       0.600
# 617297   The Magic of Hollywood... Is the Magic of People       0.654
# 29047                        The Kid Stays in the Picture       2.929
# 253639                           And the Oscar Goes To...       2.953
# 371556                   Warren Beatty - Mister Hollywood       0.600
#
#         vote_average  vote_count
# 380              7.7        3318
# 586              6.9         459
# 693              6.2        2796
# 819              7.5        1485
# 866              7.3        2353
# 879              6.9        3087
# 891              7.7         809
# 994              7.2         407
# 1262             7.2        1243
# 1427             7.2        2356
# 1599             6.3         362
# 10047            6.3         747
# 10153            6.0         816
# 10199            5.8         498
# 2284             6.2         697
# 10518            7.4         441
# 10551            5.6          98
# 3116             7.5         569
# 3148             3.5           2
# 10699            6.3         204
# 10743            6.3         210
# 11040            7.7         250
# 11329            6.9         616
# 5924             8.0         877
# 322520           0.0           1
# 31005            6.3         110
# 31200            6.4          17
# 23397            7.2          57
# 6950             6.4         927
# 31546            5.5          22
# ...              ...         ...
# 23544            7.3          17
# 1581             7.0        2686
# 435860           0.0           0
# 114524           9.0           4
# 456698           0.0           0
# 22509            6.5          31
# 2800             5.5         588
# 461569           8.0           1
# 274213           0.0           0
# 410205           8.8           5
# 469940           0.0           0
# 479530           0.0           0
# 467062           7.5         113
# 504420           0.0           0
# 514416           0.0           0
# 8592             6.1         437
# 513814           0.0           0
# 527619           0.0           0
# 527620           0.0           0
# 149395           7.0           1
# 514638           0.0           0
# 574945           0.0           0
# 588296           7.0           1
# 602545           0.0           0
# 458074           5.0           1
# 617295           0.0           0
# 617297           0.0           0
# 29047            7.0          35
# 253639           7.0          23
# 371556           3.5           2
#
# [108 rows x 4 columns]

# %%
#Now get 2nd part of actor's df from the tmdb.Movies for merging
labels = ['revenue','budget','profit','genres']
film_indices = [film[0] for film in actor_df.iterrows()]
#print(film_indices)
records = []
request_rate_limit = 40     #TMDB has rate limit of 40 requests per 10 seconds

for film_idx in film_indices:
    request_rate_limit -= 1
    if request_rate_limit == 0:            
        print("Hold yer horses, cowboy!")
        print("...wait per request limit...")
        time.sleep(10)
        request_rate_limit = 39
    movie = tmdb.Movies(film_idx)  #Each movie has unique identifier stored as index of df
    response = movie.info()
        
    profit = response['revenue'] - response['budget']
    record = [response['revenue'], response['budget'], profit, response['genres']]    
    records.append(record)

actor_movies_df = pd.DataFrame.from_records(records, columns=labels, index=film_indices)
actor_movies_df
# Out:
# Hold yer horses, cowboy!
# ...wait per request limit...
# Hold yer horses, cowboy!
# ...wait per request limit...
#           revenue    budget     profit  \
# 380     412800000  25000000  387800000
# 586      64256513  15000000   49256513
# 693     516642939  80000000  436642939
# 819     165615285  44000000  121615285
# 866     116766556  25000000   91766556
# 879     300854823  70000000  230854823
# 891      70600000   8500000   62100000
# 994       3251794   2200000    1051794
# 1262     53653224  30000000   23653224
# 1427    132180323  50000000   82180323
# 1599            0  22000000  -22000000
# 10047    66976317  85000000  -18023683
# 10153    37020277  80000000  -42979723
# 10199    86900000  60000000   26900000
# 2284     69474661         0   69474661
# 10518    21709020   6500000   15209020
# 10551    12195695         0   12195695
# 3116     44785053   3600000   41185053
# 3148            0         0          0
# 10699           0  42000000  -42000000
# 10743    23014206  15000000    8014206
# 11040    31559552  15000000   16559552
# 11329    80154140  60000000   20154140
# 5924     53267000  12000000   41267000
# 322520          0         0          0
# 31005    10011050  21000000  -10988950
# 31200           0         0          0
# 23397     9900000         0    9900000
# 6950    189859560  50000000  139859560
# 31546      665450         0     665450
# ...           ...       ...        ...
# 23544           0         0          0
# 1581    194168700  85000000  109168700
# 435860          0         0          0
# 114524          0         0          0
# 456698          0         0          0
# 22509           0         0          0
# 2800     88933562  70000000   18933562
# 461569          0         0          0
# 274213          0         0          0
# 410205          0         0          0
# 469940          0         0          0
# 479530          0         0          0
# 467062          0         0          0
# 504420          0         0          0
# 514416          0         0          0
# 8592    103738726  47000000   56738726
# 513814          0         0          0
# 527619          0         0          0
# 527620          0         0          0
# 149395          0         0          0
# 514638          0         0          0
# 574945          0         0          0
# 588296          0         0          0
# 602545          0         0          0
# 458074          0         0          0
# 617295          0         0          0
# 617297          0         0          0
# 29047     1434436     40000    1394436
# 253639          0         0          0
# 371556          0         0          0
#
#                                                    genres
# 380                         [{'id': 18, 'name': 'Drama'}]
# 586     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 693     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 819     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 866                         [{'id': 18, 'name': 'Drama'}]
# 879     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 891     [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 994     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 1262    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1427    [{'id': 80, 'name': 'Crime'}, {'id': 14, 'name...
# 1599    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 10047   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 10153   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 10199   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 2284    [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 10518   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 10551   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 3116                        [{'id': 18, 'name': 'Drama'}]
# 3148    [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 10699   [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 10743   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 11040   [{'id': 12, 'name': 'Adventure'}, {'id': 37, '...
# 11329   [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 5924    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 322520                [{'id': 99, 'name': 'Documentary'}]
# 31005   [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 31200   [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 23397   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 6950    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 31546                       [{'id': 18, 'name': 'Drama'}]
# ...                                                   ...
# 23544   [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 1581    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 435860                [{'id': 99, 'name': 'Documentary'}]
# 114524  [{'id': 36, 'name': 'History'}, {'id': 99, 'na...
# 456698                [{'id': 99, 'name': 'Documentary'}]
# 22509   [{'id': 10770, 'name': 'TV Movie'}, {'id': 18,...
# 2800                       [{'id': 35, 'name': 'Comedy'}]
# 461569                     [{'id': 35, 'name': 'Comedy'}]
# 274213                                                 []
# 410205                [{'id': 99, 'name': 'Documentary'}]
# 469940                [{'id': 99, 'name': 'Documentary'}]
# 479530                [{'id': 99, 'name': 'Documentary'}]
# 467062  [{'id': 99, 'name': 'Documentary'}, {'id': 107...
# 504420  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 514416                [{'id': 99, 'name': 'Documentary'}]
# 8592    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 513814                [{'id': 99, 'name': 'Documentary'}]
# 527619                [{'id': 99, 'name': 'Documentary'}]
# 527620                [{'id': 99, 'name': 'Documentary'}]
# 149395                [{'id': 99, 'name': 'Documentary'}]
# 514638                [{'id': 99, 'name': 'Documentary'}]
# 574945                [{'id': 99, 'name': 'Documentary'}]
# 588296  [{'id': 99, 'name': 'Documentary'}, {'id': 107...
# 602545                   [{'id': 53, 'name': 'Thriller'}]
# 458074                [{'id': 99, 'name': 'Documentary'}]
# 617295                [{'id': 99, 'name': 'Documentary'}]
# 617297                [{'id': 99, 'name': 'Documentary'}]
# 29047                 [{'id': 99, 'name': 'Documentary'}]
# 253639  [{'id': 99, 'name': 'Documentary'}, {'id': 107...
# 371556                [{'id': 99, 'name': 'Documentary'}]
#
# [108 rows x 4 columns]

# %%
print(actor_df.shape)
actor_df.head(5)
# Out:
# (108, 4)
#                  title  popularity  vote_average  vote_count
# 380           Rain Man      12.331           7.7        3318
# 586        Wag the Dog      11.072           6.9         459
# 693   Meet the Fockers      12.842           6.2        2796
# 819           Sleepers      12.434           7.5        1485
# 866  Finding Neverland       9.334           7.3        2353

# %%
print(actor_movies_df.shape)
actor_movies_df.head(5)
# Out:
# (108, 4)
#        revenue    budget     profit  \
# 380  412800000  25000000  387800000
# 586   64256513  15000000   49256513
# 693  516642939  80000000  436642939
# 819  165615285  44000000  121615285
# 866  116766556  25000000   91766556
#
#                                                 genres
# 380                      [{'id': 18, 'name': 'Drama'}]
# 586  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 693  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 819  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 866                      [{'id': 18, 'name': 'Drama'}]

# %%
# This builds the full df, still need to build final
actor_full_df = pd.merge(actor_df, actor_movies_df, left_index=True, right_index=True)
print(actor_full_df.shape)
actor_full_df
# Out:
# (108, 8)
#                                                     title  popularity  \
# 380                                              Rain Man      12.331
# 586                                           Wag the Dog      11.072
# 693                                      Meet the Fockers      12.842
# 819                                              Sleepers      12.434
# 866                                     Finding Neverland       9.334
# 879                                                  Hook      12.376
# 891                               All the President's Men      18.213
# 994                                            Straw Dogs      10.811
# 1262                                Stranger Than Fiction       8.176
# 1427                     Perfume: The Story of a Murderer      10.036
# 1599                                    I Heart Huckabees       8.180
# 10047             The Messenger: The Story of Joan of Arc      11.561
# 10153                                              Sphere      11.722
# 10199                              The Tale of Despereaux       9.896
# 2284                       Mr. Magorium's Wonder Emporium       8.198
# 10518                                        Marathon Man       8.836
# 10551                                     Family Business       8.375
# 3116                                      Midnight Cowboy      12.605
# 3148                                   Madigan's Millions       0.911
# 10699                                                Hero       8.109
# 10743                                          Confidence       6.862
# 11040                                      Little Big Man       7.857
# 11329                                        Runaway Jury       8.929
# 5924                                             Papillon      12.396
# 322520                                                Hal       2.050
# 31005                                      Moonlight Mile       8.662
# 31200                                              Agatha       2.727
# 23397                                       Straight Time       4.953
# 6950                                             Outbreak      10.650
# 31546                                    American Buffalo       2.586
# ...                                                   ...         ...
# 23544                                          The Point!       1.581
# 1581                                          The Holiday      10.987
# 435860                          Arthur Penn: The Director       0.600
# 114524             Common Threads: Stories from the Quilt       0.840
# 456698     Michael Ballhaus - Eine Reise durch mein Leben       0.600
# 22509                              The Devil's Arithmetic       3.094
# 2800                                      Rumor Has It...       8.707
# 461569                                     The Star Wagon       0.621
# 274213                     The Journey of the Fifth Horse       0.600
# 410205  All Governments Lie: Truth, Deception, and the...       0.827
# 469940                  Mantrap: Straw Dogs—The Final Cut       1.400
# 479530                A Better Man: The Making of Tootsie       1.093
# 467062                                          Spielberg       7.056
# 504420                                            Tuesday       0.600
# 514416                                 The Graduate at 25       0.600
# 8592                                           Dick Tracy       9.938
# 513814                        The Crowd Around the Cowboy       1.400
# 527619  After Midnight: Reflecting on a Classic 35 Yea...       0.600
# 527620  Controversy and Acclaim: The Timelessness of a...       0.842
# 149395               Waldo Salt: A Screenwriter's Journey       0.620
# 514638                              The Making of Tootsie       0.600
# 574945                        On Location: Dustin Hoffman       0.600
# 588296                Arthur Miller: A Man of His Century       0.600
# 602545                           The Man of the Labyrinth       1.515
# 458074                                Jonas in the Desert       0.600
# 617295     Going the Distance: Remembering 'Marathon Man'       0.600
# 617297   The Magic of Hollywood... Is the Magic of People       0.654
# 29047                        The Kid Stays in the Picture       2.929
# 253639                           And the Oscar Goes To...       2.953
# 371556                   Warren Beatty - Mister Hollywood       0.600
#
#         vote_average  vote_count    revenue    budget     profit  \
# 380              7.7        3318  412800000  25000000  387800000
# 586              6.9         459   64256513  15000000   49256513
# 693              6.2        2796  516642939  80000000  436642939
# 819              7.5        1485  165615285  44000000  121615285
# 866              7.3        2353  116766556  25000000   91766556
# 879              6.9        3087  300854823  70000000  230854823
# 891              7.7         809   70600000   8500000   62100000
# 994              7.2         407    3251794   2200000    1051794
# 1262             7.2        1243   53653224  30000000   23653224
# 1427             7.2        2356  132180323  50000000   82180323
# 1599             6.3         362          0  22000000  -22000000
# 10047            6.3         747   66976317  85000000  -18023683
# 10153            6.0         816   37020277  80000000  -42979723
# 10199            5.8         498   86900000  60000000   26900000
# 2284             6.2         697   69474661         0   69474661
# 10518            7.4         441   21709020   6500000   15209020
# 10551            5.6          98   12195695         0   12195695
# 3116             7.5         569   44785053   3600000   41185053
# 3148             3.5           2          0         0          0
# 10699            6.3         204          0  42000000  -42000000
# 10743            6.3         210   23014206  15000000    8014206
# 11040            7.7         250   31559552  15000000   16559552
# 11329            6.9         616   80154140  60000000   20154140
# 5924             8.0         877   53267000  12000000   41267000
# 322520           0.0           1          0         0          0
# 31005            6.3         110   10011050  21000000  -10988950
# 31200            6.4          17          0         0          0
# 23397            7.2          57    9900000         0    9900000
# 6950             6.4         927  189859560  50000000  139859560
# 31546            5.5          22     665450         0     665450
# ...              ...         ...        ...       ...        ...
# 23544            7.3          17          0         0          0
# 1581             7.0        2686  194168700  85000000  109168700
# 435860           0.0           0          0         0          0
# 114524           9.0           4          0         0          0
# 456698           0.0           0          0         0          0
# 22509            6.5          31          0         0          0
# 2800             5.5         588   88933562  70000000   18933562
# 461569           8.0           1          0         0          0
# 274213           0.0           0          0         0          0
# 410205           8.8           5          0         0          0
# 469940           0.0           0          0         0          0
# 479530           0.0           0          0         0          0
# 467062           7.5         113          0         0          0
# 504420           0.0           0          0         0          0
# 514416           0.0           0          0         0          0
# 8592             6.1         437  103738726  47000000   56738726
# 513814           0.0           0          0         0          0
# 527619           0.0           0          0         0          0
# 527620           0.0           0          0         0          0
# 149395           7.0           1          0         0          0
# 514638           0.0           0          0         0          0
# 574945           0.0           0          0         0          0
# 588296           7.0           1          0         0          0
# 602545           0.0           0          0         0          0
# 458074           5.0           1          0         0          0
# 617295           0.0           0          0         0          0
# 617297           0.0           0          0         0          0
# 29047            7.0          35    1434436     40000    1394436
# 253639           7.0          23          0         0          0
# 371556           3.5           2          0         0          0
#
#                                                    genres
# 380                         [{'id': 18, 'name': 'Drama'}]
# 586     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 693     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 819     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 866                         [{'id': 18, 'name': 'Drama'}]
# 879     [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 891     [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 994     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 1262    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1427    [{'id': 80, 'name': 'Crime'}, {'id': 14, 'name...
# 1599    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 10047   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 10153   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 10199   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 2284    [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 10518   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 10551   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 3116                        [{'id': 18, 'name': 'Drama'}]
# 3148    [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 10699   [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 10743   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 11040   [{'id': 12, 'name': 'Adventure'}, {'id': 37, '...
# 11329   [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 5924    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 322520                [{'id': 99, 'name': 'Documentary'}]
# 31005   [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 31200   [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 23397   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 6950    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 31546                       [{'id': 18, 'name': 'Drama'}]
# ...                                                   ...
# 23544   [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 1581    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 435860                [{'id': 99, 'name': 'Documentary'}]
# 114524  [{'id': 36, 'name': 'History'}, {'id': 99, 'na...
# 456698                [{'id': 99, 'name': 'Documentary'}]
# 22509   [{'id': 10770, 'name': 'TV Movie'}, {'id': 18,...
# 2800                       [{'id': 35, 'name': 'Comedy'}]
# 461569                     [{'id': 35, 'name': 'Comedy'}]
# 274213                                                 []
# 410205                [{'id': 99, 'name': 'Documentary'}]
# 469940                [{'id': 99, 'name': 'Documentary'}]
# 479530                [{'id': 99, 'name': 'Documentary'}]
# 467062  [{'id': 99, 'name': 'Documentary'}, {'id': 107...
# 504420  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 514416                [{'id': 99, 'name': 'Documentary'}]
# 8592    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 513814                [{'id': 99, 'name': 'Documentary'}]
# 527619                [{'id': 99, 'name': 'Documentary'}]
# 527620                [{'id': 99, 'name': 'Documentary'}]
# 149395                [{'id': 99, 'name': 'Documentary'}]
# 514638                [{'id': 99, 'name': 'Documentary'}]
# 574945                [{'id': 99, 'name': 'Documentary'}]
# 588296  [{'id': 99, 'name': 'Documentary'}, {'id': 107...
# 602545                   [{'id': 53, 'name': 'Thriller'}]
# 458074                [{'id': 99, 'name': 'Documentary'}]
# 617295                [{'id': 99, 'name': 'Documentary'}]
# 617297                [{'id': 99, 'name': 'Documentary'}]
# 29047                 [{'id': 99, 'name': 'Documentary'}]
# 253639  [{'id': 99, 'name': 'Documentary'}, {'id': 107...
# 371556                [{'id': 99, 'name': 'Documentary'}]
#
# [108 rows x 8 columns]

# %%
#Save to PostgrSQL

# %%
#Create new column containing a list of genres for each movie
def to_list(cell):
    #input is a single cell containing a list of dicts
    #rreturns a list of genres as unique strings
    l = []
    for d in cell:     #cell is list of dicts
        l.append(d['name'])
    return(l)

actor_full_df['genre_names'] = actor_full_df['genres'].map(to_list)
#Drop duplicate info
actor_full_df.drop(['genres'], axis=1, inplace=True)
actor_full_df
# Out:
#                                                     title  popularity  \
# 380                                              Rain Man      12.331
# 586                                           Wag the Dog      11.072
# 693                                      Meet the Fockers      12.842
# 819                                              Sleepers      12.434
# 866                                     Finding Neverland       9.334
# 879                                                  Hook      12.376
# 891                               All the President's Men      18.213
# 994                                            Straw Dogs      10.811
# 1262                                Stranger Than Fiction       8.176
# 1427                     Perfume: The Story of a Murderer      10.036
# 1599                                    I Heart Huckabees       8.180
# 10047             The Messenger: The Story of Joan of Arc      11.561
# 10153                                              Sphere      11.722
# 10199                              The Tale of Despereaux       9.896
# 2284                       Mr. Magorium's Wonder Emporium       8.198
# 10518                                        Marathon Man       8.836
# 10551                                     Family Business       8.375
# 3116                                      Midnight Cowboy      12.605
# 3148                                   Madigan's Millions       0.911
# 10699                                                Hero       8.109
# 10743                                          Confidence       6.862
# 11040                                      Little Big Man       7.857
# 11329                                        Runaway Jury       8.929
# 5924                                             Papillon      12.396
# 322520                                                Hal       2.050
# 31005                                      Moonlight Mile       8.662
# 31200                                              Agatha       2.727
# 23397                                       Straight Time       4.953
# 6950                                             Outbreak      10.650
# 31546                                    American Buffalo       2.586
# ...                                                   ...         ...
# 23544                                          The Point!       1.581
# 1581                                          The Holiday      10.987
# 435860                          Arthur Penn: The Director       0.600
# 114524             Common Threads: Stories from the Quilt       0.840
# 456698     Michael Ballhaus - Eine Reise durch mein Leben       0.600
# 22509                              The Devil's Arithmetic       3.094
# 2800                                      Rumor Has It...       8.707
# 461569                                     The Star Wagon       0.621
# 274213                     The Journey of the Fifth Horse       0.600
# 410205  All Governments Lie: Truth, Deception, and the...       0.827
# 469940                  Mantrap: Straw Dogs—The Final Cut       1.400
# 479530                A Better Man: The Making of Tootsie       1.093
# 467062                                          Spielberg       7.056
# 504420                                            Tuesday       0.600
# 514416                                 The Graduate at 25       0.600
# 8592                                           Dick Tracy       9.938
# 513814                        The Crowd Around the Cowboy       1.400
# 527619  After Midnight: Reflecting on a Classic 35 Yea...       0.600
# 527620  Controversy and Acclaim: The Timelessness of a...       0.842
# 149395               Waldo Salt: A Screenwriter's Journey       0.620
# 514638                              The Making of Tootsie       0.600
# 574945                        On Location: Dustin Hoffman       0.600
# 588296                Arthur Miller: A Man of His Century       0.600
# 602545                           The Man of the Labyrinth       1.515
# 458074                                Jonas in the Desert       0.600
# 617295     Going the Distance: Remembering 'Marathon Man'       0.600
# 617297   The Magic of Hollywood... Is the Magic of People       0.654
# 29047                        The Kid Stays in the Picture       2.929
# 253639                           And the Oscar Goes To...       2.953
# 371556                   Warren Beatty - Mister Hollywood       0.600
#
#         vote_average  vote_count    revenue    budget     profit  \
# 380              7.7        3318  412800000  25000000  387800000
# 586              6.9         459   64256513  15000000   49256513
# 693              6.2        2796  516642939  80000000  436642939
# 819              7.5        1485  165615285  44000000  121615285
# 866              7.3        2353  116766556  25000000   91766556
# 879              6.9        3087  300854823  70000000  230854823
# 891              7.7         809   70600000   8500000   62100000
# 994              7.2         407    3251794   2200000    1051794
# 1262             7.2        1243   53653224  30000000   23653224
# 1427             7.2        2356  132180323  50000000   82180323
# 1599             6.3         362          0  22000000  -22000000
# 10047            6.3         747   66976317  85000000  -18023683
# 10153            6.0         816   37020277  80000000  -42979723
# 10199            5.8         498   86900000  60000000   26900000
# 2284             6.2         697   69474661         0   69474661
# 10518            7.4         441   21709020   6500000   15209020
# 10551            5.6          98   12195695         0   12195695
# 3116             7.5         569   44785053   3600000   41185053
# 3148             3.5           2          0         0          0
# 10699            6.3         204          0  42000000  -42000000
# 10743            6.3         210   23014206  15000000    8014206
# 11040            7.7         250   31559552  15000000   16559552
# 11329            6.9         616   80154140  60000000   20154140
# 5924             8.0         877   53267000  12000000   41267000
# 322520           0.0           1          0         0          0
# 31005            6.3         110   10011050  21000000  -10988950
# 31200            6.4          17          0         0          0
# 23397            7.2          57    9900000         0    9900000
# 6950             6.4         927  189859560  50000000  139859560
# 31546            5.5          22     665450         0     665450
# ...              ...         ...        ...       ...        ...
# 23544            7.3          17          0         0          0
# 1581             7.0        2686  194168700  85000000  109168700
# 435860           0.0           0          0         0          0
# 114524           9.0           4          0         0          0
# 456698           0.0           0          0         0          0
# 22509            6.5          31          0         0          0
# 2800             5.5         588   88933562  70000000   18933562
# 461569           8.0           1          0         0          0
# 274213           0.0           0          0         0          0
# 410205           8.8           5          0         0          0
# 469940           0.0           0          0         0          0
# 479530           0.0           0          0         0          0
# 467062           7.5         113          0         0          0
# 504420           0.0           0          0         0          0
# 514416           0.0           0          0         0          0
# 8592             6.1         437  103738726  47000000   56738726
# 513814           0.0           0          0         0          0
# 527619           0.0           0          0         0          0
# 527620           0.0           0          0         0          0
# 149395           7.0           1          0         0          0
# 514638           0.0           0          0         0          0
# 574945           0.0           0          0         0          0
# 588296           7.0           1          0         0          0
# 602545           0.0           0          0         0          0
# 458074           5.0           1          0         0          0
# 617295           0.0           0          0         0          0
# 617297           0.0           0          0         0          0
# 29047            7.0          35    1434436     40000    1394436
# 253639           7.0          23          0         0          0
# 371556           3.5           2          0         0          0
#
#                                               genre_names
# 380                                               [Drama]
# 586                                       [Comedy, Drama]
# 693                                     [Comedy, Romance]
# 819                              [Crime, Drama, Thriller]
# 866                                               [Drama]
# 879                  [Adventure, Fantasy, Comedy, Family]
# 891                   [Drama, History, Mystery, Thriller]
# 994                              [Crime, Drama, Thriller]
# 1262                    [Comedy, Drama, Fantasy, Romance]
# 1427                              [Crime, Fantasy, Drama]
# 1599                                    [Comedy, Romance]
# 10047            [Adventure, Drama, Action, History, War]
# 10153           [Science Fiction, Drama, Horror, Mystery]
# 10199                      [Adventure, Animation, Family]
# 2284                            [Comedy, Family, Fantasy]
# 10518                                   [Thriller, Drama]
# 10551   [Action, Comedy, Crime, Drama, Thriller, Mystery]
# 3116                                              [Drama]
# 3148                              [Action, Comedy, Crime]
# 10699                  [Drama, Comedy, Thriller, Mystery]
# 10743          [Action, Comedy, Thriller, Crime, Mystery]
# 11040                 [Adventure, Western, Comedy, Drama]
# 11329                                   [Drama, Thriller]
# 5924                                       [Crime, Drama]
# 322520                                      [Documentary]
# 31005                                    [Romance, Drama]
# 31200                          [Drama, Mystery, Thriller]
# 23397                                      [Crime, Drama]
# 6950           [Action, Drama, Science Fiction, Thriller]
# 31546                                             [Drama]
# ...                                                   ...
# 23544                 [Animation, Drama, Family, Fantasy]
# 1581                                    [Comedy, Romance]
# 435860                                      [Documentary]
# 114524                             [History, Documentary]
# 456698                                      [Documentary]
# 22509        [TV Movie, Drama, Science Fiction, Thriller]
# 2800                                             [Comedy]
# 461569                                           [Comedy]
# 274213                                                 []
# 410205                                      [Documentary]
# 469940                                      [Documentary]
# 479530                                      [Documentary]
# 467062                            [Documentary, TV Movie]
# 504420                       [Family, Animation, Fantasy]
# 514416                                      [Documentary]
# 8592         [Adventure, Action, Comedy, Thriller, Crime]
# 513814                                      [Documentary]
# 527619                                      [Documentary]
# 527620                                      [Documentary]
# 149395                                      [Documentary]
# 514638                                      [Documentary]
# 574945                                      [Documentary]
# 588296                            [Documentary, TV Movie]
# 602545                                         [Thriller]
# 458074                                      [Documentary]
# 617295                                      [Documentary]
# 617297                                      [Documentary]
# 29047                                       [Documentary]
# 253639                            [Documentary, TV Movie]
# 371556                                      [Documentary]
#
# [108 rows x 8 columns]

# %%
print(actor_full_df.shape)
actor_full_df.describe()
# Out:
# (108, 8)
#        popularity  vote_average  vote_count        revenue         budget  \
# count      108.00        108.00      108.00         108.00         108.00
# mean         6.03          5.61      531.20  54,488,792.89  18,096,666.67
# std          5.42          2.73    1,034.58 126,834,970.42  34,069,419.57
# min          0.60          0.00        0.00           0.00           0.00
# 25%          0.79          5.57        1.00           0.00           0.00
# 50%          5.11          6.45       63.50           0.00           0.00
# 75%          9.56          7.20      515.75  47,792,701.25  21,250,000.00
# max         27.96         10.00    6,405.00 665,692,281.00 150,000,000.00
#
#               profit
# count         108.00
# mean   36,392,126.22
# std   101,493,169.02
# min   -48,000,000.00
# 25%             0.00
# 50%             0.00
# 75%    19,238,706.50
# max   515,692,281.00

# %% [markdown]
# Delete rows with non-movies (eg. Documentary(99), TV Movie(10770) ). Deciding what constitutes a genre.
# 1. Eliminate rows containing Documentery or TV Movie as a genre.
# 2. Eliminate rows where revenue or budget are zero.

# %%
actor_full_df.head(3)
# Out:
#                 title  popularity  vote_average  vote_count    revenue  \
# 380          Rain Man      12.331           7.7        3318  412800000
# 586       Wag the Dog      11.072           6.9         459   64256513
# 693  Meet the Fockers      12.842           6.2        2796  516642939
#
#        budget     profit        genre_names
# 380  25000000  387800000            [Drama]
# 586  15000000   49256513    [Comedy, Drama]
# 693  80000000  436642939  [Comedy, Romance]

# %%
# If Genres is in Documentary(99), TV Movie(10770), delete the row.
# If revenue, budget or profit is zero or NaN, eliminate the row.
# If vote_count	< 20, eliminate the row.
#hoffman_full_df.isnull().sum()

# %%
#Function removes Documentary(99) and TV Movie(10770) genres on each cell
def exclude_genres(cell):
    '''looks for excluded values in a cell
       returns boolean mask'''
    excluded_genre = ['TV Movie','Documentary']
#    print(cell)
    if len(cell) == 0:
        return False
    else:
        for g in excluded_genre:
            if g in cell:
                return False
    return True

#  .map to genres column
actor_full_df = actor_full_df[actor_full_df.genre_names.map(exclude_genres)]            
actor_full_df
# Out:
#                                                     title  popularity  \
# 380                                              Rain Man       12.33
# 586                                           Wag the Dog       11.07
# 693                                      Meet the Fockers       12.84
# 819                                              Sleepers       12.43
# 866                                     Finding Neverland        9.33
# 879                                                  Hook       12.38
# 891                               All the President's Men       18.21
# 994                                            Straw Dogs       10.81
# 1262                                Stranger Than Fiction        8.18
# 1427                     Perfume: The Story of a Murderer       10.04
# 1599                                    I Heart Huckabees        8.18
# 10047             The Messenger: The Story of Joan of Arc       11.56
# 10153                                              Sphere       11.72
# 10199                              The Tale of Despereaux        9.90
# 2284                       Mr. Magorium's Wonder Emporium        8.20
# 10518                                        Marathon Man        8.84
# 10551                                     Family Business        8.38
# 3116                                      Midnight Cowboy       12.61
# 3148                                   Madigan's Millions        0.91
# 10699                                                Hero        8.11
# 10743                                          Confidence        6.86
# 11040                                      Little Big Man        7.86
# 11329                                        Runaway Jury        8.93
# 5924                                             Papillon       12.40
# 31005                                      Moonlight Mile        8.66
# 31200                                              Agatha        2.73
# 23397                                       Straight Time        4.95
# 6950                                             Outbreak       10.65
# 31546                                    American Buffalo        2.59
# 12102                                   Kramer vs. Kramer        7.29
# ...                                                   ...         ...
# 37247                                        The Graduate       11.11
# 61742                                       John and Mary        1.40
# 15854          Kung Fu Panda: Secrets of the Furious Five       11.25
# 16130                                La classe américaine        5.96
# 16409                                  Last Chance Harvey        5.66
# 46829                                    Barney's Version        5.39
# 39451                                      Little Fockers        6.96
# 49444                                     Kung Fu Panda 2       14.72
# 81003               Kung Fu Panda: Secrets of the Masters        8.26
# 52691                          A Wish for Wings That Work        1.91
# 247924                                The Tiger Makes Out        0.60
# 91607   Who Is Harry Kellerman and Why Is He Saying Th...        0.76
# 59855                                    Alfredo, Alfredo        2.31
# 140300                                    Kung Fu Panda 3       15.41
# 212778                                               Chef        9.76
# 313867                             Roald Dahl's Esio Trot        3.97
# 9576                                              Tootsie        9.75
# 286519                                           Boychoir        5.26
# 238215                                        The Cobbler       10.97
# 6439                                       Racing Stripes        8.10
# 271736                                        The Program        6.90
# 396398          The Meyerowitz Stories (New and Selected)        7.82
# 381693               Kung Fu Panda: Secrets of the Scroll        7.20
# 23544                                          The Point!        1.58
# 1581                                          The Holiday       10.99
# 2800                                      Rumor Has It...        8.71
# 461569                                     The Star Wagon        0.62
# 504420                                            Tuesday        0.60
# 8592                                           Dick Tracy        9.94
# 602545                           The Man of the Labyrinth        1.51
#
#         vote_average  vote_count    revenue     budget     profit  \
# 380             7.70        3318  412800000   25000000  387800000
# 586             6.90         459   64256513   15000000   49256513
# 693             6.20        2796  516642939   80000000  436642939
# 819             7.50        1485  165615285   44000000  121615285
# 866             7.30        2353  116766556   25000000   91766556
# 879             6.90        3087  300854823   70000000  230854823
# 891             7.70         809   70600000    8500000   62100000
# 994             7.20         407    3251794    2200000    1051794
# 1262            7.20        1243   53653224   30000000   23653224
# 1427            7.20        2356  132180323   50000000   82180323
# 1599            6.30         362          0   22000000  -22000000
# 10047           6.30         747   66976317   85000000  -18023683
# 10153           6.00         816   37020277   80000000  -42979723
# 10199           5.80         498   86900000   60000000   26900000
# 2284            6.20         697   69474661          0   69474661
# 10518           7.40         441   21709020    6500000   15209020
# 10551           5.60          98   12195695          0   12195695
# 3116            7.50         569   44785053    3600000   41185053
# 3148            3.50           2          0          0          0
# 10699           6.30         204          0   42000000  -42000000
# 10743           6.30         210   23014206   15000000    8014206
# 11040           7.70         250   31559552   15000000   16559552
# 11329           6.90         616   80154140   60000000   20154140
# 5924            8.00         877   53267000   12000000   41267000
# 31005           6.30         110   10011050   21000000  -10988950
# 31200           6.40          17          0          0          0
# 23397           7.20          57    9900000          0    9900000
# 6950            6.40         927  189859560   50000000  139859560
# 31546           5.50          22     665450          0     665450
# 12102           7.50        1028  106260000    8000000   98260000
# ...              ...         ...        ...        ...        ...
# 37247           7.70        1620  104945305    3000000  101945305
# 61742           6.80          10          0          0          0
# 15854           6.60         201          0          0          0
# 16130           7.90          97          0          0          0
# 16409           6.20         131   14879423          0   14879423
# 46829           7.20         219    8454301   30000000  -21545699
# 39451           5.60        1985  310650585  100000000  210650585
# 49444           6.80        3798  665692281  150000000  515692281
# 81003           6.40         127          0          0          0
# 52691           6.00          17          0          0          0
# 247924          6.30           2          0          0          0
# 91607           4.50           5          0          0          0
# 59855           6.30          11          0          0          0
# 140300          6.70        3101  521170825  145000000  376170825
# 212778          7.10        1865   45967935   11000000   34967935
# 313867          7.10          59          0          0          0
# 9576            7.20         850  177200000   21000000  156200000
# 286519          6.80         156          0          0          0
# 238215          5.60         948          0          0          0
# 6439            5.20         285   93772522   30000000   63772522
# 271736          6.30         299    3286448          0    3286448
# 396398          6.40         497          0          0          0
# 381693          6.90          97          0          0          0
# 23544           7.30          17          0          0          0
# 1581            7.00        2686  194168700   85000000  109168700
# 2800            5.50         588   88933562   70000000   18933562
# 461569          8.00           1          0          0          0
# 504420          0.00           0          0          0          0
# 8592            6.10         437  103738726   47000000   56738726
# 602545          0.00           0          0          0          0
#
#                                               genre_names
# 380                                               [Drama]
# 586                                       [Comedy, Drama]
# 693                                     [Comedy, Romance]
# 819                              [Crime, Drama, Thriller]
# 866                                               [Drama]
# 879                  [Adventure, Fantasy, Comedy, Family]
# 891                   [Drama, History, Mystery, Thriller]
# 994                              [Crime, Drama, Thriller]
# 1262                    [Comedy, Drama, Fantasy, Romance]
# 1427                              [Crime, Fantasy, Drama]
# 1599                                    [Comedy, Romance]
# 10047            [Adventure, Drama, Action, History, War]
# 10153           [Science Fiction, Drama, Horror, Mystery]
# 10199                      [Adventure, Animation, Family]
# 2284                            [Comedy, Family, Fantasy]
# 10518                                   [Thriller, Drama]
# 10551   [Action, Comedy, Crime, Drama, Thriller, Mystery]
# 3116                                              [Drama]
# 3148                              [Action, Comedy, Crime]
# 10699                  [Drama, Comedy, Thriller, Mystery]
# 10743          [Action, Comedy, Thriller, Crime, Mystery]
# 11040                 [Adventure, Western, Comedy, Drama]
# 11329                                   [Drama, Thriller]
# 5924                                       [Crime, Drama]
# 31005                                    [Romance, Drama]
# 31200                          [Drama, Mystery, Thriller]
# 23397                                      [Crime, Drama]
# 6950           [Action, Drama, Science Fiction, Thriller]
# 31546                                             [Drama]
# 12102                                             [Drama]
# ...                                                   ...
# 37247                                     [Comedy, Drama]
# 61742                                    [Drama, Romance]
# 15854                         [Animation, Comedy, Family]
# 16130                                            [Comedy]
# 16409                            [Drama, Comedy, Romance]
# 46829                                     [Comedy, Drama]
# 39451                                   [Comedy, Romance]
# 49444                                 [Animation, Family]
# 81003                                 [Animation, Action]
# 52691                                 [Animation, Comedy]
# 247924                                           [Comedy]
# 91607                                     [Drama, Comedy]
# 59855                                   [Comedy, Romance]
# 140300     [Action, Adventure, Animation, Comedy, Family]
# 212778                                           [Comedy]
# 313867                                  [Romance, Comedy]
# 9576                                    [Comedy, Romance]
# 286519                                     [Music, Drama]
# 238215                           [Fantasy, Comedy, Drama]
# 6439                                             [Comedy]
# 271736                                            [Drama]
# 396398                                    [Comedy, Drama]
# 381693     [Adventure, Action, Animation, Family, Comedy]
# 23544                 [Animation, Drama, Family, Fantasy]
# 1581                                    [Comedy, Romance]
# 2800                                             [Comedy]
# 461569                                           [Comedy]
# 504420                       [Family, Animation, Fantasy]
# 8592         [Adventure, Action, Comedy, Thriller, Crime]
# 602545                                         [Thriller]
#
# [68 rows x 8 columns]

# %%
#Eliminate the rows without budget or revenue data
good_money_df = actor_full_df[(actor_full_df.budget > 0.0) & (actor_full_df.revenue > 0.0)]
pd.options.display.float_format = '{:,.2f}'.format
#good_money_df['revenue'] = good_money_df['revenue'].apply(lambda x: '{:d}'.format(x))

#good_money_df['budget'] = good_money_df['budget'].apply(lambda x: '{:,.2f}'.format(x))

#good_money_df['profit'] = good_money_df['profit'].apply(lambda x: '{:,.2f}'.format(x))
#print(good_money_df.info())
print(good_money_df.shape)
print(good_money_df.describe())
good_money_df
# Out:
# (38, 8)
#                                                   title  popularity  \
# 380                                            Rain Man       12.33
# 586                                         Wag the Dog       11.07
# 693                                    Meet the Fockers       12.84
# 819                                            Sleepers       12.43
# 866                                   Finding Neverland        9.33
# 879                                                Hook       12.38
# 891                             All the President's Men       18.21
# 994                                          Straw Dogs       10.81
# 1262                              Stranger Than Fiction        8.18
# 1427                   Perfume: The Story of a Murderer       10.04
# 10047           The Messenger: The Story of Joan of Arc       11.56
# 10153                                            Sphere       11.72
# 10199                            The Tale of Despereaux        9.90
# 10518                                      Marathon Man        8.84
# 3116                                    Midnight Cowboy       12.61
# 10743                                        Confidence        6.86
# 11040                                    Little Big Man        7.86
# 11329                                      Runaway Jury        8.93
# 5924                                           Papillon       12.40
# 31005                                    Moonlight Mile        8.66
# 6950                                           Outbreak       10.65
# 12102                                 Kramer vs. Kramer        7.29
# 9502                                      Kung Fu Panda       19.19
# 12704                                            Ishtar        5.19
# 9700                                      The Lost City        3.70
# 9770                                           Mad City        6.50
# 11774   Lemony Snicket's A Series of Unfortunate Events       25.15
# 37247                                      The Graduate       11.11
# 46829                                  Barney's Version        5.39
# 39451                                    Little Fockers        6.96
# 49444                                   Kung Fu Panda 2       14.72
# 140300                                  Kung Fu Panda 3       15.41
# 212778                                             Chef        9.76
# 9576                                            Tootsie        9.75
# 6439                                     Racing Stripes        8.10
# 1581                                        The Holiday       10.99
# 2800                                    Rumor Has It...        8.71
# 8592                                         Dick Tracy        9.94
#
#         vote_average  vote_count    revenue     budget     profit  \
# 380             7.70        3318  412800000   25000000  387800000
# 586             6.90         459   64256513   15000000   49256513
# 693             6.20        2796  516642939   80000000  436642939
# 819             7.50        1485  165615285   44000000  121615285
# 866             7.30        2353  116766556   25000000   91766556
# 879             6.90        3087  300854823   70000000  230854823
# 891             7.70         809   70600000    8500000   62100000
# 994             7.20         407    3251794    2200000    1051794
# 1262            7.20        1243   53653224   30000000   23653224
# 1427            7.20        2356  132180323   50000000   82180323
# 10047           6.30         747   66976317   85000000  -18023683
# 10153           6.00         816   37020277   80000000  -42979723
# 10199           5.80         498   86900000   60000000   26900000
# 10518           7.40         441   21709020    6500000   15209020
# 3116            7.50         569   44785053    3600000   41185053
# 10743           6.30         210   23014206   15000000    8014206
# 11040           7.70         250   31559552   15000000   16559552
# 11329           6.90         616   80154140   60000000   20154140
# 5924            8.00         877   53267000   12000000   41267000
# 31005           6.30         110   10011050   21000000  -10988950
# 6950            6.40         927  189859560   50000000  139859560
# 12102           7.50        1028  106260000    8000000   98260000
# 9502            7.10        6409  631744560  130000000  501744560
# 12704           4.40          56   14375181   55000000  -40624819
# 9700            6.20          45    4386236    9600000   -5213764
# 9770            6.10         136   10541523   50000000  -39458477
# 11774           6.80        3139  209073645  140000000   69073645
# 37247           7.70        1620  104945305    3000000  101945305
# 46829           7.20         219    8454301   30000000  -21545699
# 39451           5.60        1985  310650585  100000000  210650585
# 49444           6.80        3798  665692281  150000000  515692281
# 140300          6.70        3101  521170825  145000000  376170825
# 212778          7.10        1865   45967935   11000000   34967935
# 9576            7.20         850  177200000   21000000  156200000
# 6439            5.20         285   93772522   30000000   63772522
# 1581            7.00        2686  194168700   85000000  109168700
# 2800            5.50         588   88933562   70000000   18933562
# 8592            6.10         437  103738726   47000000   56738726
#
#                                            genre_names
# 380                                            [Drama]
# 586                                    [Comedy, Drama]
# 693                                  [Comedy, Romance]
# 819                           [Crime, Drama, Thriller]
# 866                                            [Drama]
# 879               [Adventure, Fantasy, Comedy, Family]
# 891                [Drama, History, Mystery, Thriller]
# 994                           [Crime, Drama, Thriller]
# 1262                 [Comedy, Drama, Fantasy, Romance]
# 1427                           [Crime, Fantasy, Drama]
# 10047         [Adventure, Drama, Action, History, War]
# 10153        [Science Fiction, Drama, Horror, Mystery]
# 10199                   [Adventure, Animation, Family]
# 10518                                [Thriller, Drama]
# 3116                                           [Drama]
# 10743       [Action, Comedy, Thriller, Crime, Mystery]
# 11040              [Adventure, Western, Comedy, Drama]
# 11329                                [Drama, Thriller]
# 5924                                    [Crime, Drama]
# 31005                                 [Romance, Drama]
# 6950        [Action, Drama, Science Fiction, Thriller]
# 12102                                          [Drama]
# 9502            [Adventure, Animation, Family, Comedy]
# 12704                      [Action, Adventure, Comedy]
# 9700                                  [Drama, Romance]
# 9770                         [Action, Drama, Thriller]
# 11774                      [Adventure, Comedy, Family]
# 37247                                  [Comedy, Drama]
# 46829                                  [Comedy, Drama]
# 39451                                [Comedy, Romance]
# 49444                              [Animation, Family]
# 140300  [Action, Adventure, Animation, Comedy, Family]
# 212778                                        [Comedy]
# 9576                                 [Comedy, Romance]
# 6439                                          [Comedy]
# 1581                                 [Comedy, Romance]
# 2800                                          [Comedy]
# 8592      [Adventure, Action, Comedy, Thriller, Crime]

# %%
print("Enter valid genre: ")
test_for_genre = input("... MUST be a capitalized: ")

def is_genre(cell):
    #returns True if in, else false (for masking)
    if test_for_genre in cell:
        return True 
    return False

tested_for_genre_df = good_money_df[good_money_df.genre_names.map(is_genre)]
not_tested_for_genre_df = good_money_df[False == good_money_df.genre_names.map(is_genre)]

print(tested_for_genre_df.shape)
print(tested_for_genre_df.describe())
tested_for_genre_df.head(3)
# Out:
# Enter valid genre:
# ... MUST be a capitalized: Drama
# (22, 8)
#        popularity  vote_average  vote_count        revenue        budget  \
# count       22.00         22.00       22.00          22.00         22.00
# mean         9.98          7.09      946.86  81,320,592.23 28,790,909.09
# std          3.03          0.61      837.45  90,684,899.45 24,695,573.33
# min          3.70          6.00       45.00   3,251,794.00  2,200,000.00
# 25%          8.30          6.53      415.50  24,171,653.00  8,775,000.00
# 50%         10.34          7.20      778.00  58,954,868.50 23,000,000.00
# 75%         11.68          7.50    1,189.25 105,931,326.25 48,500,000.00
# max         18.21          8.00    3,318.00 412,800,000.00 85,000,000.00
#
#               profit
# count          22.00
# mean   52,529,683.14
# std    91,222,291.56
# min   -42,979,723.00
# 25%    -3,647,374.50
# 50%    32,419,138.50
# 75%    89,369,997.75
# max   387,800,000.00
#            title  popularity  vote_average  vote_count    revenue    budget  \
# 380     Rain Man       12.33          7.70        3318  412800000  25000000
# 586  Wag the Dog       11.07          6.90         459   64256513  15000000
# 819     Sleepers       12.43          7.50        1485  165615285  44000000
#
#         profit               genre_names
# 380  387800000                   [Drama]
# 586   49256513           [Comedy, Drama]
# 819  121615285  [Crime, Drama, Thriller]

# %%
#Not in genre info
print(not_tested_for_genre_df.shape)
print(not_tested_for_genre_df.describe())
not_tested_for_genre_df.head(3)
# Out:
# (16, 8)
#        popularity  vote_average  vote_count        revenue         budget  \
# count       16.00         16.00       16.00          16.00          16.00
# mean        11.61          6.29    1,986.88 248,993,780.62  75,562,500.00
# std          5.07          0.81    1,740.17 220,078,104.99  46,630,417.47
# min          5.19          4.40       56.00  14,375,181.00  11,000,000.00
# 25%          8.56          5.75      482.75  88,425,171.50  42,750,000.00
# 50%          9.92          6.50    1,925.00 185,684,350.00  70,000,000.00
# 75%         13.31          6.93    3,090.50 362,148,673.50 107,500,000.00
# max         25.15          7.20    6,409.00 665,692,281.00 150,000,000.00
#
#               profit
# count          16.00
# mean  173,431,280.62
# std   185,948,708.22
# min   -40,624,819.00
# 25%    32,950,951.25
# 50%    89,121,172.50
# 75%   267,183,823.50
# max   515,692,281.00
#                         title  popularity  vote_average  vote_count  \
# 693          Meet the Fockers       12.84          6.20        2796
# 879                      Hook       12.38          6.90        3087
# 10199  The Tale of Despereaux        9.90          5.80         498
#
#          revenue    budget     profit                           genre_names
# 693    516642939  80000000  436642939                     [Comedy, Romance]
# 879    300854823  70000000  230854823  [Adventure, Fantasy, Comedy, Family]
# 10199   86900000  60000000   26900000        [Adventure, Animation, Family]

# %%
len(tested_for_genre_df['popularity'])
# Out:
# 22

# %%
#Plot the distribution for popularity

fig, ax = plt.subplots(1, figsize=(16, 3))
ax.scatter(tested_for_genre_df['popularity'], np.repeat(0, len(tested_for_genre_df['popularity'])) + np.random.normal(0, 0.1, len(tested_for_genre_df['popularity'])), marker="*", c='blue', s=120)
ax.scatter(not_tested_for_genre_df['popularity'], np.repeat(1, len(not_tested_for_genre_df['popularity'])) + np.random.normal(0, 0.1, len(not_tested_for_genre_df['popularity'])),marker="*", c='red', s=120)
plt.title(actor + ' Movies TMDB Popularity', size = 20)
ax.set_yticks([0, 1])

ax.set_yticklabels([test_for_genre, "Not " + test_for_genre])  #generalize the label for and genre
#plt.tight_layout()
# Out:
# [Text(0, 0, 'Drama'), Text(0, 0, 'Not Drama')]

# %% [markdown]
# Null Hypothesis: H0 - There is no difference in the popularity of Hoffman's movies in drama vs. non-dramatic categories.
# This hypothesis will be tested with the Rank Sum Statistic aka the U-Test

# %%
def count_winning_pairs(sample_1, sample_2):
    sample_1, sample_2 = np.array(sample_1), np.array(sample_2)
    n_total_wins = 0
    for x in sample_1:
        n_wins = np.sum(x > sample_2) + 0.5*np.sum(x == sample_2)
        n_total_wins += n_wins
    return n_total_wins

not_genre_wins = count_winning_pairs(not_tested_for_genre_df['popularity'], tested_for_genre_df['popularity'])
genre_wins = count_winning_pairs(tested_for_genre_df['popularity'], not_tested_for_genre_df['popularity'])
print("Total Number of Comparisons: {}\n".format(len(not_tested_for_genre_df['profit'])*len(tested_for_genre_df['profit'])))
print("Number of 'Not-in-Genre' Movie Wins: {}\n".format(not_genre_wins))
print("Number of In Genre: " + test_for_genre + " Movie Wins: {}".format(genre_wins))
# Out:
# Total Number of Comparisons: 352
#
# Number of 'Not-in-Genre' Movie Wins: 197.0
#
# Number of In Genre: Drama Movie Wins: 155.0

# %% [markdown]
# The total number of wins is the total number of comparisons between a popularity of an "in genre" movie and the popularity of a not-in-genre movie.

# %%
# Now, using the U-Test (aka the Mann-Whitney U Statistic) calculate 
#    the Rank Sum Statistic
res = stats.mannwhitneyu(not_tested_for_genre_df['popularity'], tested_for_genre_df['popularity'], alternative="greater")
print("p-value for 'Not-in-Genre' Movie Popularity > " + test_for_genre + " Movie Popularity: {:2.3f}".format(res.pvalue))
# Out:
# p-value for 'Not-in-Genre' Movie Popularity > Drama Movie Popularity: 0.272

# %% [markdown]
# *********************************
#
# Clearly, Non Dramatic Hoffman movies are more popular than his Dramatic movies,
# at least in the measure of popularity in the TMDB.
#
# *****Note that this conclusion will change for each actor and each genre tested!!!!

# %%
#Plot the distribution for profit
fig, ax = plt.subplots(1, figsize=(16, 3))
ax.scatter(tested_for_genre_df['revenue'], np.repeat(0, len(tested_for_genre_df['revenue'])) + np.random.normal(0, 0.1, len(tested_for_genre_df['revenue'])), marker='$''\$''$', c='yellow', edgecolors='green', s=330)
ax.scatter(not_tested_for_genre_df['revenue'], np.repeat(1, len(not_tested_for_genre_df['revenue'])) + np.random.normal(0, 0.1, len(not_tested_for_genre_df['revenue'])),marker='$''\$''$',c='blue', edgecolors='green', s=330)
plt.title(actor + ' Movies - Revenue', size=20)


def format_func(value, tick_number):
    # find number of multiples of pi/2
    N = int(np.round(value / 1000000))
    if N == 0:
        return "0"
    elif N == 100:
        return ("$100")
    elif N == 200:
        return ("$200")
    elif N == 300:
        return ("$300")
    elif N == 400:
        return ("$400")
    elif N == 500:
        return ("$500")
    elif N == 600:
        return ("$600")
    elif N == 700:
        return ("$700")
    else:
        return ("$800")

ax.xaxis.set_major_formatter(plt.FuncFormatter(format_func))
ax.set_xlabel('Millions of U.S. Dollars', backgroundcolor='white', color=(.3, .9, .01), animated=True, fontstyle='italic', size=13)
ax.set_yticks([0, 1])
_nothing = ax.set_yticklabels([test_for_genre + "  ", "Not " + test_for_genre], fontstyle='oblique', color=(.18, .31, .31), size='15')
#plt.tight_layout()

# %% [markdown]
# ******
# Null Hypothesis: H0 - There is no difference in the revenue of Hoffman's movies in drama vs. non-dramatic categories.
# This hypothesis will be tested with the Rank Sum Statistic aka the U-Test
# *******Note that this will change for each actor and genre tested.

# %%
def count_winning_pairs(sample_1, sample_2):
    sample_1, sample_2 = np.array(sample_1), np.array(sample_2)
    n_total_wins = 0
    for x in sample_1:
        n_wins = np.sum(x > sample_2) + 0.5*np.sum(x == sample_2)
        n_total_wins += n_wins
    return n_total_wins

not_genre_wins = count_winning_pairs(not_tested_for_genre_df['revenue'], tested_for_genre_df['revenue'])
genre_wins = count_winning_pairs(tested_for_genre_df['revenue'], not_tested_for_genre_df['revenue'])
print("Total Number of Comparisons: {}\n".format(len(not_tested_for_genre_df['revenue'])*len(tested_for_genre_df['revenue'])))
print("Number of 'Not-in-Genre' Movie Wins: {}\n".format(not_genre_wins))
print("Number of In Genre: " + test_for_genre + " Movie Wins: {}".format(genre_wins))
# Out:
# Total Number of Comparisons: 352
#
# Number of 'Not-in-Genre' Movie Wins: 272.0
#
# Number of In Genre: Drama Movie Wins: 80.0

# %% [markdown]
# Remember, the total number of "wins" is the total number of comparisons between the revenue of a in-genre movie and the revenue of a not-in-genre movie.

# %%
# Now, using the U-Test (aka the Mann-Whitney U Statistic) calculate 
#    the Rank Sum Statistic
res = stats.mannwhitneyu(not_tested_for_genre_df['revenue'], tested_for_genre_df['revenue'], alternative="greater")

print("p-value for 'Not-in-Genre' Movie Popularity > " + test_for_genre + " Movie Popularity: {:2.3f}".format(res.pvalue))
# Out:
# p-value for 'Not-in-Genre' Movie Popularity > Drama Movie Popularity: 0.002

# %% [markdown]
# ******
# Clearly, Non Dramatic Hoffman movies are make more money than his Dramatic movies.
# *****Note that this conclusion willchange for each actor & genre tested.
