# %%
import time
import config
import tmdbsimple as tmdb          # tmdbsimple 2.2.0
tmdb.API_KEY = config.tmdb_api_key # get TMDB API key from config.py file

import pprint as pp
import pandas as pd
import numpy as np
import scipy as sp
import scipy.stats as stats
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print("Enter actor's full name...")
actor = input("... MUST be a string: ")
search = tmdb.Search()
actor_response = search.person(query=actor) 
actor_id = search.results[0]['id']
actor_id
# Out:
# Enter actor's full name...
# ... MUST be a string: Robert De Niro
# 380

# %%
actor_movie_credits = actor + " Movies"
actor_movie_credits
# Out:
# 'Robert De Niro Movies'

# %%
#Now get actor's credits
search_actor_id = tmdb.People(actor_id)
response_actor_id = search_actor_id.movie_credits()
response_actor_id
#actor_movie_credits = actor + " Credits")
# Out:
# {'cast': [{'character': "Archibald 'Harry' Tuttle",
#    'credit_id': '52fe4213c3a36847f8001e93',
#    'poster_path': '/55Vfc1beLn3pJF4Lw83TRKHenK6.jpg',
#    'id': 68,
#    'video': False,
#    'vote_count': 1675,
#    'adult': False,
#    'backdrop_path': '/zb5aFldTPWcvAR70vXWTQWkuDnQ.jpg',
#    'genre_ids': [35, 878],
#    'original_language': 'en',
#    'original_title': 'Brazil',
#    'popularity': 10.445,
#    'title': 'Brazil',
#    'vote_average': 7.7,
#    'overview': 'Low-level bureaucrat Sam Lowry escapes the monotony of his day-to-day life through a recurring daydream of himself as a virtuous hero saving a beautiful damsel. Investigating a case that led to the wrongful arrest and eventual death of an innocent man instead of wanted terrorist Harry Tuttle, he meets the woman from his daydream, and in trying to help her gets caught in a web of mistaken identities, mindless bureaucracy and lies.',
#    'release_date': '1985-12-18'},
#   {'character': 'Travis Bickle',
#    'credit_id': '52fe4218c3a36847f80037d7',
#    'poster_path': '/ekstpH614fwDX8DUln1a2Opz0N8.jpg',
#    'id': 103,
#    'video': False,
#    'vote_count': 5578,
#    'adult': False,
#    'backdrop_path': '/hjmJKAVoZ3n2KWbKgasbfdugwhu.jpg',
#    'genre_ids': [80, 18],
#    'original_language': 'en',
#    'original_title': 'Taxi Driver',
#    'popularity': 17.5,
#    'title': 'Taxi Driver',
#    'vote_average': 8.2,
#    'overview': 'A mentally unstable Vietnam War veteran works as a night-time taxi driver in New York City where the perceived decadence and sleaze feeds his urge for violent action, attempting to save a preadolescent prostitute in the process.',
#    'release_date': '1976-02-08'},
#   {'character': 'Al Capone',
#    'credit_id': '52fe421ac3a36847f800428d',
#    'poster_path': '/bDcqwNTwhEDfQHFj7jpt18N6Giz.jpg',
#    'id': 117,
#    'video': False,
#    'vote_count': 2916,
#    'adult': False,
#    'backdrop_path': '/4cJv0cghFaJfepzGdOyqeNaJWYb.jpg',
#    'genre_ids': [80, 18, 36, 53],
#    'original_language': 'en',
#    'original_title': 'The Untouchables',
#    'popularity': 13.225,
#    'title': 'The Untouchables',
#    'vote_average': 7.8,
#    'overview': "Young Treasury Agent Elliot Ness arrives in Chicago and is determined to take down Al Capone, but it's not going to be easy because Capone has the police in his pocket. Ness meets Jimmy Malone, a veteran patrolman and probably the most honorable one on the force. He asks Malone to help him get Capone, but Malone warns him that if he goes after Capone, he is going to war.",
#    'release_date': '1987-06-03'},
#   {'character': 'Louis Gara',
#    'credit_id': '52fe4224c3a36847f8007147',
#    'release_date': '1997-12-24',
#    'vote_count': 3236,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.3,
#    'title': 'Jackie Brown',
#    'genre_ids': [35, 80, 18, 53],
#    'original_language': 'en',
#    'original_title': 'Jackie Brown',
#    'popularity': 11.681,
#    'id': 184,
#    'backdrop_path': '/lXnsC7wRDLccJR3Ju4nInvLiKO.jpg',
#    'overview': "Jackie Brown is a flight attendant who gets caught in the middle of smuggling cash into the country for her gunrunner boss. When the cops try to use Jackie to get to her boss, she hatches a plan—with help from a bail bondsman—to keep the money for herself. Based on Elmore Leonard's novel “Rum Punch”.",
#    'poster_path': '/4XVPYOdMAizdNMSwS0SK3fPJcvR.jpg'},
#   {'character': "John 'Johnny Boy' Civello",
#    'credit_id': '52fe4226c3a36847f8007dc5',
#    'poster_path': '/3awGnJPs7XmGyCB2eFdxVm6GlGd.jpg',
#    'id': 203,
#    'video': False,
#    'vote_count': 871,
#    'adult': False,
#    'backdrop_path': '/11HyjcaDbuHQceElP9gpAshdNez.jpg',
#    'genre_ids': [18, 80],
#    'original_language': 'en',
#    'original_title': 'Mean Streets',
#    'popularity': 8.479,
#    'title': 'Mean Streets',
#    'vote_average': 7.2,
#    'overview': 'A small-time hood must choose from among love, friendship and the chance to rise within the mob.',
#    'release_date': '1973-10-02'},
#   {'character': 'Don Vito Corleone',
#    'credit_id': '52fe422bc3a36847f8009511',
#    'release_date': '1974-12-20',
#    'vote_count': 6205,
#    'video': False,
#    'adult': False,
#    'vote_average': 8.5,
#    'title': 'The Godfather: Part II',
#    'genre_ids': [80, 18],
#    'original_language': 'en',
#    'original_title': 'The Godfather: Part II',
#    'popularity': 22.62,
#    'id': 240,
#    'backdrop_path': '/gLbBRyS7MBrmVUNce91Hmx9vzqI.jpg',
#    'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.',
#    'poster_path': '/bVq65huQ8vHDd1a4Z37QtuyEvpA.jpg'},
#   {'character': 'Rupert Pupkin',
#    'credit_id': '52fe422fc3a36847f800a781',
#    'release_date': '1983-02-18',
#    'vote_count': 702,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.6,
#    'title': 'The King of Comedy',
#    'genre_ids': [35, 18],
#    'original_language': 'en',
#    'original_title': 'The King of Comedy',
#    'popularity': 10.498,
#    'id': 262,
#    'backdrop_path': '/rlWOOdefsyVMbWDYVMsiIb9c47E.jpg',
#    'overview': 'Aspiring comic Rupert Pupkin attempts to achieve success in show business by stalking his idol, a late night talk-show host who craves his own privacy.',
#    'poster_path': '/pbAqLKoLydP7jl6P0vmYwlDtRPD.jpg'},
#   {'character': "David 'Noodles' Aaronson",
#    'credit_id': '52fe4236c3a36847f800c749',
#    'release_date': '1984-06-01',
#    'vote_count': 2375,
#    'video': False,
#    'adult': False,
#    'vote_average': 8.4,
#    'title': 'Once Upon a Time in America',
#    'genre_ids': [80, 18],
#    'original_language': 'en',
#    'original_title': 'Once Upon a Time in America',
#    'popularity': 21.282,
#    'id': 311,
#    'backdrop_path': '/vnT6HzjLSDrAweHn9xWykb8Ii6T.jpg',
#    'overview': 'A former Prohibition-era Jewish gangster returns to the Lower East Side of Manhattan over thirty years later, where he once again must confront the ghosts and regrets of his old life.',
#    'poster_path': '/x733R4ISI0RbKeHhVkXdTMFmTFr.jpg'},
#   {'character': "Sam 'Ace' Rothstein",
#    'credit_id': '52fe424dc3a36847f80139d1',
#    'release_date': '1995-11-22',
#    'vote_count': 2585,
#    'video': False,
#    'adult': False,
#    'vote_average': 8,
#    'title': 'Casino',
#    'genre_ids': [80, 18],
#    'original_language': 'en',
#    'original_title': 'Casino',
#    'popularity': 19.726,
#    'id': 524,
#    'backdrop_path': '/eP41pD4YfyVOjdpEaTmoNrL9DGx.jpg',
#    'overview': 'In early-1970s Las Vegas, low-level mobster Sam "Ace" Rothstein gets tapped by his bosses to head the Tangiers Casino. At first, he\'s a great success in the job, but over the years, problems with his loose-cannon enforcer Nicky Santoro, his ex-hustler wife Ginger, her con-artist ex Lester Diamond and a handful of corrupt politicians put Sam in ever-increasing danger.',
#    'poster_path': '/jC0dqpkRMwh3A1X2PHahTxOaLbp.jpg'},
#   {'character': 'Conrad Brean',
#    'credit_id': '52fe4258c3a36847f8016f19',
#    'poster_path': '/cGatilylRyJiCoOu5T5sAB17HKR.jpg',
#    'id': 586,
#    'video': False,
#    'vote_count': 459,
#    'adult': False,
#    'backdrop_path': '/bWoNwo04ZfZoEvEF8gliyB1EAyS.jpg',
#    'genre_ids': [35, 18],
#    'original_language': 'en',
#    'original_title': 'Wag the Dog',
#    'popularity': 11.072,
#    'title': 'Wag the Dog',
#    'vote_average': 6.9,
#    'overview': "During the final weeks of a presidential race, the President is accused of sexual misconduct. To distract the public until the election, the President's adviser hires a Hollywood producer to help him stage a fake war.",
#    'release_date': '1997-12-25'},
#   {'character': 'Louis Cyphre',
#    'credit_id': '52fe4261c3a36847f8019fbd',
#    'release_date': '1987-03-06',
#    'vote_count': 663,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.2,
#    'title': 'Angel Heart',
#    'genre_ids': [27, 9648],
#    'original_language': 'en',
#    'original_title': 'Angel Heart',
#    'popularity': 9.44,
#    'id': 635,
#    'backdrop_path': '/lMsT7WcLHVucDsOG2aUlm8AbkvZ.jpg',
#    'overview': 'Down-and-out private detective, Harry Angel is ordered by the mysterious Louis Cyphre to go on a mission to find a missing person. His routine failure soon leads to a bloody spar with himself, as he goes on a supernatural journey into his own soul.',
#    'poster_path': '/xFtrVJWygDiK2iZluUxNwuQZ6Sm.jpg'},
#   {'character': 'Jack Byrnes',
#    'credit_id': '52fe426bc3a36847f801d321',
#    'release_date': '2004-12-22',
#    'vote_count': 2796,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.2,
#    'title': 'Meet the Fockers',
#    'genre_ids': [35, 10749],
#    'original_language': 'en',
#    'original_title': 'Meet the Fockers',
#    'popularity': 12.842,
#    'id': 693,
#    'backdrop_path': '/f0eF1rB9KnZPonliSt8CazKvihD.jpg',
#    'overview': "Hard-to-crack ex-CIA man, Jack Byrnes and his wife, Dina head for the warmer climes of Florida to meet son-in-law-to-be, Greg Focker's parents. Unlike their happily matched offspring, the future in-laws find themselves in a situation of opposites that definitely do not attract.",
#    'poster_path': '/xHAqB06iL5D6HyOS6QpgyKkRQHD.jpg'},
#   {'character': 'James Conway',
#    'credit_id': '52fe4274c3a36847f801fd1b',
#    'release_date': '1990-09-19',
#    'vote_count': 5947,
#    'video': False,
#    'adult': False,
#    'vote_average': 8.4,
#    'title': 'GoodFellas',
#    'genre_ids': [80, 18],
#    'original_language': 'en',
#    'original_title': 'GoodFellas',
#    'popularity': 22.002,
#    'id': 769,
#    'backdrop_path': '/sw7mordbZxgITU877yTpZCud90M.jpg',
#    'overview': 'The true story of Henry Hill, a half-Irish, half-Sicilian Brooklyn kid who is adopted by neighbourhood gangsters at an early age and climbs the ranks of a Mafia family under the guidance of Jimmy Conway.',
#    'poster_path': '/pwpGfTImTGifEGgLb3s6LRPd4I6.jpg'},
#   {'character': 'Father Bobby',
#    'credit_id': '52fe427bc3a36847f802228b',
#    'poster_path': '/cDqEv4Fw4JZh2zCfecqw3z09L8z.jpg',
#    'id': 819,
#    'video': False,
#    'vote_count': 1485,
#    'adult': False,
#    'backdrop_path': '/vvdo7wDPJZHfstNMKprqRIM8l3B.jpg',
#    'genre_ids': [80, 18, 53],
#    'original_language': 'en',
#    'original_title': 'Sleepers',
#    'popularity': 12.434,
#    'title': 'Sleepers',
#    'vote_average': 7.5,
#    'overview': 'Two gangsters seek revenge on the state jail worker who during their stay at a youth prison sexually abused them. A sensational court hearing takes place to charge him for the crimes.',
#    'release_date': '1996-10-18'},
#   {'character': 'Neil McCauley',
#    'credit_id': '52fe4292c3a36847f80291f9',
#    'poster_path': '/6pmLVffM9jEYK7VqDJqPblMxfEY.jpg',
#    'id': 949,
#    'video': False,
#    'vote_count': 3382,
#    'adult': False,
#    'backdrop_path': '/7RRuRcGuWkZGuRyYugfXn0Fgrrr.jpg',
#    'genre_ids': [28, 80, 18, 53],
#    'original_language': 'en',
#    'original_title': 'Heat',
#    'popularity': 15.406,
#    'title': 'Heat',
#    'vote_average': 7.8,
#    'overview': 'Obsessive master thief, Neil McCauley leads a top-notch crew on various daring heists throughout Los Angeles while determined detective, Vincent Hanna pursues him without rest. Each man recognizes and respects the ability and the dedication of the other even though they are aware their cat-and-mouse game may end in violence.',
#    'release_date': '1995-12-15'},
#   {'character': 'Bill Sullivan',
#    'credit_id': '52fe42eac3a36847f802c6af',
#    'poster_path': '/s2RYkRXrjUIyOlmzym37kpLTKRz.jpg',
#    'id': 1247,
#    'video': False,
#    'vote_count': 562,
#    'adult': False,
#    'backdrop_path': '/3qvtPTzdeV5cJFBpJO56KFAkF4d.jpg',
#    'genre_ids': [18, 53, 36],
#    'original_language': 'en',
#    'original_title': 'The Good Shepherd',
#    'popularity': 7.7,
#    'title': 'The Good Shepherd',
#    'vote_average': 6.4,
#    'overview': "Edward Wilson, the only witness to his father's suicide and member of the Skull and Bones Society while a student at Yale, is a morally upright young man who values honor and discretion, qualities that help him to be recruited for a career in the newly founded OSS. His dedication to his work does not come without a price though, leading him to sacrifice his ideals and eventually his family.",
#    'release_date': '2006-12-11'},
#   {'character': 'Jake LaMotta',
#    'credit_id': '52fe4300c3a36847f8032f07',
#    'release_date': '1980-11-14',
#    'vote_count': 1939,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.9,
#    'title': 'Raging Bull',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'Raging Bull',
#    'popularity': 15.27,
#    'id': 1578,
#    'backdrop_path': '/yt88nEyDJLN8gOg1FTvCcXCM672.jpg',
#    'overview': "When Jake LaMotta steps into a boxing ring and obliterates his opponent, he's a prizefighter. But when he treats his family and friends the same way, he's a ticking time bomb, ready to go off at any moment. Though LaMotta wants his family's love, something always seems to come between them. Perhaps it's his violent bouts of paranoia and jealousy. This kind of rage helped make him a champ, but in real life, he winds up in the ring alone.",
#    'poster_path': '/3cgzzWsUOBlNjmA5m4qs9BGkezC.jpg'},
#   {'character': 'Jack Byrnes',
#    'credit_id': '52fe4303c3a36847f8033c83',
#    'release_date': '2000-10-06',
#    'vote_count': 3449,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.6,
#    'title': 'Meet the Parents',
#    'genre_ids': [35, 10749],
#    'original_language': 'en',
#    'original_title': 'Meet the Parents',
#    'popularity': 12.756,
#    'id': 1597,
#    'backdrop_path': '/jEBgtMuhM86K0P1u0HS8diHk7ej.jpg',
#    'overview': "Greg Focker is ready to marry his girlfriend, Pam, but before he pops the question, he must win over her formidable father, humorless former CIA agent Jack Byrnes, at the wedding of Pam's sister. As Greg bends over backward to make a good impression, his visit to the Byrnes home turns into a hilarious series of disasters, and everything that can go wrong does, all under Jack's critical, hawklike gaze.",
#    'poster_path': '/wVjtQtzv9IcNRGnOOdcK797Sdxx.jpg'},
#   {'character': 'Max Cady',
#    'credit_id': '52fe4303c3a36847f8033d55',
#    'poster_path': '/4KvrvcqckdupXXO2YnANtyG7QLK.jpg',
#    'id': 1598,
#    'video': False,
#    'vote_count': 1492,
#    'adult': False,
#    'backdrop_path': '/yzTQI4chLWB7Vj2MHxTFtZT4MYo.jpg',
#    'genre_ids': [80, 53, 18, 27],
#    'original_language': 'en',
#    'original_title': 'Cape Fear',
#    'popularity': 9.261,
#    'title': 'Cape Fear',
#    'vote_average': 7.2,
#    'overview': "Sam Bowden is a small-town corporate attorney. Max Cady is a tattooed, cigar-smoking, bible-quoting, psychotic rapist. What do they have in common? Fourteen years ago, Sam was a public defender assigned to Max Cady's rape trial, and he made a serious error: he hid a document from his illiterate client that could have gotten him acquitted. Now, the cagey, bibliophile Cady has been released, and he intends to teach Sam Bowden and his family a thing or two about loss.",
#    'release_date': '1991-11-15'},
#   {'character': 'Lorenzo Anello',
#    'credit_id': '52fe4303c3a36847f8033fdd',
#    'release_date': '1993-09-14',
#    'vote_count': 839,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.6,
#    'title': 'A Bronx Tale',
#    'genre_ids': [80, 18],
#    'original_language': 'en',
#    'original_title': 'A Bronx Tale',
#    'popularity': 9.809,
#    'id': 1607,
#    'backdrop_path': '/aRMZOhLj6IjnmDnRGjblXYMOPxR.jpg',
#    'overview': "Set in the Bronx during the tumultuous 1960s, an adolescent boy is torn between his honest, working-class father and a violent yet charismatic crime boss. Complicating matters is the youngster's growing attraction - forbidden in his neighborhood - for a beautiful black girl.",
#    'poster_path': '/sDbO6LmLYtyqAoFTPpRcMgPSCEO.jpg'},
#   {'character': 'Lt. Moe Tilden',
#    'credit_id': '52fe433ac3a36847f804406b',
#    'poster_path': '/th2UDVewgUAfIXFUaWGWWBxCM91.jpg',
#    'id': 2142,
#    'video': False,
#    'vote_count': 697,
#    'adult': False,
#    'backdrop_path': '/ltq1i8ienPm7OSdOXl3o8ROgmKc.jpg',
#    'genre_ids': [28, 80, 18],
#    'original_language': 'en',
#    'original_title': 'Cop Land',
#    'popularity': 11.098,
#    'title': 'Cop Land',
#    'vote_average': 6.7,
#    'overview': 'Freddy Heflin is the sheriff of a place everyone calls “Cop Land” — a small and seemingly peaceful town populated by the big city police officers he’s long admired. Yet something ugly is taking place behind the town’s peaceful facade. And when Freddy uncovers a massive, deadly conspiracy among these local residents, he is forced to take action and make a dangerous choice between protecting his idols and upholding the law.',
#    'release_date': '1997-08-15'},
#   {'character': 'Cap. Shakespeare',
#    'credit_id': '52fe4349c3a36847f80488ad',
#    'poster_path': '/A9gXvPOnMu961E36x5p3RT4FQ5E.jpg',
#    'id': 2270,
#    'video': False,
#    'vote_count': 2263,
#    'adult': False,
#    'backdrop_path': '/zrGPZc07huy9ApZs7GCrWj05Cy8.jpg',
#    'genre_ids': [12, 14, 10749, 10751],
#    'original_language': 'en',
#    'original_title': 'Stardust',
#    'popularity': 9.242,
#    'title': 'Stardust',
#    'vote_average': 7.2,
#    'overview': "In a countryside town bordering on a magical land, a young man makes a promise to his beloved that he'll retrieve a fallen star by venturing into the magical realm. His journey takes him into a world beyond his wildest dreams and reveals his true identity.",
#    'release_date': '2007-08-09'},
#   {'character': 'Detective Eddie Flemming',
#    'credit_id': '52fe4369c3a36847f8052597',
#    'poster_path': '/qqqleHV8y7NLKt7isSZAvOwVPH6.jpg',
#    'id': 2749,
#    'video': False,
#    'vote_count': 345,
#    'adult': False,
#    'backdrop_path': '/xdha8DvElblfBbNnkpGsF42lAyv.jpg',
#    'genre_ids': [28, 80, 53],
#    'original_language': 'en',
#    'original_title': '15 Minutes',
#    'popularity': 11.765,
#    'title': '15 Minutes',
#    'vote_average': 5.8,
#    'overview': 'When Eastern European criminals Oleg and Emil come to New York City to pick up their share of a heist score, Oleg steals a video camera and starts filming their activities, both legal and illegal. When they learn how the American media circus can make a remorseless killer look like the victim and make them rich, they target media-savvy NYPD Homicide Detective Eddie Flemming and media-naive FDNY Fire Marshal Jordy Warsaw, the cops investigating their murder and torching of their former criminal partner, filming everything to sell to the local tabloid TV show "Top Story."',
#    'release_date': '2001-03-01'},
#   {'character': "Wayne 'Mad Dog' Dobie",
#    'credit_id': '52fe436f9251416c750104e3',
#    'poster_path': '/xZlVITyuTxI3Olu9h64xYPdpZyP.jpg',
#    'id': 10433,
#    'video': False,
#    'vote_count': 145,
#    'adult': False,
#    'backdrop_path': '/pCGZ8707SsPvbgaqy78eahOX4e0.jpg',
#    'genre_ids': [35, 80, 10749, 18],
#    'original_language': 'en',
#    'original_title': 'Mad Dog and Glory',
#    'popularity': 7.812,
#    'title': 'Mad Dog and Glory',
#    'vote_average': 5.7,
#    'overview': 'Wayne Dobie is a shy cop whose low-key demeanor has earned him the affectionate nickname "Mad Dog." After Mad Dog saves the life of Frank Milo, a crime boss and aspiring stand-up comedian, he\'s offered the company of an attractive young waitress named Glory for a week. At first both are uneasy about the arrangement, but they eventually fall in love. However, the situation becomes complicated when Milo demands Glory back.',
#    'release_date': '1993-03-05'},
#   {'character': 'Donald Rimgale',
#    'credit_id': '52fe4375c3a36847f8055925',
#    'release_date': '1991-05-24',
#    'vote_count': 652,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.6,
#    'title': 'Backdraft',
#    'genre_ids': [28, 80, 18, 9648, 53],
#    'original_language': 'en',
#    'original_title': 'Backdraft',
#    'popularity': 11.403,
#    'id': 2924,
#    'backdrop_path': '/iosYFI66bhoB5uC27qvIejrEvJu.jpg',
#    'overview': 'Firemen brothers Brian and Stephen McCaffrey battle each other over past slights while trying to stop an arsonist with a diabolical agenda from torching Chicago.',
#    'poster_path': '/3E2puQrspfkGC6XuxGdB9ghXPtY.jpg'},
#   {'character': 'The Creature',
#    'credit_id': '52fe437fc3a36847f80588e3',
#    'poster_path': '/uG0YLHdiBuWBv99MLwthucsvKLZ.jpg',
#    'id': 3036,
#    'video': False,
#    'vote_count': 600,
#    'adult': False,
#    'backdrop_path': '/vVyF1OMjsdsboBBjEVL8wmOdPNG.jpg',
#    'genre_ids': [18, 27, 878, 10749],
#    'original_language': 'en',
#    'original_title': 'Frankenstein',
#    'popularity': 8.161,
#    'title': 'Frankenstein',
#    'vote_average': 6.3,
#    'overview': 'Based on Mary Shelley\'s novel, "Frankenstein" tells the story of Victor Frankenstein, a promising young doctor who, devastated by the death of his mother during childbirth, becomes obsessed with bringing the dead back to life. His experiments lead to the creation of a monster, which Frankenstein has put together with the remains of corpses. It\'s not long before Frankenstein regrets his actions.',
#    'release_date': '1994-11-04'},
#   {'character': 'Don Lino (voice)',
#    'credit_id': '52fe43879251416c75013e55',
#    'release_date': '2004-10-01',
#    'vote_count': 3802,
#    'video': False,
#    'adult': False,
#    'vote_average': 5.9,
#    'title': 'Shark Tale',
#    'genre_ids': [28, 16, 35, 10751],
#    'original_language': 'en',
#    'original_title': 'Shark Tale',
#    'popularity': 16.385,
#    'id': 10555,
#    'backdrop_path': '/v3RnhCEMu9MVxA5aHWPgVzFGdSG.jpg',
#    'overview': "Oscar is a small fish whose big aspirations often get him into trouble. Meanwhile, Lenny is a great white shark with a surprising secret that no sea creature would guess: He's a vegetarian. When a lie turns Oscar into an improbable hero and Lenny becomes an outcast, the two form an unlikely friendship.",
#    'poster_path': '/r08DpyPyhXcJTfNZAICNGMzcQ8l.jpg'},
#   {'character': 'Himself',
#    'credit_id': '52fe438ec3a36847f805d57d',
#    'poster_path': '/aQOgmbDaAee64gy2lIyH4HwO0z5.jpg',
#    'id': 3212,
#    'video': False,
#    'vote_count': 1,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': '100 Years of Horror: The Frankenstein Family',
#    'popularity': 0.929,
#    'title': '100 Years of Horror: The Frankenstein Family',
#    'vote_average': 10,
#    'overview': 'No overview found.',
#    'release_date': '1996-01-01'},
#   {'character': 'Himself',
#    'credit_id': '52fe438fc3a36847f805d947',
#    'poster_path': '/8JTuv77uZJBnbxhmVsAKJ3vfATo.jpg',
#    'id': 3287,
#    'video': False,
#    'vote_count': 1,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'original_language': 'en',
#    'original_title': "It's Alive: The True Story of Frankenstein",
#    'popularity': 0.667,
#    'title': "It's Alive: The True Story of Frankenstein",
#    'vote_average': 6,
#    'overview': "Mary Shelley created a monster in 1818, and writers, actors and filmmakers haven't been able to get enough of it ever since. The history of the creature on and off the screen includes clips from Thomas Edison's 1910 filmization to Kenneth Branagh's 1994 treatment, plus interviews with Robert De Niro, Mel Brooks, Roger Corman and others. Hosted by Roger Moore; narrated by Eli Wallach.",
#    'release_date': '1994-10-25'},
#   {'character': 'Alfredo Berlinghieri',
#    'credit_id': '52fe43a5c3a36847f8064897',
#    'release_date': '1977-10-07',
#    'vote_count': 213,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.7,
#    'title': '1900',
#    'genre_ids': [18, 36, 10749],
#    'original_language': 'it',
#    'original_title': 'Novecento',
#    'popularity': 7.678,
#    'id': 3870,
#    'backdrop_path': '/7yiI7Z3TSPSOWbEPeWIetZlSzEP.jpg',
#    'overview': "Set in Bertolucci's ancestral region of Emilia, the film chronicles the lives of two men during the political turmoils that took place in Italy in the first half on the 20th century.",
#    'poster_path': '/rzu0PRS3QVn5WB4VIz1Y8cMv1V3.jpg'},
#   {'character': 'Leonard Lowe',
#    'credit_id': '52fe43e09251416c750219f9',
#    'poster_path': '/6vkJhhd9h9QxMGHYQjVY1fY5XSI.jpg',
#    'id': 11005,
#    'video': False,
#    'vote_count': 1166,
#    'adult': False,
#    'backdrop_path': '/xzNas1TCJh7S11nIfhZD7gImfWj.jpg',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'Awakenings',
#    'popularity': 8.931,
#    'title': 'Awakenings',
#    'vote_average': 7.8,
#    'overview': 'Dr. Malcolm Sayer, a shy research physician, uses an experimental drug to "awaken" the catatonic victims of a rare disease. Leonard is the first patient to receive the controversial treatment. His awakening, filled with awe and enthusiasm, proves a rebirth for Sayer too, as the exuberant patient reveals life\'s simple but unutterably sweet pleasures to the introverted doctor.',
#    'release_date': '1990-12-19'},
#   {'character': 'Richard Wells',
#    'credit_id': '52fe43ed9251416c7502351b',
#    'poster_path': '/6ma5D4uW33tu9LWBH2G0wGuzUkL.jpg',
#    'id': 11058,
#    'video': False,
#    'vote_count': 224,
#    'adult': False,
#    'backdrop_path': '/u2yiftT7YTSqfcwTSqWQr4hCvZG.jpg',
#    'genre_ids': [18, 27, 878, 53],
#    'original_language': 'en',
#    'original_title': 'Godsend',
#    'popularity': 9.15,
#    'title': 'Godsend',
#    'vote_average': 4.8,
#    'overview': 'A couple agree to have their deceased son cloned under the supervision of an enigmatic doctor, but bizarre things start to happen years after his rebirth.',
#    'release_date': '2004-04-30'},
#   {'character': 'David Callaway',
#    'credit_id': '52fe43f69251416c75024589',
#    'release_date': '2005-01-27',
#    'vote_count': 836,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.3,
#    'title': 'Hide and Seek',
#    'genre_ids': [27, 9648, 53],
#    'original_language': 'en',
#    'original_title': 'Hide and Seek',
#    'popularity': 8.059,
#    'id': 11096,
#    'backdrop_path': '/gGFDS4JxyhftFR6fIqgRfQ31TYr.jpg',
#    'overview': "David Callaway tries to piece together his life in the wake of his wife's suicide and has been left to raise his nine-year-old daughter, Emily on his own. David is at first amused to discover that Emily has created an imaginary friend named 'Charlie', but it isn't long before 'Charlie' develops a sinister and violent side, and as David struggles with his daughter's growing emotional problems, he comes to the frightening realisation that 'Charlie' isn't just a figment of Emily's imagination.",
#    'poster_path': '/g8qIjDUzru1c0reqca7dJ6cmte8.jpg'},
#   {'character': 'Danny',
#    'credit_id': '52fe4412c3a368484e00db6d',
#    'release_date': '1971-12-01',
#    'vote_count': 10,
#    'video': False,
#    'adult': False,
#    'vote_average': 5.7,
#    'title': 'Born to Win',
#    'genre_ids': [35, 80, 18],
#    'original_language': 'en',
#    'original_title': 'Born to Win',
#    'popularity': 2.047,
#    'id': 21256,
#    'backdrop_path': '/Ar0PSIPPCEigjCMhhlSCnULpNqE.jpg',
#    'overview': "The film follows Jay Jay, a former hair dresser who has become a drug addict. He lives his new life by doing deals for Vivian from time to time. One day he meets Parm, a free-spirited girl. The two fall in love. Jay Jay's drug habit grows, and he soon resorts to robbery. On the threat of arrest, he works alongside two dirty policemen by becoming a narc, and reports on his former fellow junkies. Yet, as the movie continues, Jay Jay sinks deeper into turmoil with feelings of self-hatred.",
#    'poster_path': '/yOnmSnEeLhTRx7Uz1TEs0a4atr4.jpg'},
#   {'character': 'Det. Mitch Preston',
#    'credit_id': '52fe4426c3a36847f808536b',
#    'release_date': '2002-03-14',
#    'vote_count': 493,
#    'video': False,
#    'adult': False,
#    'vote_average': 5.4,
#    'title': 'Showtime',
#    'genre_ids': [28, 35],
#    'original_language': 'en',
#    'original_title': 'Showtime',
#    'popularity': 9.349,
#    'id': 5851,
#    'backdrop_path': '/rQwWtujstlG3dzfGsnp57Hh3pmj.jpg',
#    'overview': 'A spoof of buddy cop movies where two very different cops are forced to team up on a new reality based T.V. cop show.',
#    'poster_path': '/a1vRxRQFRwheHXJESIt2cnfudaH.jpg'},
#   {'character': 'Nick Wells',
#    'credit_id': '52fe44339251416c7502c3c7',
#    'poster_path': '/8d9HG9An0WOPNQywo99QyEptLHz.jpg',
#    'id': 11371,
#    'video': False,
#    'vote_count': 793,
#    'adult': False,
#    'backdrop_path': '/cQ7y4GAwmDZAHev8IwOzA6Utr3z.jpg',
#    'genre_ids': [28, 80, 53, 9648],
#    'original_language': 'en',
#    'original_title': 'The Score',
#    'popularity': 10.322,
#    'title': 'The Score',
#    'vote_average': 6.7,
#    'overview': 'An aging thief hopes to retire and live off his ill-gotten wealth when a young kid convinces him into doing one last heist.',
#    'release_date': '2001-07-13'},
#   {'character': 'Ned',
#    'credit_id': '52fe4433c3a36847f8088315',
#    'poster_path': '/9he4Lp6Wkc9X7O46wMn92Ei6lB1.jpg',
#    'id': 5971,
#    'video': False,
#    'vote_count': 214,
#    'adult': False,
#    'backdrop_path': '/3yDXJnBqHdjztrd7YVneRe30LOY.jpg',
#    'genre_ids': [35, 80, 18],
#    'original_language': 'en',
#    'original_title': "We're No Angels",
#    'popularity': 7.926,
#    'title': "We're No Angels",
#    'vote_average': 6.2,
#    'overview': "Two escaped cons' only prayer to escape is to pass themselves off as priests and pass by the police blockade at the border into the safety of Canada.",
#    'release_date': '1989-12-15'},
#   {'character': 'Rodrigo Mendoza',
#    'credit_id': '52fe443b9251416c7502d787',
#    'release_date': '1986-09-29',
#    'vote_count': 623,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.4,
#    'title': 'The Mission',
#    'genre_ids': [28, 12, 18, 36],
#    'original_language': 'en',
#    'original_title': 'The Mission',
#    'popularity': 7.216,
#    'id': 11416,
#    'backdrop_path': '/22GLW4Qgs7NycHLjsp8whRCuky4.jpg',
#    'overview': 'When a Spanish Jesuit goes into the South American wilderness to build a mission in the hope of converting the Indians of the region, a slave hunter is converted and joins his mission. When Spain sells the colony to Portugal, they are forced to defend all they have built against the Portugese aggressors.',
#    'poster_path': '/oTU13XXz4WHisDWKX3X6dFWEjC0.jpg'},
#   {'character': 'Michael Vronsky',
#    'credit_id': '52fe44849251416c750378c7',
#    'release_date': '1978-12-08',
#    'vote_count': 1828,
#    'video': False,
#    'adult': False,
#    'vote_average': 8,
#    'title': 'The Deer Hunter',
#    'genre_ids': [18, 10752],
#    'original_language': 'en',
#    'original_title': 'The Deer Hunter',
#    'popularity': 12.735,
#    'id': 11778,
#    'backdrop_path': '/ojG57hVx69vhk5DDGPIcfyRR55I.jpg',
#    'overview': 'A group of working-class friends decides to enlist in the Army during the Vietnam War and finds it to be hellish chaos -- not the noble venture they imagined. Before they left, Steven married his pregnant girlfriend -- and Michael and Nick were in love with the same woman. But all three are different men upon their return.',
#    'poster_path': '/slNJESItHPqp1CENEJQUPw8d7WE.jpg'},
#   {'character': 'Lloyd Barker',
#    'credit_id': '52fe448a9251416c9101447b',
#    'poster_path': '/mMLxOsKwQQ8rxog5zV4VKueJrU.jpg',
#    'id': 31581,
#    'video': False,
#    'vote_count': 33,
#    'adult': False,
#    'backdrop_path': '/cLgcFublwz1wdCasy9D8pr9Oa3x.jpg',
#    'genre_ids': [28, 18, 53, 80],
#    'original_language': 'en',
#    'original_title': 'Bloody Mama',
#    'popularity': 2.604,
#    'title': 'Bloody Mama',
#    'vote_average': 5.4,
#    'overview': 'Sexually abused as a young girl, Kate "Ma" Barker (Shelley Winters) grows into a violently powerful woman by the 1930s. She lovingly dominates her grown sons, and grooms them into a pack of tough crooks. The boys include the cruel Herman (Don Stroud), who still shares a bed with Ma; Fred (Robert Walden), an ex-con who fell in love with a fellow prisoner; and Lloyd (Robert De Niro), who gets high on whatever\'s handy. Together they form a deadly, bizarre family of Depression-era bandits.',
#    'release_date': '1970-03-24'},
#   {'character': 'Walt Koontz',
#    'credit_id': '52fe448a9251416c910144c3',
#    'poster_path': '/fkwkkUnaTmhaWt2OGBRepYr7yB5.jpg',
#    'id': 31582,
#    'video': False,
#    'vote_count': 108,
#    'adult': False,
#    'backdrop_path': '/5GYxvLeCDzsMIiZV3eJeaSXj9lm.jpg',
#    'genre_ids': [35, 18],
#    'original_language': 'en',
#    'original_title': 'Flawless',
#    'popularity': 6.28,
#    'title': 'Flawless',
#    'vote_average': 6.2,
#    'overview': 'An ultraconservative police officer suffers a debilitating stroke and is assigned to a rehabilitative program that includes singing lessons - with the drag queen next door.',
#    'release_date': '1999-11-26'},
#   {'character': 'Dwight Hansen',
#    'credit_id': '52fe4492c3a36847f809dcd1',
#    'poster_path': '/xs8ebrGRGu6Y9ebu2dJFdm9yaZP.jpg',
#    'id': 8092,
#    'video': False,
#    'vote_count': 422,
#    'adult': False,
#    'backdrop_path': '/8C7ZLEOWMMusJERzyJoYVvTH6eh.jpg',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'This Boy’s Life',
#    'popularity': 7.952,
#    'title': 'This Boy’s Life',
#    'vote_average': 7,
#    'overview': "In 1957, a son and mother flee the East and an abusive boyfriend to find a new life, and end up in Seattle, where the mother meets a polite garage mechanic. The boy continually gets into trouble by hanging out with the wrong crowd. The mom marries the mechanic, but they soon find out that he's an abusive and unreasoning alcoholic, and they struggle to maintain hope in an impossible situation as the boy grows up with plans to escape the small town by any means possible. Based on a true story by Tobias Wolff.",
#    'release_date': '1993-04-09'},
#   {'character': 'Sam',
#    'credit_id': '52fe4494c3a36847f809e317',
#    'release_date': '1998-09-25',
#    'vote_count': 1151,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.9,
#    'title': 'Ronin',
#    'genre_ids': [28, 12, 80, 53],
#    'original_language': 'en',
#    'original_title': 'Ronin',
#    'popularity': 9.516,
#    'id': 8195,
#    'backdrop_path': '/l1OwGq9f2ZzlFJ35tP6mhhDqkMw.jpg',
#    'overview': "A briefcase with undisclosed contents – sought by Irish terrorists and the Russian mob – makes its way into criminals' hands. An Irish liaison assembles a squad of mercenaries, or 'ronin', and gives them the thorny task of recovering the case.",
#    'poster_path': '/UoFUXemMYGKuCN01Y111JlPjjr.jpg'},
#   {'character': "Master Chief Leslie W. Sunday ('Billy')",
#    'credit_id': '52fe44ae9251416c7503d50d',
#    'poster_path': '/wNUAnXV1mzOOfvnVBIYsalkk078.jpg',
#    'id': 11978,
#    'video': False,
#    'vote_count': 1011,
#    'adult': False,
#    'backdrop_path': '/7wVtInOyDrYlcZGQcaGGH4rm8iJ.jpg',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'Men of Honor',
#    'popularity': 9.018,
#    'title': 'Men of Honor',
#    'vote_average': 7.2,
#    'overview': "Against formidable odds -- and an old-school diving instructor embittered by the U.S. Navy's new, less prejudicial policies -- Carl Brashear sets his sights on becoming the Navy's first African-American master diver in this uplifting true story. Their relationship starts out on the rocks, but fate ultimately conspires to bring the men together into a setting of mutual respect, triumph and honor.",
#    'release_date': '2000-11-09'},
#   {'character': 'Father Des Spellacy',
#    'credit_id': '52fe44b89251416c9101a917',
#    'release_date': '1981-09-25',
#    'vote_count': 54,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.1,
#    'title': 'True Confessions',
#    'genre_ids': [80, 18],
#    'original_language': 'en',
#    'original_title': 'True Confessions',
#    'popularity': 5.447,
#    'id': 32077,
#    'backdrop_path': '/cbzZhWQdzXAQUwwcUp76xSdLLFm.jpg',
#    'overview': 'A cop clashes with his priest brother while investigating the brutal murder of a young prostitute',
#    'poster_path': '/8ofh3dT6IlUfUU0TIQi2ocIwcC7.jpg'},
#   {'character': 'Ben',
#    'credit_id': '52fe44cac3a36847f80aa237',
#    'poster_path': '/hr5oELD0PJxnRGAFsWT22uFtcyP.jpg',
#    'id': 8944,
#    'video': False,
#    'vote_count': 222,
#    'adult': False,
#    'backdrop_path': '/4dyRBYhJQi23vFHyyrsWlJz6Yca.jpg',
#    'genre_ids': [35, 18],
#    'original_language': 'en',
#    'original_title': 'What Just Happened',
#    'popularity': 5.808,
#    'title': 'What Just Happened',
#    'vote_average': 5.4,
#    'overview': "During the course of an ordinary week in Hollywood, movie producer Ben (Robert De Niro) must navigate his way through shark-infested waters as he struggles to complete his latest projects. A demanding studio boss (Catherine Keener) demands extensive changes to a movie starring Sean Penn, while another chief won't greenlight a project unless star Bruce Willis shaves his beard. Meanwhile, Ben tries to reconcile with his wife and maintain a relationship with his young daughter.",
#    'release_date': '2008-10-17'},
#   {'character': 'Jack Walsh',
#    'credit_id': '52fe44d1c3a36847f80abcdf',
#    'release_date': '1988-07-20',
#    'vote_count': 435,
#    'video': False,
#    'adult': False,
#    'vote_average': 7.2,
#    'title': 'Midnight Run',
#    'genre_ids': [12, 35, 80],
#    'original_language': 'en',
#    'original_title': 'Midnight Run',
#    'popularity': 7.075,
#    'id': 9013,
#    'backdrop_path': '/t2qRUwdbqacM0SmHGJxkgneyzR7.jpg',
#    'overview': 'An accountant embezzles $15 million of mob money, jumps bail and is chased by bounty hunters, the FBI, and the Mafia.',
#    'poster_path': '/avLXoDhPPbKgdOU7wsoVlOzYfUP.jpg'},
#   {'character': 'Frank Goode',
#    'credit_id': '52fe44f1c3a368484e03fac5',
#    'poster_path': '/twn8J0uDkZXmSx702nkGJNVX23n.jpg',
#    'id': 26171,
#    'video': False,
#    'vote_count': 533,
#    'adult': False,
#    'backdrop_path': '/95hS2UOxAMpLUhC5SuImXXsgmZl.jpg',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': "Everybody's Fine",
#    'popularity': 7.042,
#    'title': "Everybody's Fine",
#    'vote_average': 6.6,
#    'overview': "Eight months after the death of his wife, Frank Goode looks forward to a reunion with his four adult children. When all of them cancel their visits at the last minute, Frank, against the advice of his doctor, sets out on a road trip to reconnect with his offspring. As he visits each one in turn, Frank finds that his children's lives are not quite as picture-perfect as they've made them out to be.",
#    'release_date': '2009-12-04'},
#   {'character': 'Prisoner / Lustig',
#    'credit_id': '52fe44f4c3a36847f80b3f3d',
#    'release_date': '1998-01-30',
#    'vote_count': 258,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.6,
#    'title': 'Great Expectations',
#    'genre_ids': [35, 18, 10749],
#    'original_language': 'en',
#    'original_title': 'Great Expectations',
#    'popularity': 8.594,
#    'id': 9410,
#    'backdrop_path': '/l4zs8et9D949eKzmFmrzOVXVBRP.jpg',
#    'overview': 'Loosely based on the Charles Dickens\' classic novel, "Great Expectations" is a sensual tale of a young man\'s unforgettable passage into manhood, and the three individuals who will undeniably change his life forever. Through the surprising interactions of these vivid characters, "Great Expectations" takes a unique and contemporary look at life\'s great coincidences.',
#    'poster_path': '/eIJqLiZyu4QAY2a1ZGMqhOI0yNI.jpg'},
#   {'character': 'Paul Vitti',
#    'credit_id': '52fe4506c3a36847f80b7c33',
#    'poster_path': '/eqa4TEgkx63WRhqyD8eTwmL7bUi.jpg',
#    'id': 9535,
#    'video': False,
#    'vote_count': 906,
#    'adult': False,
#    'backdrop_path': '/sGEzPq2p85Wgn0JbAK0MVgCpzDL.jpg',
#    'genre_ids': [35, 80],
#    'original_language': 'en',
#    'original_title': 'Analyze This',
#    'popularity': 9.007,
#    'title': 'Analyze This',
#    'vote_average': 6.4,
#    'overview': 'Countless wiseguy films are spoofed in this film that centers on the neuroses and angst of a powerful Mafia racketeer who suffers from panic attacks. When Paul Vitti needs help dealing with his role in the "family," unlucky shrink Dr. Ben Sobel is given just days to resolve Vitti\'s emotional crisis and turn him into a happy, well-adjusted gangster.',
#    'release_date': '1999-03-05'},
#   {'character': 'Gil Renard',
#    'credit_id': '52fe450bc3a36847f80b8fa5',
#    'poster_path': '/fdW8T9kkYlPyOGh0V5eodFr8SQq.jpg',
#    'id': 9566,
#    'video': False,
#    'vote_count': 367,
#    'adult': False,
#    'backdrop_path': '/AlvcFqLx3JYNkp8UJUUtvxsCtWZ.jpg',
#    'genre_ids': [18, 9648, 53],
#    'original_language': 'en',
#    'original_title': 'The Fan',
#    'popularity': 9.045,
#    'title': 'The Fan',
#    'vote_average': 5.9,
#    'overview': 'When the San Francisco Giants pay centerfielder Bobby Rayburn $40 million to lead their team to the World Series, no one is happier or more supportive than #1 fan Gil Renard.  So when Rayburn becomes mired in the worst slump of his career, the obsessed Renard decides to stop at nothing to help his idol regain his former glory... not even murder.',
#    'release_date': '1996-08-15'},
#   {'character': 'Jimmy Doyle',
#    'credit_id': '52fe450d9251416c7504a0a9',
#    'poster_path': '/dIOJNDtWmAMQgxB1wPAhBtM96C9.jpg',
#    'id': 12637,
#    'video': False,
#    'vote_count': 179,
#    'adult': False,
#    'backdrop_path': '/oTBxvPzfn2EtTV7b7FGGmXxJqP3.jpg',
#    'genre_ids': [18, 10402, 10749],
#    'original_language': 'en',
#    'original_title': 'New York, New York',
#    'popularity': 6.6,
#    'title': 'New York, New York',
#    'vote_average': 6.5,
#    'overview': 'An egotistical saxophone player and a young singer meet on V-J Day and embark upon a strained and rocky romance, even as their careers begin a long uphill climb.',
#    'release_date': '1977-06-21'},
#   {'character': 'Marvin',
#    'credit_id': '52fe4534c3a36847f80c1e35',
#    'release_date': '1996-12-18',
#    'vote_count': 277,
#    'video': False,
#    'adult': False,
#    'vote_average': 6.7,
#    'title': "Marvin's Room",
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': "Marvin's Room",
#    'popularity': 8.63,
#    'id': 9819,
#    'backdrop_path': '/dXGjxSaKV02s1It9i0IF7HhVQ8l.jpg',
#    'overview': 'A leukemia patient attempts to end a 20-year feud with her sister to get her bone marrow.',
#    'poster_path': '/mousrrNQ0ypRjCvgYzgMrusTW8b.jpg'},
#   {'character': 'Paul Vitti',
#    'credit_id': '52fe454cc3a36847f80c64ff',
#    'poster_path': '/qq12vSFojs306GpQh2hf5oILMsc.jpg',
#    'id': 9932,
#    'video': False,
#    'vote_count': 649,
#    'adult': False,
#    'backdrop_path': '/4HBhDTmAY2MkdvQm7WDyDIgNDNj.jpg',
#    'genre_ids': [35, 80],
#    'original_language': 'en',
#    'original_title': 'Analyze That',
#    'popularity': 9.424,
#    'title': 'Analyze That',
#    'vote_average': 5.7,
#    'overview': "The mafia's Paul Vitti is back in prison and will need some serious counseling when he gets out. Naturally, he returns to his analyst Dr. Ben Sobel for help and finds that Sobel needs some serious help himself as he has inherited the family practice, as well as an excess stock of stress.",
#    'release_date': '2002-12-06'},
#   {'character': 'Turk',
#    'credit_id': '52fe45639251416c75054ac7',
#    'poster_path': '/97Jvzj9ekO9mzYqgvsyGRMepres.jpg',
#    'id': 13389,
#    'video': False,
#    'vote_count': 646,
#    'adult': False,
#    'backdrop_path': '/bWMkiU2ryh8JL7hkrxoiWRquyKa.jpg',
#    'genre_ids': [28, 80, 18, 53],
#    'original_language': 'en',
#    'original_title': 'Righteous Kill',
#    'popularity': 8.992,
#    'title': 'Righteous Kill',
#    'vote_average': 5.9,
#    'overview': 'Two veteran New York City detectives work to identify the possible connection between a recent murder and a case they believe they solved years ago; is there a serial killer on the loose, and did they perhaps put the wrong person behind bars?',
#    'release_date': '2008-09-12'},
#   {'character': 'Vincent LaMarca',
#    'credit_id': '52fe45779251416c7505783d',
#    'poster_path': '/rFb1HGXjh3X1iVFXUCIKuFdKykM.jpg',
#    'id': 13536,
#    'video': False,
#    'vote_count': 167,
#    'adult': False,
#    'backdrop_path': '/6bq2pi8Cor0X3GNgWyfrEde02DY.jpg',
#    'genre_ids': [80, 18, 9648],
#    'original_language': 'en',
#    'original_title': 'City By The Sea',
#    'popularity': 8.072,
#    'title': 'City By The Sea',
#    'vote_average': 5.8,
#    'overview': 'A man struggling to come to terms with the sins of his father makes the terrible discovery that his own son has fallen into a life of crime in a drama based on a true story. Vincent LaMarca is a dedicated and well-respected New York City police detective who has gone to great lengths to distance himself from his past.',
#    'release_date': '2002-09-06'},
#   {'character': 'Stanley Everett Cox',
#    'credit_id': '52fe45cc9251416c9103eb51',
#    'poster_path': '/AugbguhFPQ2aHDKMyBecaJiQLWy.jpg',
#    'id': 36094,
#    'video': False,
#    'vote_count': 59,
#    'adult': False,
#    'backdrop_path': '/12sWAG62Baqt91qIHNEo8WlaFq4.jpg',
#    'genre_ids': [18, 10749],
#    'original_language': 'en',
#    'original_title': 'Stanley & Iris',
#    'popularity': 2.82,
#    'title': 'Stanley & Iris',
#    'vote_average': 6.5,
#    'overview': 'An illiterate cook at a company cafeteria tries for the attention of a newly widowed woman. As they get to know one another, she discovers his inability to read. When he is fired, she takes on trying to teach him to read in her kitchen each night.',
#    'release_date': '1990-02-09'},
#   {'character': 'Harry Fabian',
#    'credit_id': '52fe45dc9251416c91040dcf',
#    'poster_path': '/4XhlqA4PdDzKcFhKPBPj6DW3qfT.jpg',
#    'id': 36288,
#    'video': False,
#    'vote_count': 29,
#    'adult': False,
#    'backdrop_path': '/o5qrTpoSvPJ9MlJi1uWNhiwDlAT.jpg',
#    'genre_ids': [80],
#    'original_language': 'en',
#    'original_title': 'Night and the City',
#    'popularity': 4.7,
#    'title': 'Night and the City',
#    'vote_average': 5.6,
#    'overview': 'Looking to get rich quick, an unsuccessful lawyer uses dishonest means to try to become a boxing promoter.',
#    'release_date': '1992-10-11'},
#   {'character': 'Bruce Pearson',
#    'credit_id': '52fe4604c3a36847f80e762f',
#    'poster_path': '/8eI9sJzzv7he77YifyMJkvihwhT.jpg',
#    'id': 42459,
#    'video': False,
#    'vote_count': 21,
#    'adult': False,
#    'backdrop_path': '/yncYbFoAlaLLWsuq5r6vLU81tQK.jpg',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'original_title': 'Bang the Drum Slowly',
#    'popularity': 3.301,
#    'title': 'Bang the Drum Slowly',
#    'vote_average': 6.7,
#    'overview': "The story of a New York pro baseball team and two of its players. Henry Wiggen is the star pitcher and Bruce Pearson is the normal, everyday catcher who is far from the star player on the team and friend to all of his teammates. During the off-season, Bruce learns that he is terminally ill, and Henry, his only true friend, is determined to be the one person there for him during his last season with the club. Throughout the course of the season, Henry and his teammates attempt to deal with Bruce's impending illness, all the while attempting to make his last year a memorable one.",
#    'release_date': '1973-08-26'},
#   {'character': 'Jon Rubin',
#    'credit_id': '52fe460bc3a36847f80e9159',
#    'poster_path': '/l4rge37nxK6nQFQVJxgdRaBG1xS.jpg',
#    'id': 42589,
#    'video': False,
#    'vote_count': 43,
#    'adult': False,
#    'backdrop_path': '/vl8dVttuNMYmsT97pKGeGRGNTZb.jpg',
#    'genre_ids': [35, 18],
#    'original_language': 'en',
#    'original_title': 'Hi, Mom!',
#    'popularity': 3.91,
#    'title': 'Hi, Mom!',
#    'vote_average': 6,
#    'overview': "Vietnam vet Jon Rubin returns to New York and rents a rundown flat in Greenwich Village. It is in this flat that he begins to film, 'Peeping Tom' style, the people in the apartment across the street. His obsession with making films leads him to fall in with a radical 'Black Power' group, which in turn leads him to carry out a bizarre act of urban terrorism.",
#    'release_date': '1970-04-27'},
#   {'character': 'Great sewer (voice)',
#    'credit_id': '52fe4662c3a368484e08dcb9',
#    'poster_path': '/mxtyyPSPcuCn1aNCzpkGfV4eLi.jpg',
#    'id': 61777,
#    'video': False,
#    'vote_count': 9,
#    'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99, 10752],
#    'original_language': 'en',
#    'original_title': 'Dear America: Letters Home from Vietnam',
#    'popularity': 1.527,
#    'title': 'Dear America: Letters Home from Vietnam',
#    'vote_average': 7.3,
# ...
#   {'id': 12395,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Thunderheart',
#    'job': 'Producer',
#    'overview': 'An FBI man with Sioux background is sent to a reservation to help with a murder investigation, where he has to come to terms with his heritage.',
#    'vote_count': 117,
#    'video': False,
#    'poster_path': '/tn3TYcas6zjd4UcoYIsagCeGpY3.jpg',
#    'backdrop_path': '/mPNFHfbBhjUSLHutbaPu4qjQjbr.jpg',
#    'title': 'Thunderheart',
#    'popularity': 10.164,
#    'genre_ids': [28, 12, 80, 18, 9648, 53],
#    'vote_average': 6.4,
#    'adult': False,
#    'release_date': '1992-04-03',
#    'credit_id': '52fe44dc9251416c7504376f'},
#   {'id': 39451,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Little Fockers',
#    'job': 'Producer',
#    'overview': "It has taken 10 years, two little Fockers with wife Pam and countless hurdles for Greg to finally get in with his tightly wound father-in-law, Jack. After the cash-strapped dad takes a job moonlighting for a drug company, Jack's suspicions about his favorite male nurse come roaring back. When Greg and Pam's entire clan descends for the twins' birthday party, Greg must prove to the skeptical Jack that he's fully capable as the man of the house.",
#    'vote_count': 1985,
#    'video': False,
#    'poster_path': '/qixmjH8fLD9IkboPO7FKxAqzwRJ.jpg',
#    'backdrop_path': '/gpodYxsJZ6OVlpPo0fYkubTBWx9.jpg',
#    'title': 'Little Fockers',
#    'popularity': 6.964,
#    'genre_ids': [35, 10749],
#    'vote_average': 5.6,
#    'adult': False,
#    'release_date': '2010-12-21',
#    'credit_id': '52fe471a9251416c9106a171'},
#   {'id': 71825,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Mistress',
#    'job': 'Producer',
#    'overview': 'A comedy about a screenwriter (Wuhl) whose old movie script is read by a producer (Landau) and the search for financial backers begins. But it seems that each money source (Aiello, DeNiro, Wallach) has his own mistress that he wants put into the film. Gradually, the screenwriter is forced to make changes to his script to accommodate these backers until he finally sees no semblance of his original ideas in the writing.',
#    'vote_count': 14,
#    'video': False,
#    'release_date': '1992-07-24',
#    'vote_average': 5.5,
#    'title': 'Mistress',
#    'popularity': 2.501,
#    'genre_ids': [35],
#    'backdrop_path': '/olzgaTu8HuNyMCaxGnL0RfNmMNe.jpg',
#    'adult': False,
#    'poster_path': '/aYSqbNwWLEqb0rFazgIIGYSCfHD.jpg',
#    'credit_id': '52fe484ac3a368484e0f1685'},
#   {'id': 1597,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Meet the Parents',
#    'job': 'Producer',
#    'overview': "Greg Focker is ready to marry his girlfriend, Pam, but before he pops the question, he must win over her formidable father, humorless former CIA agent Jack Byrnes, at the wedding of Pam's sister. As Greg bends over backward to make a good impression, his visit to the Byrnes home turns into a hilarious series of disasters, and everything that can go wrong does, all under Jack's critical, hawklike gaze.",
#    'vote_count': 3449,
#    'video': False,
#    'poster_path': '/wVjtQtzv9IcNRGnOOdcK797Sdxx.jpg',
#    'backdrop_path': '/jEBgtMuhM86K0P1u0HS8diHk7ej.jpg',
#    'title': 'Meet the Parents',
#    'popularity': 12.756,
#    'genre_ids': [35, 10749],
#    'vote_average': 6.6,
#    'adult': False,
#    'release_date': '2000-10-06',
#    'credit_id': '557313ddc3a36838d3004484'},
#   {'id': 8944,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'What Just Happened',
#    'job': 'Producer',
#    'overview': "During the course of an ordinary week in Hollywood, movie producer Ben (Robert De Niro) must navigate his way through shark-infested waters as he struggles to complete his latest projects. A demanding studio boss (Catherine Keener) demands extensive changes to a movie starring Sean Penn, while another chief won't greenlight a project unless star Bruce Willis shaves his beard. Meanwhile, Ben tries to reconcile with his wife and maintain a relationship with his young daughter.",
#    'vote_count': 222,
#    'video': False,
#    'release_date': '2008-10-17',
#    'vote_average': 5.4,
#    'title': 'What Just Happened',
#    'popularity': 5.808,
#    'genre_ids': [35, 18],
#    'backdrop_path': '/4dyRBYhJQi23vFHyyrsWlJz6Yca.jpg',
#    'adult': False,
#    'poster_path': '/hr5oELD0PJxnRGAFsWT22uFtcyP.jpg',
#    'credit_id': '56fa7d06c3a3681937002bd9'},
#   {'id': 17711,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'The Adventures of Rocky & Bullwinkle',
#    'job': 'Producer',
#    'overview': 'Rocky and Bullwinkle have been living off the finances made from the reruns of their cartoon show. Boris and Natasha somehow manage to crossover into reality and team up with Fearless Leader, an evil criminal turned media mogul with some evil plans up his sleeve. Rocky and Bullwinkle must stop the three of them before they wreak havoc.',
#    'vote_count': 190,
#    'video': False,
#    'release_date': '2000-06-30',
#    'vote_average': 4.1,
#    'title': 'The Adventures of Rocky & Bullwinkle',
#    'popularity': 6.964,
#    'genre_ids': [28, 12, 16, 35, 10751],
#    'backdrop_path': '/cIPxnFC31aYSnCIoyG8kNeYnRmP.jpg',
#    'adult': False,
#    'poster_path': '/pjzt6S76Uumm0aZtxNAVhDCLQ0P.jpg',
#    'credit_id': '593c9f81c3a3680f4201597d'},
#   {'id': 26108,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Stage Beauty',
#    'job': 'Producer',
#    'overview': "Humble Maria, who outfits top London theater star Ned Kynaston, takes none of the credit for the male actor's success at playing women. And because this is the 17th century, Maria, like other females, is prohibited from pursuing her dream of acting. But when powerful people support her, King Charles II lifts the ban on female stage performers. And just as Maria aided Ned, she needs his help to learn her new profession.",
#    'vote_count': 61,
#    'video': False,
#    'release_date': '2004-09-03',
#    'vote_average': 7,
#    'title': 'Stage Beauty',
#    'popularity': 5.684,
#    'genre_ids': [35, 10749],
#    'backdrop_path': '/35SaLfbWvgsP2RLHgOKf0Mj0Z0M.jpg',
#    'adult': False,
#    'poster_path': '/tBzAWltVOWTpw4KNFd6dz02PhqV.jpg',
#    'credit_id': '5973a352c3a3685ded0029b8'},
#   {'id': 64920,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Witness to the Mob',
#    'job': 'Executive Producer',
#    'overview': "Sammy 'The Bull' Gravano was mafiosi. He started out as a soldier, but his talent for murder, including the slayings of his best friends, his wife's brother and his own boss, Paul Castellano, saw him rise to under-boss in the Gambino crime family. However, betrayals within the family saw him break the code of silence and became the highest ranking member of the mob to turn into a rat - 'a rat in a suit,- assisting the government to finally put away the Teflon Don, John Gotti.",
#    'vote_count': 7,
#    'video': False,
#    'release_date': '1998-05-10',
#    'vote_average': 7.3,
#    'title': 'Witness to the Mob',
#    'popularity': 1.544,
#    'genre_ids': [10770, 80, 18],
#    'backdrop_path': '/tS9dxzJpbUqivQ6ungJyXiQ3c70.jpg',
#    'adult': False,
#    'poster_path': '/niX9b5Sew9GxXML09Wl5o6gLcT7.jpg',
#    'credit_id': '5973a38cc3a3685e0f002c47'},
#   {'id': 57450,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Holiday Heart',
#    'job': 'Executive Producer',
#    'overview': 'A drag queen takes in a drug addict and her daughter and helps raise the daughter.',
#    'vote_count': 5,
#    'video': False,
#    'release_date': '2000-12-10',
#    'vote_average': 8,
#    'title': 'Holiday Heart',
#    'popularity': 1.461,
#    'genre_ids': [18, 10749],
#    'backdrop_path': '/gK5hMwL3zcvKDcyu8wrZDM5LkwY.jpg',
#    'adult': False,
#    'poster_path': '/tqDPMWks5U1GP4mnSdSiVoiTjDa.jpg',
#    'credit_id': '5973a3d5c3a3685da400299e'},
#   {'id': 41661,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'The Night We Never Met',
#    'job': 'Producer',
#    'overview': 'Sam has a problem with his roommates: they are disgusting, and don\'t seem to share his views on responsibility, privacy, and basic hygine. Such is his discomfort with his living arrangements that he agrees to share the occupancy of another flat: he gets two nights a week, the owner (a sleazy frat-boy yuppie named Brian, soon to be married) and Ellen (a would-be painter seeking relief from her boring marriage) each get their seperate nights in the flat. Things go extremely well until Sam and Brian swap nights without telling Ellen, who attributes the "nice" things that happen around the place to the slob Brian, while berating the responsible Sam for his hedonistic lifestyle.',
#    'vote_count': 8,
#    'video': False,
#    'release_date': '1993-04-30',
#    'vote_average': 5.6,
#    'title': 'The Night We Never Met',
#    'popularity': 2.112,
#    'genre_ids': [10749, 35],
#    'backdrop_path': '/2ZmtLTt6W83QQXeWw4CjZjEB3bI.jpg',
#    'adult': False,
#    'poster_path': '/AjlTuKaMBdvRPwktWVKslaB9cMM.jpg',
#    'credit_id': '5973a486c3a3685dd8002e48'},
#   {'id': 41478,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Panther',
#    'job': 'Producer',
#    'overview': "Panther is a semi-historic film about the origins of The Black Panther Party for Self-Defense. The movie spans about 3 years (1966-68) of the Black Panther's history in Oakland. Panther also uses historical footage (B/W) to emphasize some points.",
#    'vote_count': 13,
#    'video': False,
#    'release_date': '1995-11-10',
#    'vote_average': 6.5,
#    'title': 'Panther',
#    'popularity': 3.032,
#    'genre_ids': [18],
#    'backdrop_path': '/nDbINAgGrw7aiuS8IEwXn4gQ8F7.jpg',
#    'adult': False,
#    'poster_path': '/gxGOkt6WBhSIdZiQqyVEccRURVv.jpg',
#    'credit_id': '5973a4b4c3a3685e0f002da3'},
#   {'id': 47502,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Faithful',
#    'job': 'Producer',
#    'overview': 'A depressed housewife whose husband is having an affair contemplates suicide, but changes her mind when she faces death by a killer hired to do her in.',
#    'vote_count': 6,
#    'video': False,
#    'release_date': '1996-04-03',
#    'vote_average': 5,
#    'title': 'Faithful',
#    'popularity': 1.968,
#    'genre_ids': [35, 80, 18],
#    'backdrop_path': '/jiGj8wWUunpLRs1hWy6ezsxN7d2.jpg',
#    'adult': False,
#    'poster_path': '/hGimJZmyw8SR27dxCoK6xIHiqKx.jpg',
#    'credit_id': '5973a51f92514157f7002b8f'},
#   {'id': 30382,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Entropy',
#    'job': 'Producer',
#    'overview': 'Entropy is the semi-autobiographical film by director which tells the story of a young director struggling to make a film for a despotic studio while his life falls apart around him. Along the way, he goes on tour with U2 to help them make a music video, gets married in Vegas, and has a conversation with his cat.',
#    'vote_count': 8,
#    'video': False,
#    'release_date': '1999-11-27',
#    'vote_average': 5,
#    'title': 'Entropy',
#    'popularity': 1.821,
#    'genre_ids': [18, 35, 10749],
#    'backdrop_path': '/47pHc6KPyNZwDjfLqOU8klnVbYe.jpg',
#    'adult': False,
#    'poster_path': '/eF5oEK3DbqBaIHOPSHweHk53eCn.jpg',
#    'credit_id': '5973a83c92514157f2002e94'},
#   {'id': 26478,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Prison Song',
#    'job': 'Producer',
#    'overview': 'Elijah has been bounced from group home to group home throughout his turbulent young life. What has sustained him is his art. After a promised scholarship is taken away, Elijah ends up in a fight that result in the death of another boy. Now, sentenced to a minimum of fifteen years, the young man must find a way to keep his soul alive behind bars or turn into a hardened bitter criminal.',
#    'vote_count': 6,
#    'video': False,
#    'release_date': '2001-04-27',
#    'vote_average': 5.6,
#    'title': 'Prison Song',
#    'popularity': 1.4,
#    'genre_ids': [18],
#    'backdrop_path': '/7mslPEUJ4n9cRymlC5zqawroD7.jpg',
#    'adult': False,
#    'poster_path': '/7iJAsdGSMCVStOh4cz3qecIUzRq.jpg',
#    'credit_id': '5973a884c3a3685dba002824'},
#   {'id': 9819,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': "Marvin's Room",
#    'job': 'Producer',
#    'overview': 'A leukemia patient attempts to end a 20-year feud with her sister to get her bone marrow.',
#    'vote_count': 277,
#    'video': False,
#    'poster_path': '/mousrrNQ0ypRjCvgYzgMrusTW8b.jpg',
#    'backdrop_path': '/dXGjxSaKV02s1It9i0IF7HhVQ8l.jpg',
#    'title': "Marvin's Room",
#    'popularity': 8.63,
#    'genre_ids': [18],
#    'vote_average': 6.7,
#    'adult': False,
#    'release_date': '1996-12-18',
#    'credit_id': '59a673f292514112e40095ca'},
#   {'id': 363992,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'The Wizard of Lies',
#    'job': 'Executive Producer',
#    'overview': "A look behind the scenes at Bernie Madoff's massive Ponzi scheme, how it was perpetrated on the public and the trail of destruction it left in its wake, both for the victims and Madoff's family.",
#    'vote_count': 277,
#    'video': False,
#    'release_date': '2017-05-20',
#    'vote_average': 6.5,
#    'title': 'The Wizard of Lies',
#    'popularity': 9.917,
#    'genre_ids': [80, 18, 36, 53, 10770],
#    'backdrop_path': '/dqtosyPcgnotoMuo8wy4xwY1Bxe.jpg',
#    'adult': False,
#    'poster_path': '/8k4lJ4e0hvDQtKpItXmmPdw69sO.jpg',
#    'credit_id': '59c7b3fdc3a368143005bf7e'},
#   {'id': 424694,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Bohemian Rhapsody',
#    'job': 'Producer',
#    'overview': "Singer Freddie Mercury, guitarist Brian May, drummer Roger Taylor and bass guitarist John Deacon take the music world by storm when they form the rock 'n' roll band Queen in 1970. Hit songs become instant classics. When Mercury's increasingly wild lifestyle starts to spiral out of control, Queen soon faces its greatest challenge yet – finding a way to keep the band together amid the success and excess.",
#    'vote_count': 8573,
#    'video': False,
#    'poster_path': '/lHu1wtNaczFPGFDTrjCSzeLPTKN.jpg',
#    'backdrop_path': '/xcaSYLBhmDzJ6P14bcKe0KTh3QV.jpg',
#    'title': 'Bohemian Rhapsody',
#    'popularity': 32.927,
#    'genre_ids': [18, 10402],
#    'vote_average': 8.1,
#    'adult': False,
#    'release_date': '2018-11-02',
#    'credit_id': '5ab9ff9fc3a36871d20116d7'},
#   {'id': 3036,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'Frankenstein',
#    'job': 'Associate Producer',
#    'overview': 'Based on Mary Shelley\'s novel, "Frankenstein" tells the story of Victor Frankenstein, a promising young doctor who, devastated by the death of his mother during childbirth, becomes obsessed with bringing the dead back to life. His experiments lead to the creation of a monster, which Frankenstein has put together with the remains of corpses. It\'s not long before Frankenstein regrets his actions.',
#    'vote_count': 600,
#    'video': False,
#    'release_date': '1994-11-04',
#    'vote_average': 6.3,
#    'title': 'Frankenstein',
#    'popularity': 8.161,
#    'genre_ids': [18, 27, 878, 10749],
#    'backdrop_path': '/vVyF1OMjsdsboBBjEVL8wmOdPNG.jpg',
#    'adult': False,
#    'poster_path': '/uG0YLHdiBuWBv99MLwthucsvKLZ.jpg',
#    'credit_id': '5b811d13c3a368656300c584'},
#   {'id': 398978,
#    'department': 'Production',
#    'original_language': 'en',
#    'original_title': 'The Irishman',
#    'job': 'Producer',
#    'overview': 'A mob hitman recalls his possible involvement with the slaying of Jimmy Hoffa.',
#    'vote_count': 0,
#    'video': False,
#    'poster_path': '/oPHvjHzzOj0qngM09KZ1cxnk0nd.jpg',
#    'backdrop_path': '/iLLDiO4dbUfFEnRug8DuvFEl1NB.jpg',
#    'title': 'The Irishman',
#    'popularity': 4.079,
#    'genre_ids': [80, 18],
#    'vote_average': 0,
#    'adult': False,
#    'release_date': '2019-11-01',
#    'credit_id': '5bdcab619251410297004f1d'}],
#  'id': 380}

# %%
num_of_credits = len(response_actor_id['cast'][:])
num_of_credits   #how many movies
# Out:
# 149

# %%
#Put all records in actor's first part of Data Frame (ie. hoffman_df)
labels = ['title','popularity','vote_average','vote_count']
idx = [film['id'] for film in response_actor_id['cast'][:]]
records = []
for film in (response_actor_id['cast'][:]):
    record = [film['title'], film['popularity'], film['vote_average'], film['vote_count']]
    records.append(record)

actor_df = pd.DataFrame.from_records(records, columns=labels, index=idx)
actor_df
# Out:
#                                                     title  popularity  \
# 68                                                 Brazil      10.445
# 103                                           Taxi Driver      17.500
# 117                                      The Untouchables      13.225
# 184                                          Jackie Brown      11.681
# 203                                          Mean Streets       8.479
# 240                                The Godfather: Part II      22.620
# 262                                    The King of Comedy      10.498
# 311                           Once Upon a Time in America      21.282
# 524                                                Casino      19.726
# 586                                           Wag the Dog      11.072
# 635                                           Angel Heart       9.440
# 693                                      Meet the Fockers      12.842
# 769                                            GoodFellas      22.002
# 819                                              Sleepers      12.434
# 949                                                  Heat      15.406
# 1247                                    The Good Shepherd       7.700
# 1578                                          Raging Bull      15.270
# 1597                                     Meet the Parents      12.756
# 1598                                            Cape Fear       9.261
# 1607                                         A Bronx Tale       9.809
# 2142                                             Cop Land      11.098
# 2270                                             Stardust       9.242
# 2749                                           15 Minutes      11.765
# 10433                                   Mad Dog and Glory       7.812
# 2924                                            Backdraft      11.403
# 3036                                         Frankenstein       8.161
# 10555                                          Shark Tale      16.385
# 3212         100 Years of Horror: The Frankenstein Family       0.929
# 3287           It's Alive: The True Story of Frankenstein       0.667
# 3870                                                 1900       7.678
# ...                                                   ...         ...
# 56205                 The Godfather Family: A Look Inside       1.701
# 402123                                Lennon or McCartney       2.663
# 418410         100 Years of Horror: Witchcraft and Demons       1.400
# 421029                                 Movies Are My Life       0.600
# 369524                                       The Comedian       7.651
# 425001                               The War with Grandpa       2.660
# 438349                                        Candy Store       0.627
# 398978                                       The Irishman       4.079
# 147581                           Three Rooms in Manhattan       3.020
# 9992                            Arthur and the Invisibles      10.173
# 1777                                      Fahrenheit 9/11       8.218
# 466057                       Alec Baldwin: One Night Only       1.400
# 333360                       Peggy Guggenheim: Art Addict       1.590
# 486068                         Tony Bennett Celebrates 90       0.970
# 446048                      Jim Norton: Mouthful of Shame       2.272
# 502332                            Martin Scorsese Directs       0.600
# 250280                                Trespassing Bergman       1.684
# 515834                     Jackie Brown: How It Went Down       0.613
# 75009                       The Concert for New York City       1.296
# 547562            Vanity Fair: Killers Kill, Dead Men Die       0.855
# 551587  National Museum of African American History an...       0.600
# 467536                                       Young Wolves       0.624
# 564815                                Hollywood Mavericks       0.600
# 543658               Breslin and Hamill: Deadline Artists       0.774
# 118254                                         Club Oscar       0.600
# 475557                                              Joker      45.225
# 601313                                         I Am Durán       3.231
# 466420                         Killers of the Flower Moon       0.969
# 621509                                         GoodBagels       0.737
# 622794                                        After Exile       0.600
#
#         vote_average  vote_count
# 68               7.7        1675
# 103              8.2        5578
# 117              7.8        2916
# 184              7.3        3236
# 203              7.2         871
# 240              8.5        6205
# 262              7.6         702
# 311              8.4        2375
# 524              8.0        2585
# 586              6.9         459
# 635              7.2         663
# 693              6.2        2796
# 769              8.4        5947
# 819              7.5        1485
# 949              7.8        3382
# 1247             6.4         562
# 1578             7.9        1939
# 1597             6.6        3449
# 1598             7.2        1492
# 1607             7.6         839
# 2142             6.7         697
# 2270             7.2        2263
# 2749             5.8         345
# 10433            5.7         145
# 2924             6.6         652
# 3036             6.3         600
# 10555            5.9        3802
# 3212            10.0           1
# 3287             6.0           1
# 3870             7.7         213
# ...              ...         ...
# 56205            8.2          15
# 402123           6.6           9
# 418410           8.5           2
# 421029           0.0           0
# 369524           5.6          76
# 425001           7.0           1
# 438349           0.0           0
# 398978           0.0           0
# 147581           4.8           5
# 9992             6.2        1571
# 1777             7.1         738
# 466057           0.0           0
# 333360           6.9          11
# 486068          10.0           1
# 446048           6.6          18
# 502332          10.0           1
# 250280           6.3          10
# 515834           7.8           6
# 75009            5.0           2
# 547562           0.0           0
# 551587           0.0           0
# 467536           6.0           1
# 564815           0.0           0
# 543658           8.0           2
# 118254           2.5           2
# 475557           0.0          29
# 601313           7.3          10
# 466420           0.0           0
# 621509           0.0           0
# 622794           0.0           0
#
# [149 rows x 4 columns]

# %%
#Now get 2nd part of actor's df from the tmdb.Movies for merging
labels = ['revenue','budget','profit','genres']
film_indices = [film[0] for film in actor_df.iterrows()]
#print(film_indices)
records = []
request_rate_limit = 40     #TMDB has rate limit of 40 requests per 10 seconds

for film_idx in film_indices:
    request_rate_limit -= 1
    if request_rate_limit == 0:            
        print("Hold yer horses, cowboy!")
        print("...wait per request limit...")
        time.sleep(10)
        request_rate_limit = 39
    movie = tmdb.Movies(film_idx)  #Each movie has unique identifier stored as index of df
    response = movie.info()
        
    profit = response['revenue'] - response['budget']
    record = [response['revenue'], response['budget'], profit, response['genres']]    
    records.append(record)

actor_movies_df = pd.DataFrame.from_records(records, columns=labels, index=film_indices)
actor_movies_df
# Out:
# Hold yer horses, cowboy!
# ...wait per request limit...
# Hold yer horses, cowboy!
# ...wait per request limit...
# Hold yer horses, cowboy!
# ...wait per request limit...
#           revenue     budget     profit  \
# 68              0   15000000  -15000000
# 103      28262574    1300000   26962574
# 117      76270454   25000000   51270454
# 184      39673162   12000000   27673162
# 203       3000000     500000    2500000
# 240     102600000   13000000   89600000
# 262             0   20000000  -20000000
# 311       5300000   20000000  -14700000
# 524     116112375   52000000   64112375
# 586      64256513   15000000   49256513
# 635      17185632   17000000     185632
# 693     516642939   80000000  436642939
# 769      46836394   25000000   21836394
# 819     165615285   44000000  121615285
# 949     187436818   60000000  127436818
# 1247     59908565   85000000  -25091435
# 1578     23000000   18000000    5000000
# 1597    330444045   55000000  275444045
# 1598    182300000   35000000  147300000
# 1607     17287898   22000000   -4712102
# 2142     44862187   15000000   29862187
# 2270    135560026   70000000   65560026
# 2749     56359980   60000000   -3640020
# 10433    11081586          0   11081586
# 2924    152368585   75000000   77368585
# 3036    112006296   45000000   67006296
# 10555   367275019   75000000  292275019
# 3212            0          0          0
# 3287            0          0          0
# 3870            0    9000000   -9000000
# ...           ...        ...        ...
# 56205           0          0          0
# 402123          0          0          0
# 418410          0          0          0
# 421029          0          0          0
# 369524          0   15000000  -15000000
# 425001          0          0          0
# 438349          0          0          0
# 398978          0  125000000 -125000000
# 147581          0          0          0
# 9992    107944236   86000000   21944236
# 1777    119114517    6000000  113114517
# 466057          0          0          0
# 333360          0          0          0
# 486068          0          0          0
# 446048          0          0          0
# 502332          0          0          0
# 250280          0          0          0
# 515834          0          0          0
# 75009           0          0          0
# 547562          0          0          0
# 551587          0          0          0
# 467536          0          0          0
# 564815          0          0          0
# 543658          0          0          0
# 118254          0          0          0
# 475557          0   55000000  -55000000
# 601313          0          0          0
# 466420          0          0          0
# 621509          0          0          0
# 622794          0          0          0
#
#                                                    genres
# 68      [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
# 103     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 117     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 184     [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 203     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 240     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 262     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 311     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 524     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 586     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 635     [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 693     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 769     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 819     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 949     [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 1247    [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 1578                        [{'id': 18, 'name': 'Drama'}]
# 1597    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 1598    [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 1607    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 2142    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2270    [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2749    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 10433   [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 2924    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 3036    [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 10555   [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 3212                  [{'id': 99, 'name': 'Documentary'}]
# 3287                  [{'id': 99, 'name': 'Documentary'}]
# 3870    [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# ...                                                   ...
# 56205                 [{'id': 99, 'name': 'Documentary'}]
# 402123                [{'id': 99, 'name': 'Documentary'}]
# 418410  [{'id': 27, 'name': 'Horror'}, {'id': 99, 'nam...
# 421029                [{'id': 99, 'name': 'Documentary'}]
# 369524                     [{'id': 35, 'name': 'Comedy'}]
# 425001  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 438349  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 398978  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 147581                      [{'id': 18, 'name': 'Drama'}]
# 9992    [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 1777                  [{'id': 99, 'name': 'Documentary'}]
# 466057                     [{'id': 35, 'name': 'Comedy'}]
# 333360                [{'id': 99, 'name': 'Documentary'}]
# 486068  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
# 446048  [{'id': 35, 'name': 'Comedy'}, {'id': 10770, '...
# 502332                [{'id': 99, 'name': 'Documentary'}]
# 250280                                                 []
# 515834                [{'id': 99, 'name': 'Documentary'}]
# 75009   [{'id': 10402, 'name': 'Music'}, {'id': 36, 'n...
# 547562                [{'id': 99, 'name': 'Documentary'}]
# 551587  [{'id': 99, 'name': 'Documentary'}, {'id': 104...
# 467536                      [{'id': 18, 'name': 'Drama'}]
# 564815                [{'id': 99, 'name': 'Documentary'}]
# 543658                [{'id': 99, 'name': 'Documentary'}]
# 118254                  [{'id': 16, 'name': 'Animation'}]
# 475557  [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 601313                [{'id': 99, 'name': 'Documentary'}]
# 466420  [{'id': 36, 'name': 'History'}, {'id': 53, 'na...
# 621509                                                 []
# 622794                                                 []
#
# [149 rows x 4 columns]

# %%
print(actor_df.shape)
actor_df.head(5)
# Out:
# (149, 4)
#                 title  popularity  vote_average  vote_count
# 68             Brazil      10.445           7.7        1675
# 103       Taxi Driver      17.500           8.2        5578
# 117  The Untouchables      13.225           7.8        2916
# 184      Jackie Brown      11.681           7.3        3236
# 203      Mean Streets       8.479           7.2         871

# %%
print(actor_movies_df.shape)
actor_movies_df.head(5)
# Out:
# (149, 4)
#       revenue    budget    profit  \
# 68          0  15000000 -15000000
# 103  28262574   1300000  26962574
# 117  76270454  25000000  51270454
# 184  39673162  12000000  27673162
# 203   3000000    500000   2500000
#
#                                                 genres
# 68   [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
# 103  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 117  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 184  [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 203  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...

# %%
# This builds the full df, still need to build final
actor_full_df = pd.merge(actor_df, actor_movies_df, left_index=True, right_index=True)
print(actor_full_df.shape)
actor_full_df
# Out:
# (149, 8)
#                                                     title  popularity  \
# 68                                                 Brazil      10.445
# 103                                           Taxi Driver      17.500
# 117                                      The Untouchables      13.225
# 184                                          Jackie Brown      11.681
# 203                                          Mean Streets       8.479
# 240                                The Godfather: Part II      22.620
# 262                                    The King of Comedy      10.498
# 311                           Once Upon a Time in America      21.282
# 524                                                Casino      19.726
# 586                                           Wag the Dog      11.072
# 635                                           Angel Heart       9.440
# 693                                      Meet the Fockers      12.842
# 769                                            GoodFellas      22.002
# 819                                              Sleepers      12.434
# 949                                                  Heat      15.406
# 1247                                    The Good Shepherd       7.700
# 1578                                          Raging Bull      15.270
# 1597                                     Meet the Parents      12.756
# 1598                                            Cape Fear       9.261
# 1607                                         A Bronx Tale       9.809
# 2142                                             Cop Land      11.098
# 2270                                             Stardust       9.242
# 2749                                           15 Minutes      11.765
# 10433                                   Mad Dog and Glory       7.812
# 2924                                            Backdraft      11.403
# 3036                                         Frankenstein       8.161
# 10555                                          Shark Tale      16.385
# 3212         100 Years of Horror: The Frankenstein Family       0.929
# 3287           It's Alive: The True Story of Frankenstein       0.667
# 3870                                                 1900       7.678
# ...                                                   ...         ...
# 56205                 The Godfather Family: A Look Inside       1.701
# 402123                                Lennon or McCartney       2.663
# 418410         100 Years of Horror: Witchcraft and Demons       1.400
# 421029                                 Movies Are My Life       0.600
# 369524                                       The Comedian       7.651
# 425001                               The War with Grandpa       2.660
# 438349                                        Candy Store       0.627
# 398978                                       The Irishman       4.079
# 147581                           Three Rooms in Manhattan       3.020
# 9992                            Arthur and the Invisibles      10.173
# 1777                                      Fahrenheit 9/11       8.218
# 466057                       Alec Baldwin: One Night Only       1.400
# 333360                       Peggy Guggenheim: Art Addict       1.590
# 486068                         Tony Bennett Celebrates 90       0.970
# 446048                      Jim Norton: Mouthful of Shame       2.272
# 502332                            Martin Scorsese Directs       0.600
# 250280                                Trespassing Bergman       1.684
# 515834                     Jackie Brown: How It Went Down       0.613
# 75009                       The Concert for New York City       1.296
# 547562            Vanity Fair: Killers Kill, Dead Men Die       0.855
# 551587  National Museum of African American History an...       0.600
# 467536                                       Young Wolves       0.624
# 564815                                Hollywood Mavericks       0.600
# 543658               Breslin and Hamill: Deadline Artists       0.774
# 118254                                         Club Oscar       0.600
# 475557                                              Joker      45.225
# 601313                                         I Am Durán       3.231
# 466420                         Killers of the Flower Moon       0.969
# 621509                                         GoodBagels       0.737
# 622794                                        After Exile       0.600
#
#         vote_average  vote_count    revenue     budget     profit  \
# 68               7.7        1675          0   15000000  -15000000
# 103              8.2        5578   28262574    1300000   26962574
# 117              7.8        2916   76270454   25000000   51270454
# 184              7.3        3236   39673162   12000000   27673162
# 203              7.2         871    3000000     500000    2500000
# 240              8.5        6205  102600000   13000000   89600000
# 262              7.6         702          0   20000000  -20000000
# 311              8.4        2375    5300000   20000000  -14700000
# 524              8.0        2585  116112375   52000000   64112375
# 586              6.9         459   64256513   15000000   49256513
# 635              7.2         663   17185632   17000000     185632
# 693              6.2        2796  516642939   80000000  436642939
# 769              8.4        5947   46836394   25000000   21836394
# 819              7.5        1485  165615285   44000000  121615285
# 949              7.8        3382  187436818   60000000  127436818
# 1247             6.4         562   59908565   85000000  -25091435
# 1578             7.9        1939   23000000   18000000    5000000
# 1597             6.6        3449  330444045   55000000  275444045
# 1598             7.2        1492  182300000   35000000  147300000
# 1607             7.6         839   17287898   22000000   -4712102
# 2142             6.7         697   44862187   15000000   29862187
# 2270             7.2        2263  135560026   70000000   65560026
# 2749             5.8         345   56359980   60000000   -3640020
# 10433            5.7         145   11081586          0   11081586
# 2924             6.6         652  152368585   75000000   77368585
# 3036             6.3         600  112006296   45000000   67006296
# 10555            5.9        3802  367275019   75000000  292275019
# 3212            10.0           1          0          0          0
# 3287             6.0           1          0          0          0
# 3870             7.7         213          0    9000000   -9000000
# ...              ...         ...        ...        ...        ...
# 56205            8.2          15          0          0          0
# 402123           6.6           9          0          0          0
# 418410           8.5           2          0          0          0
# 421029           0.0           0          0          0          0
# 369524           5.6          76          0   15000000  -15000000
# 425001           7.0           1          0          0          0
# 438349           0.0           0          0          0          0
# 398978           0.0           0          0  125000000 -125000000
# 147581           4.8           5          0          0          0
# 9992             6.2        1571  107944236   86000000   21944236
# 1777             7.1         738  119114517    6000000  113114517
# 466057           0.0           0          0          0          0
# 333360           6.9          11          0          0          0
# 486068          10.0           1          0          0          0
# 446048           6.6          18          0          0          0
# 502332          10.0           1          0          0          0
# 250280           6.3          10          0          0          0
# 515834           7.8           6          0          0          0
# 75009            5.0           2          0          0          0
# 547562           0.0           0          0          0          0
# 551587           0.0           0          0          0          0
# 467536           6.0           1          0          0          0
# 564815           0.0           0          0          0          0
# 543658           8.0           2          0          0          0
# 118254           2.5           2          0          0          0
# 475557           0.0          29          0   55000000  -55000000
# 601313           7.3          10          0          0          0
# 466420           0.0           0          0          0          0
# 621509           0.0           0          0          0          0
# 622794           0.0           0          0          0          0
#
#                                                    genres
# 68      [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
# 103     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 117     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 184     [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 203     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 240     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 262     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 311     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 524     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 586     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 635     [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 693     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 769     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 819     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 949     [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 1247    [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 1578                        [{'id': 18, 'name': 'Drama'}]
# 1597    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 1598    [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 1607    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 2142    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2270    [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2749    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 10433   [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 2924    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 3036    [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 10555   [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 3212                  [{'id': 99, 'name': 'Documentary'}]
# 3287                  [{'id': 99, 'name': 'Documentary'}]
# 3870    [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# ...                                                   ...
# 56205                 [{'id': 99, 'name': 'Documentary'}]
# 402123                [{'id': 99, 'name': 'Documentary'}]
# 418410  [{'id': 27, 'name': 'Horror'}, {'id': 99, 'nam...
# 421029                [{'id': 99, 'name': 'Documentary'}]
# 369524                     [{'id': 35, 'name': 'Comedy'}]
# 425001  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 438349  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 398978  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 147581                      [{'id': 18, 'name': 'Drama'}]
# 9992    [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 1777                  [{'id': 99, 'name': 'Documentary'}]
# 466057                     [{'id': 35, 'name': 'Comedy'}]
# 333360                [{'id': 99, 'name': 'Documentary'}]
# 486068  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
# 446048  [{'id': 35, 'name': 'Comedy'}, {'id': 10770, '...
# 502332                [{'id': 99, 'name': 'Documentary'}]
# 250280                                                 []
# 515834                [{'id': 99, 'name': 'Documentary'}]
# 75009   [{'id': 10402, 'name': 'Music'}, {'id': 36, 'n...
# 547562                [{'id': 99, 'name': 'Documentary'}]
# 551587  [{'id': 99, 'name': 'Documentary'}, {'id': 104...
# 467536                      [{'id': 18, 'name': 'Drama'}]
# 564815                [{'id': 99, 'name': 'Documentary'}]
# 543658                [{'id': 99, 'name': 'Documentary'}]
# 118254                  [{'id': 16, 'name': 'Animation'}]
# 475557  [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 601313                [{'id': 99, 'name': 'Documentary'}]
# 466420  [{'id': 36, 'name': 'History'}, {'id': 53, 'na...
# 621509                                                 []
# 622794                                                 []
#
# [149 rows x 8 columns]

# %%
#Save to PostgrSQL

# %%
#Create new column containing a list of genres for each movie
def to_list(cell):
    #input is a single cell containing a list of dicts
    #rreturns a list of genres as unique strings
    l = []
    for d in cell:     #cell is list of dicts
        l.append(d['name'])
    return(l)

actor_full_df['genre_names'] = actor_full_df['genres'].map(to_list)
#Drop duplicate info
actor_full_df.drop(['genres'], axis=1, inplace=True)
actor_full_df
# Out:
#                                                     title  popularity  \
# 68                                                 Brazil      10.445
# 103                                           Taxi Driver      17.500
# 117                                      The Untouchables      13.225
# 184                                          Jackie Brown      11.681
# 203                                          Mean Streets       8.479
# 240                                The Godfather: Part II      22.620
# 262                                    The King of Comedy      10.498
# 311                           Once Upon a Time in America      21.282
# 524                                                Casino      19.726
# 586                                           Wag the Dog      11.072
# 635                                           Angel Heart       9.440
# 693                                      Meet the Fockers      12.842
# 769                                            GoodFellas      22.002
# 819                                              Sleepers      12.434
# 949                                                  Heat      15.406
# 1247                                    The Good Shepherd       7.700
# 1578                                          Raging Bull      15.270
# 1597                                     Meet the Parents      12.756
# 1598                                            Cape Fear       9.261
# 1607                                         A Bronx Tale       9.809
# 2142                                             Cop Land      11.098
# 2270                                             Stardust       9.242
# 2749                                           15 Minutes      11.765
# 10433                                   Mad Dog and Glory       7.812
# 2924                                            Backdraft      11.403
# 3036                                         Frankenstein       8.161
# 10555                                          Shark Tale      16.385
# 3212         100 Years of Horror: The Frankenstein Family       0.929
# 3287           It's Alive: The True Story of Frankenstein       0.667
# 3870                                                 1900       7.678
# ...                                                   ...         ...
# 56205                 The Godfather Family: A Look Inside       1.701
# 402123                                Lennon or McCartney       2.663
# 418410         100 Years of Horror: Witchcraft and Demons       1.400
# 421029                                 Movies Are My Life       0.600
# 369524                                       The Comedian       7.651
# 425001                               The War with Grandpa       2.660
# 438349                                        Candy Store       0.627
# 398978                                       The Irishman       4.079
# 147581                           Three Rooms in Manhattan       3.020
# 9992                            Arthur and the Invisibles      10.173
# 1777                                      Fahrenheit 9/11       8.218
# 466057                       Alec Baldwin: One Night Only       1.400
# 333360                       Peggy Guggenheim: Art Addict       1.590
# 486068                         Tony Bennett Celebrates 90       0.970
# 446048                      Jim Norton: Mouthful of Shame       2.272
# 502332                            Martin Scorsese Directs       0.600
# 250280                                Trespassing Bergman       1.684
# 515834                     Jackie Brown: How It Went Down       0.613
# 75009                       The Concert for New York City       1.296
# 547562            Vanity Fair: Killers Kill, Dead Men Die       0.855
# 551587  National Museum of African American History an...       0.600
# 467536                                       Young Wolves       0.624
# 564815                                Hollywood Mavericks       0.600
# 543658               Breslin and Hamill: Deadline Artists       0.774
# 118254                                         Club Oscar       0.600
# 475557                                              Joker      45.225
# 601313                                         I Am Durán       3.231
# 466420                         Killers of the Flower Moon       0.969
# 621509                                         GoodBagels       0.737
# 622794                                        After Exile       0.600
#
#         vote_average  vote_count    revenue     budget     profit  \
# 68               7.7        1675          0   15000000  -15000000
# 103              8.2        5578   28262574    1300000   26962574
# 117              7.8        2916   76270454   25000000   51270454
# 184              7.3        3236   39673162   12000000   27673162
# 203              7.2         871    3000000     500000    2500000
# 240              8.5        6205  102600000   13000000   89600000
# 262              7.6         702          0   20000000  -20000000
# 311              8.4        2375    5300000   20000000  -14700000
# 524              8.0        2585  116112375   52000000   64112375
# 586              6.9         459   64256513   15000000   49256513
# 635              7.2         663   17185632   17000000     185632
# 693              6.2        2796  516642939   80000000  436642939
# 769              8.4        5947   46836394   25000000   21836394
# 819              7.5        1485  165615285   44000000  121615285
# 949              7.8        3382  187436818   60000000  127436818
# 1247             6.4         562   59908565   85000000  -25091435
# 1578             7.9        1939   23000000   18000000    5000000
# 1597             6.6        3449  330444045   55000000  275444045
# 1598             7.2        1492  182300000   35000000  147300000
# 1607             7.6         839   17287898   22000000   -4712102
# 2142             6.7         697   44862187   15000000   29862187
# 2270             7.2        2263  135560026   70000000   65560026
# 2749             5.8         345   56359980   60000000   -3640020
# 10433            5.7         145   11081586          0   11081586
# 2924             6.6         652  152368585   75000000   77368585
# 3036             6.3         600  112006296   45000000   67006296
# 10555            5.9        3802  367275019   75000000  292275019
# 3212            10.0           1          0          0          0
# 3287             6.0           1          0          0          0
# 3870             7.7         213          0    9000000   -9000000
# ...              ...         ...        ...        ...        ...
# 56205            8.2          15          0          0          0
# 402123           6.6           9          0          0          0
# 418410           8.5           2          0          0          0
# 421029           0.0           0          0          0          0
# 369524           5.6          76          0   15000000  -15000000
# 425001           7.0           1          0          0          0
# 438349           0.0           0          0          0          0
# 398978           0.0           0          0  125000000 -125000000
# 147581           4.8           5          0          0          0
# 9992             6.2        1571  107944236   86000000   21944236
# 1777             7.1         738  119114517    6000000  113114517
# 466057           0.0           0          0          0          0
# 333360           6.9          11          0          0          0
# 486068          10.0           1          0          0          0
# 446048           6.6          18          0          0          0
# 502332          10.0           1          0          0          0
# 250280           6.3          10          0          0          0
# 515834           7.8           6          0          0          0
# 75009            5.0           2          0          0          0
# 547562           0.0           0          0          0          0
# 551587           0.0           0          0          0          0
# 467536           6.0           1          0          0          0
# 564815           0.0           0          0          0          0
# 543658           8.0           2          0          0          0
# 118254           2.5           2          0          0          0
# 475557           0.0          29          0   55000000  -55000000
# 601313           7.3          10          0          0          0
# 466420           0.0           0          0          0          0
# 621509           0.0           0          0          0          0
# 622794           0.0           0          0          0          0
#
#                                       genre_names
# 68                      [Comedy, Science Fiction]
# 103                                [Crime, Drama]
# 117             [Crime, Drama, History, Thriller]
# 184              [Crime, Thriller, Drama, Comedy]
# 203                                [Drama, Crime]
# 240                                [Drama, Crime]
# 262                               [Comedy, Drama]
# 311                                [Drama, Crime]
# 524                                [Crime, Drama]
# 586                               [Comedy, Drama]
# 635                             [Horror, Mystery]
# 693                             [Comedy, Romance]
# 769                                [Drama, Crime]
# 819                      [Crime, Drama, Thriller]
# 949              [Action, Crime, Drama, Thriller]
# 1247                   [Drama, Thriller, History]
# 1578                                      [Drama]
# 1597                            [Comedy, Romance]
# 1598             [Crime, Thriller, Drama, Horror]
# 1607                               [Drama, Crime]
# 2142                       [Action, Crime, Drama]
# 2270        [Adventure, Fantasy, Romance, Family]
# 2749                    [Action, Crime, Thriller]
# 10433             [Comedy, Crime, Romance, Drama]
# 2924    [Action, Crime, Drama, Mystery, Thriller]
# 3036    [Drama, Horror, Science Fiction, Romance]
# 10555         [Animation, Action, Comedy, Family]
# 3212                                [Documentary]
# 3287                                [Documentary]
# 3870                    [Drama, History, Romance]
# ...                                           ...
# 56205                               [Documentary]
# 402123                              [Documentary]
# 418410                      [Horror, Documentary]
# 421029                              [Documentary]
# 369524                                   [Comedy]
# 425001                           [Comedy, Family]
# 438349                         [Thriller, Action]
# 398978                             [Drama, Crime]
# 147581                                    [Drama]
# 9992      [Adventure, Fantasy, Animation, Family]
# 1777                                [Documentary]
# 466057                                   [Comedy]
# 333360                              [Documentary]
# 486068                       [Music, Documentary]
# 446048                         [Comedy, TV Movie]
# 502332                              [Documentary]
# 250280                                         []
# 515834                              [Documentary]
# 75009               [Music, History, Documentary]
# 547562                              [Documentary]
# 551587              [Documentary, Music, History]
# 467536                                    [Drama]
# 564815                              [Documentary]
# 543658                              [Documentary]
# 118254                                [Animation]
# 475557                   [Crime, Thriller, Drama]
# 601313                              [Documentary]
# 466420          [History, Thriller, Crime, Drama]
# 621509                                         []
# 622794                                         []
#
# [149 rows x 8 columns]

# %%
print(actor_full_df.shape)
actor_full_df.describe()
# Out:
# (149, 8)
#        popularity  vote_average   vote_count       revenue        budget  \
# count  149.000000    149.000000   149.000000  1.490000e+02  1.490000e+02
# mean     6.693631      6.073826   786.825503  4.064510e+07  1.901371e+07
# std      5.851663      2.103710  1418.374725  7.924004e+07  2.703944e+07
# min      0.600000      0.000000     0.000000  0.000000e+00  0.000000e+00
# 25%      1.743000      5.700000     9.000000  0.000000e+00  0.000000e+00
# 50%      6.964000      6.400000   133.000000  0.000000e+00  0.000000e+00
# 75%      9.424000      7.200000   793.000000  4.881491e+07  2.700000e+07
# max     45.225000     10.000000  7914.000000  5.166429e+08  1.250000e+08
#
#              profit
# count  1.490000e+02
# mean   2.163138e+07
# std    6.590370e+07
# min   -1.250000e+08
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    1.112906e+07
# max    4.366429e+08

# %% [markdown]
# Delete rows with non-movies (eg. Documentary(99), TV Movie(10770) ). Deciding what constitutes a genre.
# 1. Eliminate rows containing Documentery or TV Movie as a genre.
# 2. Eliminate rows where revenue or budget are zero.

# %%
actor_full_df.head(3)
# Out:
#                 title  popularity  vote_average  vote_count   revenue  \
# 68             Brazil      10.445           7.7        1675         0
# 103       Taxi Driver      17.500           8.2        5578  28262574
# 117  The Untouchables      13.225           7.8        2916  76270454
#
#        budget    profit                        genre_names
# 68   15000000 -15000000          [Comedy, Science Fiction]
# 103   1300000  26962574                     [Crime, Drama]
# 117  25000000  51270454  [Crime, Drama, History, Thriller]

# %%
# If Genres is in Documentary(99), TV Movie(10770), delete the row.
# If revenue, budget or profit is zero or NaN, eliminate the row.
# If vote_count	< 20, eliminate the row.
#hoffman_full_df.isnull().sum()

# %%
#Function removes Documentary(99) and TV Movie(10770) genres on each cell
def exclude_genres(cell):
    '''looks for excluded values in a cell
       returns boolean mask'''
    excluded_genre = ['TV Movie','Documentary']
#    print(cell)
    if len(cell) == 0:
        return False
    else:
        for g in excluded_genre:
            if g in cell:
                return False
    return True

#  .map to genres column
actor_full_df = actor_full_df[actor_full_df.genre_names.map(exclude_genres)]            
actor_full_df
# Out:
#                                     title  popularity  vote_average  \
# 68                                 Brazil      10.445           7.7
# 103                           Taxi Driver      17.500           8.2
# 117                      The Untouchables      13.225           7.8
# 184                          Jackie Brown      11.681           7.3
# 203                          Mean Streets       8.479           7.2
# 240                The Godfather: Part II      22.620           8.5
# 262                    The King of Comedy      10.498           7.6
# 311           Once Upon a Time in America      21.282           8.4
# 524                                Casino      19.726           8.0
# 586                           Wag the Dog      11.072           6.9
# 635                           Angel Heart       9.440           7.2
# 693                      Meet the Fockers      12.842           6.2
# 769                            GoodFellas      22.002           8.4
# 819                              Sleepers      12.434           7.5
# 949                                  Heat      15.406           7.8
# 1247                    The Good Shepherd       7.700           6.4
# 1578                          Raging Bull      15.270           7.9
# 1597                     Meet the Parents      12.756           6.6
# 1598                            Cape Fear       9.261           7.2
# 1607                         A Bronx Tale       9.809           7.6
# 2142                             Cop Land      11.098           6.7
# 2270                             Stardust       9.242           7.2
# 2749                           15 Minutes      11.765           5.8
# 10433                   Mad Dog and Glory       7.812           5.7
# 2924                            Backdraft      11.403           6.6
# 3036                         Frankenstein       8.161           6.3
# 10555                          Shark Tale      16.385           5.9
# 3870                                 1900       7.678           7.7
# 11005                          Awakenings       8.931           7.8
# 11058                             Godsend       9.150           4.8
# ...                                   ...         ...           ...
# 78571                         Being Flynn       6.236           6.2
# 87567                     The Big Wedding       7.793           5.8
# 122800                        Freelancers       9.149           4.9
# 110843                           The Swap       1.743           4.3
# 112205                         The Family       9.703           6.2
# 153538  Tony Bennett: An American Classic       0.883           8.0
# 361671                              Ellis       2.100           6.9
# 137093                         Last Vegas       8.912           6.4
# 184341                     Hands of Stone       6.971           6.2
# 168672                    American Hustle      13.841           6.8
# 242076                        The Bag Man       6.647           5.3
# 23631                             Machete      13.096           6.3
# 22423                 Guilty by Suspicion       4.088           6.3
# 73612                          Sam's Song       2.164           5.3
# 336004                              Heist       7.558           5.8
# 257211                         The Intern      11.264           7.1
# 291870                      Dirty Grandpa      11.656           5.8
# 365717                       The Audition       3.344           6.4
# 274479                                Joy      10.330           6.5
# 369524                       The Comedian       7.651           5.6
# 425001               The War with Grandpa       2.660           7.0
# 438349                        Candy Store       0.627           0.0
# 398978                       The Irishman       4.079           0.0
# 147581           Three Rooms in Manhattan       3.020           4.8
# 9992            Arthur and the Invisibles      10.173           6.2
# 466057       Alec Baldwin: One Night Only       1.400           0.0
# 467536                       Young Wolves       0.624           6.0
# 118254                         Club Oscar       0.600           2.5
# 475557                              Joker      45.225           0.0
# 466420         Killers of the Flower Moon       0.969           0.0
#
#         vote_count    revenue     budget     profit  \
# 68            1675          0   15000000  -15000000
# 103           5578   28262574    1300000   26962574
# 117           2916   76270454   25000000   51270454
# 184           3236   39673162   12000000   27673162
# 203            871    3000000     500000    2500000
# 240           6205  102600000   13000000   89600000
# 262            702          0   20000000  -20000000
# 311           2375    5300000   20000000  -14700000
# 524           2585  116112375   52000000   64112375
# 586            459   64256513   15000000   49256513
# 635            663   17185632   17000000     185632
# 693           2796  516642939   80000000  436642939
# 769           5947   46836394   25000000   21836394
# 819           1485  165615285   44000000  121615285
# 949           3382  187436818   60000000  127436818
# 1247           562   59908565   85000000  -25091435
# 1578          1939   23000000   18000000    5000000
# 1597          3449  330444045   55000000  275444045
# 1598          1492  182300000   35000000  147300000
# 1607           839   17287898   22000000   -4712102
# 2142           697   44862187   15000000   29862187
# 2270          2263  135560026   70000000   65560026
# 2749           345   56359980   60000000   -3640020
# 10433          145   11081586          0   11081586
# 2924           652  152368585   75000000   77368585
# 3036           600  112006296   45000000   67006296
# 10555         3802  367275019   75000000  292275019
# 3870           213          0    9000000   -9000000
# 11005         1166   52096475          0   52096475
# 11058          224   30114487   25000000    5114487
# ...            ...        ...        ...        ...
# 78571          132     540152          0     540152
# 87567          711   21819348   35000000  -13180652
# 122800          99          0   11000000  -11000000
# 110843           3          0          0          0
# 112205        1712   36894225   30000000    6894225
# 153538           1          0          0          0
# 361671          42          0          0          0
# 137093        1266  134402450   28000000  106402450
# 184341         175          0   20000000  -20000000
# 168672        4595  251171807   40000000  211171807
# 242076         191      56574          0      56574
# 23631         1940   31327899   20000000   11327899
# 22423           60          0          0          0
# 73612            4          0          0          0
# 336004         511    4100000    8900000   -4800000
# 257211        3521  194564672   35000000  159564672
# 291870        2783   94073028   11500000   82573028
# 365717          54          0          0          0
# 274479        2817  101134059   60000000   41134059
# 369524          76          0   15000000  -15000000
# 425001           1          0          0          0
# 438349           0          0          0          0
# 398978           0          0  125000000 -125000000
# 147581           5          0          0          0
# 9992          1571  107944236   86000000   21944236
# 466057           0          0          0          0
# 467536           1          0          0          0
# 118254           2          0          0          0
# 475557          29          0   55000000  -55000000
# 466420           0          0          0          0
#
#                                        genre_names
# 68                       [Comedy, Science Fiction]
# 103                                 [Crime, Drama]
# 117              [Crime, Drama, History, Thriller]
# 184               [Crime, Thriller, Drama, Comedy]
# 203                                 [Drama, Crime]
# 240                                 [Drama, Crime]
# 262                                [Comedy, Drama]
# 311                                 [Drama, Crime]
# 524                                 [Crime, Drama]
# 586                                [Comedy, Drama]
# 635                              [Horror, Mystery]
# 693                              [Comedy, Romance]
# 769                                 [Drama, Crime]
# 819                       [Crime, Drama, Thriller]
# 949               [Action, Crime, Drama, Thriller]
# 1247                    [Drama, Thriller, History]
# 1578                                       [Drama]
# 1597                             [Comedy, Romance]
# 1598              [Crime, Thriller, Drama, Horror]
# 1607                                [Drama, Crime]
# 2142                        [Action, Crime, Drama]
# 2270         [Adventure, Fantasy, Romance, Family]
# 2749                     [Action, Crime, Thriller]
# 10433              [Comedy, Crime, Romance, Drama]
# 2924     [Action, Crime, Drama, Mystery, Thriller]
# 3036     [Drama, Horror, Science Fiction, Romance]
# 10555          [Animation, Action, Comedy, Family]
# 3870                     [Drama, History, Romance]
# 11005                                      [Drama]
# 11058   [Drama, Horror, Science Fiction, Thriller]
# ...                                            ...
# 78571                                      [Drama]
# 87567                                     [Comedy]
# 122800             [Mystery, Drama, Action, Crime]
# 110843                              [Drama, Crime]
# 112205                     [Crime, Comedy, Action]
# 153538                                     [Music]
# 361671                                     [Drama]
# 137093                                    [Comedy]
# 184341                                     [Drama]
# 168672                              [Drama, Crime]
# 242076                    [Crime, Drama, Thriller]
# 23631                   [Action, Comedy, Thriller]
# 22423                            [Drama, Thriller]
# 73612                                      [Drama]
# 336004                   [Crime, Action, Thriller]
# 257211                                    [Comedy]
# 291870                                    [Comedy]
# 365717                                    [Comedy]
# 274479                             [Drama, Comedy]
# 369524                                    [Comedy]
# 425001                            [Comedy, Family]
# 438349                          [Thriller, Action]
# 398978                              [Drama, Crime]
# 147581                                     [Drama]
# 9992       [Adventure, Fantasy, Animation, Family]
# 466057                                    [Comedy]
# 467536                                     [Drama]
# 118254                                 [Animation]
# 475557                    [Crime, Thriller, Drama]
# 466420           [History, Thriller, Crime, Drama]
#
# [109 rows x 8 columns]

# %%
#Eliminate the rows without budget or revenue data
good_money_df = actor_full_df[(actor_full_df.budget > 0.0) & (actor_full_df.revenue > 0.0)]
pd.options.display.float_format = '{:,.2f}'.format
#good_money_df['revenue'] = good_money_df['revenue'].apply(lambda x: '{:d}'.format(x))

#good_money_df['budget'] = good_money_df['budget'].apply(lambda x: '{:,.2f}'.format(x))

#good_money_df['profit'] = good_money_df['profit'].apply(lambda x: '{:,.2f}'.format(x))
#print(good_money_df.info())
print(good_money_df.shape)
print(good_money_df.describe())
good_money_df
# Out:
# (62, 8)
#        popularity  vote_average  vote_count        revenue         budget  \
# count       62.00         62.00       62.00          62.00          62.00
# mean        10.70          6.63    1,751.21  94,392,643.85  40,581,346.69
# std          3.87          0.91    1,780.88  99,658,067.65  25,282,232.41
# min          2.82          4.10       59.00   3,000,000.00     500,000.00
# 25%          8.24          5.93      571.50  24,315,643.50  21,250,000.00
# 50%          9.48          6.55      958.50  57,068,543.00  32,500,000.00
# 75%         12.27          7.20    2,532.50 131,464,578.00  60,000,000.00
# max         22.62          8.50    7,914.00 516,642,939.00 100,000,000.00
#
#               profit
# count          62.00
# mean   53,811,297.16
# std    90,196,500.17
# min   -40,865,180.00
# 25%    -4,778,025.50
# 50%    21,890,315.00
# 75%    85,176,735.50
# max   436,642,939.00
#                                        title  popularity  vote_average  \
# 103                              Taxi Driver       17.50          8.20
# 117                         The Untouchables       13.22          7.80
# 184                             Jackie Brown       11.68          7.30
# 203                             Mean Streets        8.48          7.20
# 240                   The Godfather: Part II       22.62          8.50
# 311              Once Upon a Time in America       21.28          8.40
# 524                                   Casino       19.73          8.00
# 586                              Wag the Dog       11.07          6.90
# 635                              Angel Heart        9.44          7.20
# 693                         Meet the Fockers       12.84          6.20
# 769                               GoodFellas       22.00          8.40
# 819                                 Sleepers       12.43          7.50
# 949                                     Heat       15.41          7.80
# 1247                       The Good Shepherd        7.70          6.40
# 1578                             Raging Bull       15.27          7.90
# 1597                        Meet the Parents       12.76          6.60
# 1598                               Cape Fear        9.26          7.20
# 1607                            A Bronx Tale        9.81          7.60
# 2142                                Cop Land       11.10          6.70
# 2270                                Stardust        9.24          7.20
# 2749                              15 Minutes       11.77          5.80
# 2924                               Backdraft       11.40          6.60
# 3036                            Frankenstein        8.16          6.30
# 10555                             Shark Tale       16.39          5.90
# 11058                                Godsend        9.15          4.80
# 11096                          Hide and Seek        8.06          6.30
# 5851                                Showtime        9.35          5.40
# 11371                              The Score       10.32          6.70
# 11416                            The Mission        7.22          7.40
# 11778                        The Deer Hunter       12.73          8.00
# ...                                      ...         ...           ...
# 8944                      What Just Happened        5.81          5.40
# 9013                            Midnight Run        7.08          7.20
# 9410                      Great Expectations        8.59          6.60
# 9535                            Analyze This        9.01          6.40
# 9566                                 The Fan        9.04          5.90
# 12637                     New York, New York        6.60          6.50
# 9819                           Marvin's Room        8.63          6.70
# 9932                            Analyze That        9.42          5.70
# 13389                         Righteous Kill        8.99          5.90
# 13536                        City By The Sea        8.07          5.80
# 36094                         Stanley & Iris        2.82          6.50
# 44113                                  Stone        7.30          5.20
# 62838                         New Year's Eve       10.37          5.80
# 64807                           Grudge Match        7.93          6.00
# 39451                         Little Fockers        6.96          5.60
# 17711   The Adventures of Rocky & Bullwinkle        6.96          4.10
# 49021                           Killer Elite       10.29          6.20
# 51876                              Limitless       13.14          7.10
# 82693                Silver Linings Playbook        9.06          7.10
# 75638                             Red Lights        7.07          6.10
# 87567                        The Big Wedding        7.79          5.80
# 112205                            The Family        9.70          6.20
# 137093                            Last Vegas        8.91          6.40
# 168672                       American Hustle       13.84          6.80
# 23631                                Machete       13.10          6.30
# 336004                                 Heist        7.56          5.80
# 257211                            The Intern       11.26          7.10
# 291870                         Dirty Grandpa       11.66          5.80
# 274479                                   Joy       10.33          6.50
# 9992               Arthur and the Invisibles       10.17          6.20
#
#         vote_count    revenue     budget     profit  \
# 103           5578   28262574    1300000   26962574
# 117           2916   76270454   25000000   51270454
# 184           3236   39673162   12000000   27673162
# 203            871    3000000     500000    2500000
# 240           6205  102600000   13000000   89600000
# 311           2375    5300000   20000000  -14700000
# 524           2585  116112375   52000000   64112375
# 586            459   64256513   15000000   49256513
# 635            663   17185632   17000000     185632
# 693           2796  516642939   80000000  436642939
# 769           5947   46836394   25000000   21836394
# 819           1485  165615285   44000000  121615285
# 949           3382  187436818   60000000  127436818
# 1247           562   59908565   85000000  -25091435
# 1578          1939   23000000   18000000    5000000
# 1597          3449  330444045   55000000  275444045
# 1598          1492  182300000   35000000  147300000
# 1607           839   17287898   22000000   -4712102
# 2142           697   44862187   15000000   29862187
# 2270          2263  135560026   70000000   65560026
# 2749           345   56359980   60000000   -3640020
# 2924           652  152368585   75000000   77368585
# 3036           600  112006296   45000000   67006296
# 10555         3802  367275019   75000000  292275019
# 11058          224   30114487   25000000    5114487
# 11096          836  122650962   30000000   92650962
# 5851           493   77741732   85000000   -7258268
# 11371          793  113579918   68000000   45579918
# 11416          623   17218023   24500000   -7281977
# 11778         1828   50000000   15000000   35000000
# ...            ...        ...        ...        ...
# 8944           222    6673422   25000000  -18326578
# 9013           435   38413606   30000000    8413606
# 9410           258   55494066   25000000   30494066
# 9535           906  176885658   80000000   96885658
# 9566           367   18626419   55000000  -36373581
# 12637          179   16400000   14000000    2400000
# 9819           277   12803305   23000000  -10196695
# 9932           649   55003135   60000000   -4996865
# 13389          646   73174566   60000000   13174566
# 13536          167   22433915   40000000  -17566085
# 36094           59    5820015   23000000  -17179985
# 44113          350    9479718   22000000  -12520282
# 62838         1359  142044638   56000000   86044638
# 64807          745   44907260   40000000    4907260
# 39451         1985  310650585  100000000  210650585
# 17711          190   35134820   76000000  -40865180
# 49021         1136   57777106   66000000   -8222894
# 51876         6564  161849455   27000000  134849455
# 82693         7914  236412453   21000000  215412453
# 75638          643   13551174   14000000    -448826
# 87567          711   21819348   35000000  -13180652
# 112205        1712   36894225   30000000    6894225
# 137093        1266  134402450   28000000  106402450
# 168672        4595  251171807   40000000  211171807
# 23631         1940   31327899   20000000   11327899
# 336004         511    4100000    8900000   -4800000
# 257211        3521  194564672   35000000  159564672
# 291870        2783   94073028   11500000   82573028
# 274479        2817  101134059   60000000   41134059
# 9992          1571  107944236   86000000   21944236
#
#                                            genre_names
# 103                                     [Crime, Drama]
# 117                  [Crime, Drama, History, Thriller]
# 184                   [Crime, Thriller, Drama, Comedy]
# 203                                     [Drama, Crime]
# 240                                     [Drama, Crime]
# 311                                     [Drama, Crime]
# 524                                     [Crime, Drama]
# 586                                    [Comedy, Drama]
# 635                                  [Horror, Mystery]
# 693                                  [Comedy, Romance]
# 769                                     [Drama, Crime]
# 819                           [Crime, Drama, Thriller]
# 949                   [Action, Crime, Drama, Thriller]
# 1247                        [Drama, Thriller, History]
# 1578                                           [Drama]
# 1597                                 [Comedy, Romance]
# 1598                  [Crime, Thriller, Drama, Horror]
# 1607                                    [Drama, Crime]
# 2142                            [Action, Crime, Drama]
# 2270             [Adventure, Fantasy, Romance, Family]
# 2749                         [Action, Crime, Thriller]
# 2924         [Action, Crime, Drama, Mystery, Thriller]
# 3036         [Drama, Horror, Science Fiction, Romance]
# 10555              [Animation, Action, Comedy, Family]
# 11058       [Drama, Horror, Science Fiction, Thriller]
# 11096                      [Horror, Mystery, Thriller]
# 5851                                  [Action, Comedy]
# 11371               [Action, Crime, Thriller, Mystery]
# 11416              [Adventure, Drama, Action, History]
# 11778                                     [Drama, War]
# ...                                                ...
# 8944                                   [Comedy, Drama]
# 9013                        [Adventure, Comedy, Crime]
# 9410                          [Comedy, Drama, Romance]
# 9535                                   [Comedy, Crime]
# 9566                        [Drama, Mystery, Thriller]
# 12637                          [Drama, Music, Romance]
# 9819                                           [Drama]
# 9932                                   [Comedy, Crime]
# 13389                 [Action, Crime, Drama, Thriller]
# 13536                          [Crime, Drama, Mystery]
# 36094                                 [Drama, Romance]
# 44113                                [Drama, Thriller]
# 62838                                [Comedy, Romance]
# 64807                                         [Comedy]
# 39451                                [Comedy, Romance]
# 17711   [Action, Adventure, Animation, Comedy, Family]
# 49021                    [Action, Adventure, Thriller]
# 51876             [Thriller, Mystery, Science Fiction]
# 82693                         [Drama, Comedy, Romance]
# 75638                                       [Thriller]
# 87567                                         [Comedy]
# 112205                         [Crime, Comedy, Action]
# 137093                                        [Comedy]
# 168672                                  [Drama, Crime]
# 23631                       [Action, Comedy, Thriller]
# 336004                       [Crime, Action, Thriller]
# 257211                                        [Comedy]
# 291870                                        [Comedy]
# 274479                                 [Drama, Comedy]
# 9992           [Adventure, Fantasy, Animation, Family]
#
# [62 rows x 8 columns]

# %%
print("Enter valid genre: ")
test_for_genre = input("... MUST be a capitalized: ")

def is_genre(cell):
    #returns True if in, else false (for masking)
    if test_for_genre in cell:
        return True 
    return False

tested_for_genre_df = good_money_df[good_money_df.genre_names.map(is_genre)]
not_tested_for_genre_df = good_money_df[False == good_money_df.genre_names.map(is_genre)]

print(tested_for_genre_df.shape)
print(tested_for_genre_df.describe())
tested_for_genre_df
# Out:
# Enter valid genre:
# ... MUST be a capitalized: Comedy
# (23, 8)
#        popularity  vote_average  vote_count        revenue         budget  \
# count       23.00         23.00       23.00          23.00          23.00
# mean         9.91          6.19    1,897.74 135,298,640.61  45,847,826.09
# std          2.47          0.73    1,779.92 133,870,896.05  26,685,642.54
# min          5.81          4.10      190.00   6,673,422.00  11,500,000.00
# 25%          8.26          5.80      571.00  39,043,384.00  25,000,000.00
# 50%          9.42          6.20    1,359.00  77,741,732.00  35,000,000.00
# 75%         11.46          6.60    2,806.50 185,725,165.00  67,500,000.00
# max         16.39          7.30    7,914.00 516,642,939.00 100,000,000.00
#
#               profit
# count          23.00
# mean   89,450,814.52
# std   121,996,100.26
# min   -40,865,180.00
# 25%     5,900,742.50
# 50%    41,134,059.00
# 75%   132,983,561.00
# max   436,642,939.00
#                                        title  popularity  vote_average  \
# 184                             Jackie Brown       11.68          7.30
# 586                              Wag the Dog       11.07          6.90
# 693                         Meet the Fockers       12.84          6.20
# 1597                        Meet the Parents       12.76          6.60
# 10555                             Shark Tale       16.39          5.90
# 5851                                Showtime        9.35          5.40
# 8944                      What Just Happened        5.81          5.40
# 9013                            Midnight Run        7.08          7.20
# 9410                      Great Expectations        8.59          6.60
# 9535                            Analyze This        9.01          6.40
# 9932                            Analyze That        9.42          5.70
# 62838                         New Year's Eve       10.37          5.80
# 64807                           Grudge Match        7.93          6.00
# 39451                         Little Fockers        6.96          5.60
# 17711   The Adventures of Rocky & Bullwinkle        6.96          4.10
# 82693                Silver Linings Playbook        9.06          7.10
# 87567                        The Big Wedding        7.79          5.80
# 112205                            The Family        9.70          6.20
# 137093                            Last Vegas        8.91          6.40
# 23631                                Machete       13.10          6.30
# 257211                            The Intern       11.26          7.10
# 291870                         Dirty Grandpa       11.66          5.80
# 274479                                   Joy       10.33          6.50
#
#         vote_count    revenue     budget     profit  \
# 184           3236   39673162   12000000   27673162
# 586            459   64256513   15000000   49256513
# 693           2796  516642939   80000000  436642939
# 1597          3449  330444045   55000000  275444045
# 10555         3802  367275019   75000000  292275019
# 5851           493   77741732   85000000   -7258268
# 8944           222    6673422   25000000  -18326578
# 9013           435   38413606   30000000    8413606
# 9410           258   55494066   25000000   30494066
# 9535           906  176885658   80000000   96885658
# 9932           649   55003135   60000000   -4996865
# 62838         1359  142044638   56000000   86044638
# 64807          745   44907260   40000000    4907260
# 39451         1985  310650585  100000000  210650585
# 17711          190   35134820   76000000  -40865180
# 82693         7914  236412453   21000000  215412453
# 87567          711   21819348   35000000  -13180652
# 112205        1712   36894225   30000000    6894225
# 137093        1266  134402450   28000000  106402450
# 23631         1940   31327899   20000000   11327899
# 257211        3521  194564672   35000000  159564672
# 291870        2783   94073028   11500000   82573028
# 274479        2817  101134059   60000000   41134059
#
#                                            genre_names
# 184                   [Crime, Thriller, Drama, Comedy]
# 586                                    [Comedy, Drama]
# 693                                  [Comedy, Romance]
# 1597                                 [Comedy, Romance]
# 10555              [Animation, Action, Comedy, Family]
# 5851                                  [Action, Comedy]
# 8944                                   [Comedy, Drama]
# 9013                        [Adventure, Comedy, Crime]
# 9410                          [Comedy, Drama, Romance]
# 9535                                   [Comedy, Crime]
# 9932                                   [Comedy, Crime]
# 62838                                [Comedy, Romance]
# 64807                                         [Comedy]
# 39451                                [Comedy, Romance]
# 17711   [Action, Adventure, Animation, Comedy, Family]
# 82693                         [Drama, Comedy, Romance]
# 87567                                         [Comedy]
# 112205                         [Crime, Comedy, Action]
# 137093                                        [Comedy]
# 23631                       [Action, Comedy, Thriller]
# 257211                                        [Comedy]
# 291870                                        [Comedy]
# 274479                                 [Drama, Comedy]

# %%
#Not in genre info
print(not_tested_for_genre_df.shape)
print(not_tested_for_genre_df.describe())
not_tested_for_genre_df.head(3)
# Out:
# (39, 8)
#        popularity  vote_average  vote_count        revenue        budget  \
# count       39.00         39.00       39.00          39.00         39.00
# mean        11.16          6.89    1,664.79  70,268,594.49 37,475,474.23
# std          4.47          0.91    1,798.97  62,907,964.06 24,230,154.98
# min          2.82          4.80       59.00   3,000,000.00    500,000.00
# 25%          8.32          6.25      581.00  17,252,960.50 19,000,000.00
# 50%          9.52          6.80      839.00  50,000,000.00 27,000,000.00
# 75%         12.94          7.55    2,101.00 112,793,107.00 57,500,000.00
# max         22.62          8.50    6,564.00 251,171,807.00 86,000,000.00
#
#               profit
# count          39.00
# mean   32,793,120.26
# std    56,752,010.03
# min   -36,373,581.00
# 25%    -6,040,988.50
# 50%    13,174,566.00
# 75%    64,836,200.50
# max   211,171,807.00
#                 title  popularity  vote_average  vote_count   revenue  \
# 103       Taxi Driver       17.50          8.20        5578  28262574
# 117  The Untouchables       13.22          7.80        2916  76270454
# 203      Mean Streets        8.48          7.20         871   3000000
#
#        budget    profit                        genre_names
# 103   1300000  26962574                     [Crime, Drama]
# 117  25000000  51270454  [Crime, Drama, History, Thriller]
# 203    500000   2500000                     [Drama, Crime]

# %%
len(tested_for_genre_df['popularity'])
# Out:
# 23

# %%
#Plot the distribution for popularity

fig, ax = plt.subplots(1, figsize=(16, 3))
ax.scatter(tested_for_genre_df['popularity'], np.repeat(0, len(tested_for_genre_df['popularity'])) + np.random.normal(0, 0.1, len(tested_for_genre_df['popularity'])), marker="*", c='blue', s=120)
ax.scatter(not_tested_for_genre_df['popularity'], np.repeat(1, len(not_tested_for_genre_df['popularity'])) + np.random.normal(0, 0.1, len(not_tested_for_genre_df['popularity'])),marker="*", c='red', s=120)
plt.title(actor + ' Movies TMDB Popularity', size = 20)
ax.set_yticks([0, 1])

ax.set_yticklabels([test_for_genre, "Not " + test_for_genre])  #generalize the label for and genre
#plt.tight_layout()
# Out:
# [Text(0, 0, 'Comedy'), Text(0, 0, 'Not Comedy')]

# %% [markdown]
# Null Hypothesis: H0 - There is no difference in the popularity of De Niro's comedy genre movies vs. his non-comedy genre movies categories.
# This hypothesis will be tested with the Rank Sum Statistic aka the U-Test

# %%
def count_winning_pairs(sample_1, sample_2):
    sample_1, sample_2 = np.array(sample_1), np.array(sample_2)
    n_total_wins = 0
    for x in sample_1:
        n_wins = np.sum(x > sample_2) + 0.5*np.sum(x == sample_2)
        n_total_wins += n_wins
    return n_total_wins

not_genre_wins = count_winning_pairs(not_tested_for_genre_df['popularity'], tested_for_genre_df['popularity'])
genre_wins = count_winning_pairs(tested_for_genre_df['popularity'], not_tested_for_genre_df['popularity'])
print("Total Number of Comparisons: {}\n".format(len(not_tested_for_genre_df['profit'])*len(tested_for_genre_df['profit'])))

print("Number of In Genre: " + test_for_genre + " Movie Wins: {}".format(genre_wins))
print("Number of 'Not-in-Genre' Movie Wins: {}\n".format(not_genre_wins))
# Out:
# Total Number of Comparisons: 897
#
# Number of In Genre: Comedy Movie Wins: 399.0
# Number of 'Not-in-Genre' Movie Wins: 498.0

# %% [markdown]
# The total number of wins is the total number of comparisons between a popularity of an "in genre" movie and the popularity of a not-in-genre movie.

# %%
# Now, using the U-Test (aka the Mann-Whitney U Statistic) calculate 
#    the Rank Sum Statistic
res = stats.mannwhitneyu(not_tested_for_genre_df['popularity'], tested_for_genre_df['popularity'], alternative="greater")
print("p-value for 'Not-in-Genre' Movie Popularity > " + test_for_genre + " Movie Popularity: {:2.3f}".format(res.pvalue))
# Out:
# p-value for 'Not-in-Genre' Movie Popularity > Comedy Movie Popularity: 0.238

# %% [markdown]
# *********************************
#
# Here, fail to reject the null hypothesis that Robert De Niro comic movies are less popular than his non-comic movies, at least in the measure of popularity in the TMDB.
#
# *****Note that this conclusion will change for each actor and each genre tested!!!!

# %%
#Plot the distribution for profit
fig, ax = plt.subplots(1, figsize=(16, 3))
ax.scatter(tested_for_genre_df['revenue'], np.repeat(0, len(tested_for_genre_df['revenue'])) + np.random.normal(0, 0.1, len(tested_for_genre_df['revenue'])), marker='$''\$''$', c='yellow', edgecolors='green', s=330)
ax.scatter(not_tested_for_genre_df['revenue'], np.repeat(1, len(not_tested_for_genre_df['revenue'])) + np.random.normal(0, 0.1, len(not_tested_for_genre_df['revenue'])),marker='$''\$''$',c='blue', edgecolors='green', s=330)
plt.title(actor + ' Movies - Revenue', size=20)


def format_func(value, tick_number):
    # find number of multiples of pi/2
    N = int(np.round(value / 1000000))
    if N == 0:
        return "0"
    elif N == 100:
        return ("$100")
    elif N == 200:
        return ("$200")
    elif N == 300:
        return ("$300")
    elif N == 400:
        return ("$400")
    elif N == 500:
        return ("$500")
    elif N == 600:
        return ("$600")
    elif N == 700:
        return ("$700")
    else:
        return ("$800")

ax.xaxis.set_major_formatter(plt.FuncFormatter(format_func))
ax.set_xlabel('Millions of U.S. Dollars', backgroundcolor='white', color=(.3, .9, .01), animated=True, fontstyle='italic', size=13)
ax.set_yticks([0, 1])
_nothing = ax.set_yticklabels([test_for_genre + "  ", "Not " + test_for_genre], fontstyle='oblique', color=(.18, .31, .31), size='15')
#plt.tight_layout()

# %% [markdown]
# ******
# Null Hypothesis: H0 - There is no difference in the revenue of Robert De Niro's comic movies and the revenue of those movies not in the comic genre.
# This hypothesis will be tested with the Rank Sum Statistic aka the U-Test
# *******Note that this will change for each actor and genre tested.

# %%
def count_winning_pairs(sample_1, sample_2):
    sample_1, sample_2 = np.array(sample_1), np.array(sample_2)
    n_total_wins = 0
    for x in sample_1:
        n_wins = np.sum(x > sample_2) + 0.5*np.sum(x == sample_2)
        n_total_wins += n_wins
    return n_total_wins

not_genre_wins = count_winning_pairs(not_tested_for_genre_df['revenue'], tested_for_genre_df['revenue'])
genre_wins = count_winning_pairs(tested_for_genre_df['revenue'], not_tested_for_genre_df['revenue'])
print("Total Number of Comparisons: {}\n".format(len(not_tested_for_genre_df['revenue'])*len(tested_for_genre_df['revenue'])))
print("Number of 'Not-in-Genre' Movie Wins: {}\n".format(not_genre_wins))
print("Number of In Genre: " + test_for_genre + " Movie Wins: {}".format(genre_wins))
# Out:
# Total Number of Comparisons: 897
#
# Number of 'Not-in-Genre' Movie Wins: 310.0
#
# Number of In Genre: Comedy Movie Wins: 587.0

# %% [markdown]
# Remember, the total number of "wins" is the total number of comparisons between the revenue of a in-genre movie and the revenue of a not-in-genre movie.

# %%
# Now, using the U-Test (aka the Mann-Whitney U Statistic) calculate 
#    the Rank Sum Statistic
res = stats.mannwhitneyu(not_tested_for_genre_df['revenue'], tested_for_genre_df['revenue'], alternative="greater")

print("p-value for 'Not-in-Genre' Movie Popularity > " + test_for_genre + " Movie Popularity: {:2.3f}".format(res.pvalue))
# Out:
# p-value for 'Not-in-Genre' Movie Popularity > Comedy Movie Popularity: 0.979

# %% [markdown]
# ******
# Here, we do reject the null hypothesis that there is no difference in revenue between Robert De Niro's Comedy Genre films and his non-comic genre movies. His non-comic movies may well make more money.
# *****Note that this conclusion will change for each actor & genre tested.
